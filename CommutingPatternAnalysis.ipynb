# %%
# Start writing code here...
import pandas as pd
from shapely.geometry import Point # Shapely for converting latitude/longtitude to geometry
import geopandas as gpd # To create GeodataFrame
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
from datetime import datetime, timedelta
warnings.filterwarnings('ignore')

# %% [markdown]
# ## Read in data of EI trips

# %%
trips_ei = pd.read_csv('./Full Data1/trips_ei.csv',index_col=0)
trips_ei.reset_index(drop=True, inplace=True)

# %% [markdown]
# ## Create geometry column

# %%
# creating a geometry column 
trips_ei_origin = trips_ei.copy()
trips_ei_destn = trips_ei.copy()
trips_ei_origin['Startlocation'] = list(zip(trips_ei_origin.StartLocLon, trips_ei_origin.StartLocLat))
trips_ei_origin['Startlocation'] = trips_ei_origin['Startlocation'].apply(Point)

trips_ei_destn['Endlocation'] = list(zip(trips_ei_destn.EndLocLon, trips_ei_destn.EndLocLat))
trips_ei_destn['Endlocation'] = trips_ei_destn['Endlocation'].apply(Point)

# %%
# Coordinate reference system : WGS84
crs = {'init': 'epsg:4326'}

# Creating a Geographic data frame 
gdf_ei_origin = gpd.GeoDataFrame(trips_ei_origin, crs=crs, geometry=list(trips_ei_origin['Startlocation']))

# Creating a Geographic data frame 
gdf_ei_destn = gpd.GeoDataFrame(trips_ei_destn, crs=crs, geometry=list(trips_ei_destn['Endlocation']))

# %% [markdown]
# ## Separate each cluster into different dataframs

# %%
gb = gdf_ei_origin.groupby('StartCluster')    
clusters_origin = [gb.get_group(x) for x in gb.groups]
gb_destn = gdf_ei_destn.groupby('EndCluster') 
clusters_destn = [gb_destn.get_group(x) for x in gb_destn.groups]

# %% [markdown]
# # Origion Cluster Analysis

# %% [markdown]
# ## Get the number of trips in each origion cluster

# %%
# display the number of trips in each cluster
_clusters = gdf_ei_origin.groupby('StartCluster',as_index=False).agg(tripcount = ('TripId','count'))
sorted_clusters_origin = _clusters.sort_values(by ='tripcount')
sorted_clusters_origin
# Out:
#     StartCluster  tripcount
# 14            14        107
# 8              8        245
# 15            15        305
# 1              1        308
# 27            27        457
# 24            24        497
# 12            12        836
# 9              9       2797
# 19            19       3722
# 26            26       7878
# 16            16       9040
# 22            22       9581
# 21            21      10618
# 11            11      15677
# 23            23      17782
# 20            20      18115
# 4              4      19427
# 13            13      21406
# 7              7      26172
# 25            25      28171
# 6              6      33169
# 17            17      35258
# 3              3      38945
# 10            10      44822
# 5              5      46125
# 2              2      50638
# 0              0      71818
# 18            18      95482

# %%
#plt.rcParams['figure.figsize'] = [12, 15]
plt.figure(figsize=(15,18))
# Plot the figure.
cluster = list(sorted_clusters_origin.index)
tripcount = sorted_clusters_origin['tripcount']
# Plot the figure.
ax = tripcount.plot(kind='barh')
ax.set_title('Number of Trips by Clusters')
ax.set_xlabel('Number of Trips')
ax.set_ylabel('Clusters')
ax.set_yticklabels(cluster)

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # If value of bar is negative: Place label left of bar
    if x_value < 0:
        # Invert space to place label to the left
        space *= -1
        # Horizontally align label at right
        ha = 'right'

    # Use X value as label and format number with one decimal place
    label = "{:d}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.

#plt.savefig("image.png")

# %% [markdown]
# ## Get average trip time of each origin region

# %%
average_trip_time_origin = []
col_name = []
for i in range(0,28):
    name = str(i)
    col_name.append(name)

for gdf_origin in clusters_origin: 
    time_diff = gdf_origin
    time_diff['MST_end_datetime'] = pd.to_datetime(time_diff['MST_end_datetime'])
    time_diff['MST_start_datetime'] = pd.to_datetime(time_diff['MST_start_datetime'])

    time_diff['timediff_min'] = (time_diff.MST_end_datetime - time_diff.MST_start_datetime) / pd.Timedelta(minutes=1)
    ave = time_diff['timediff_min'].mean()
    average_trip_time_origin.append(ave)

# %%
average_trip_time_origin = pd.DataFrame({"StartCluster":col_name,"triptime":average_trip_time_origin})
average_trip_time_origin = average_trip_time_origin.sort_values(by=['triptime'])
average_trip_time_origin
# Out:
#    StartCluster    triptime
# 10           10   14.496718
# 0             0   14.833335
# 5             5   20.060216
# 2             2   20.390456
# 3             3   20.725153
# 6             6   21.250538
# 18           18   21.777176
# 17           17   26.149636
# 25           25   27.528507
# 23           23   28.226101
# 20           20   31.687538
# 7             7   32.222733
# 11           11   33.799794
# 4             4   34.680479
# 13           13   38.395746
# 22           22   39.864539
# 16           16   46.198621
# 21           21   48.697230
# 19           19   51.441030
# 9             9   51.834160
# 26           26   86.862633
# 24           24  102.211784
# 12           12  122.711026
# 27           27  168.349301
# 15           15  192.090840
# 1             1  214.208604
# 8             8  281.508435
# 14           14  370.851558

# %%
plt.figure(figsize=(16,15))
# Plot the figure.
cluster = list(average_trip_time_origin['StartCluster'])
# Plot the figure.
ax = average_trip_time_origin['triptime'].plot(kind='barh')
ax.set_title('Average Trip Time of Origin Clusters (EI)')
ax.set_xlabel('Average Trip Time in Minutes')
ax.set_ylabel('Clusters')
ax.set_yticklabels(cluster)

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # If value of bar is negative: Place label left of bar
    if x_value < 0:
        # Invert space to place label to the left
        space *= -1
        # Horizontally align label at right
        ha = 'right'

    # Use X value as label and format number with one decimal place
    label = "{:.2f}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.

#plt.savefig("image.png")

# %% [markdown]
# ## Create the bounding polygon of each cluster

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
polygons = []
for cluster in clusters_origin:
    points = list(zip(cluster['StartLocLon'],cluster['StartLocLat']))
    points = np.array([*points])
    hull = ConvexHull(points)
    points_l = []
    for simplex in hull.simplices:
        points_l.append(Point(points[simplex][0][0], points[simplex][0][1]))
        points_l.append(Point(points[simplex][1][0], points[simplex][1][1]))

    polygon_geom = Polygon([[p.x, p.y] for p in points_l]).convex_hull
    polygon = gpd.GeoDataFrame(index=[0], crs=crs, geometry=[polygon_geom])
    polygons.append(polygon)

# %% [markdown]
# ## Draw polygons, gradient by the number of trips in each cluster

# %%
# convert ['StartCluster'] column to string 
sorted_clusters_origin['StartCluster'] = sorted_clusters_origin['StartCluster'].astype('str')

# create a geojson object from the polygons
geojson_poly = pd.DataFrame()
geojson_poly['StartCluster'] = sorted_clusters_origin['StartCluster']
geojson_poly['geometry'] = ''
for i in geojson_poly['StartCluster']:
    i = int(i)
    geojson_poly['geometry'].loc[i] = polygons[i]['geometry'].loc[0]
crs = {'init': 'epsg:4326'}
geojson_poly = gpd.GeoDataFrame(geojson_poly, crs=crs, geometry=list(geojson_poly['geometry']))
geojson_poly = geojson_poly.to_json()

# %%
# Draw the gradiented polygons on map 
import folium
m = folium.Map(location=[38, -104], zoom_start=5)
crs = {'init': 'epsg:4326'}
# capturing the return of folium.Choropleth()
cp = folium.Choropleth(
  geo_data=geojson_poly,
  name="choropleth",
  data=sorted_clusters_origin,
  columns=['StartCluster','tripcount'],
  key_on="feature.id",
  fill_color="YlGn",
  fill_opacity=0.7,
  line_opacity=0.2,
  legend_name="Number of Trips",
).add_to(m)

# looping thru the geojson object and adding a new property(unemployment)
# and assigning a value from our dataframe
for s in cp.geojson.data['features']:
    s['properties']['tripcount'] = str(sorted_clusters_origin['tripcount'].loc[int(s['id'])])

# and finally adding a tooltip/hover to the choropleth's geojson
folium.GeoJsonTooltip(['StartCluster','tripcount']).add_to(cp.geojson)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_7a5583ff1e1c528788bbd61a5b878b4a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_7a5583ff1e1c528788bbd61a5b878b4a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_7a5583ff1e1c528788bbd61a5b878b4a = L.map(
#                 &quot;map_7a5583ff1e1c528788bbd61a5b878b4a&quot;,
#                 {
#                     center: [38.0, -104.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_596ad0a5a356ddef5fb375ad7915af34 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_7a5583ff1e1c528788bbd61a5b878b4a);
#
#
#             var choropleth_810e1d60a7284748979639d7ed50bebf = L.featureGroup(
#                 {}
#             ).addTo(map_7a5583ff1e1c528788bbd61a5b878b4a);
#
#
#         function geo_json_c52fb445b7e848442a86d94a3a64951d_styler(feature) {
#             switch(feature.id) {
#                 case &quot;23&quot;: case &quot;20&quot;: case &quot;4&quot;: case &quot;13&quot;: case &quot;7&quot;: case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;6&quot;: case &quot;17&quot;: case &quot;3&quot;: case &quot;10&quot;: case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;0&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;18&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_c52fb445b7e848442a86d94a3a64951d_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_c52fb445b7e848442a86d94a3a64951d = L.geoJson(null, {
#                 onEachFeature: geo_json_c52fb445b7e848442a86d94a3a64951d_onEachFeature,
#
#                 style: geo_json_c52fb445b7e848442a86d94a3a64951d_styler,
#         });
#
#         function geo_json_c52fb445b7e848442a86d94a3a64951d_add (data) {
#             geo_json_c52fb445b7e848442a86d94a3a64951d
#                 .addData(data)
#                 .addTo(choropleth_810e1d60a7284748979639d7ed50bebf);
#         }
#             geo_json_c52fb445b7e848442a86d94a3a64951d_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-98.6634, 35.53613], [-98.92433, 36.14397], [-99.64805, 38.96634], [-99.25666, 40.67803], [-96.13929, 41.16573], [-94.13017, 39.01331], [-98.6634, 35.53613]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;14&quot;, &quot;properties&quot;: {&quot;StartCluster&quot;: &quot;14&quot;, &quot;tripcount&quot;: &quot;107&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.91697, 32.73703], [-103.20487, 34.39954], [-103.37104, 36.49583], [-102.66517, 37.27897], [-102.61573, 37.2735], [-100.92247, 37.04805], [-99.41596, 36.43398], [-98.71147, 35.5216], [-98.19786, 33.80026], [-100.91697, 32.73703]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;8&quot;, &quot;properties&quot;: {&quot;StartCluster&quot;: &quot;8&quot;, &quot;tripcount&quot;: &quot;245&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-110.15785, 34.90902], [-111.

# %% [markdown]
# ## Draw polygons, gradient by the average trip time

# %%
# convert ['StartCluster'] column to string 
average_trip_time_origin['StartCluster'] = average_trip_time_origin['StartCluster']

# create a geojson object from the polygons
geojson_poly = pd.DataFrame()
geojson_poly['StartCluster'] = average_trip_time_origin['StartCluster']
geojson_poly['geometry'] = ''
for i in geojson_poly['StartCluster']:
    i = int(i)
    geojson_poly['geometry'].loc[i] = polygons[i]['geometry'].loc[0]
crs = {'init': 'epsg:4326'}
geojson_poly = gpd.GeoDataFrame(geojson_poly, crs=crs, geometry=list(geojson_poly['geometry']))
geojson_poly = geojson_poly.to_json()

# %%
# Draw the gradiented polygons on map 
import folium
m = folium.Map(location=[38, -104], zoom_start=5)
crs = {'init': 'epsg:4326'}
# capturing the return of folium.Choropleth()
cp = folium.Choropleth(
  geo_data=geojson_poly,
  name="choropleth",
  data=average_trip_time_origin,
  columns=['StartCluster','triptime'],
  key_on="feature.id",
  fill_color="YlGn",
  fill_opacity=0.7,
  line_opacity=0.2,
  legend_name="Average Trip Time",
).add_to(m)

# looping thru the geojson object and adding a new property(unemployment)
# and assigning a value from our dataframe
for s in cp.geojson.data['features']:
    s['properties']['triptime'] = str(average_trip_time_origin['triptime'].loc[int(s['id'])])

# and finally adding a tooltip/hover to the choropleth's geojson
folium.GeoJsonTooltip(['StartCluster','triptime']).add_to(cp.geojson)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_77cd729a93ba5f6cc6085feeabfdd1bb {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_77cd729a93ba5f6cc6085feeabfdd1bb&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_77cd729a93ba5f6cc6085feeabfdd1bb = L.map(
#                 &quot;map_77cd729a93ba5f6cc6085feeabfdd1bb&quot;,
#                 {
#                     center: [38.0, -104.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_031bf45077452c3a697b7582170c3fb1 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_77cd729a93ba5f6cc6085feeabfdd1bb);
#
#
#             var choropleth_b98a2f9732c7bec3b3f8708a977d14d1 = L.featureGroup(
#                 {}
#             ).addTo(map_77cd729a93ba5f6cc6085feeabfdd1bb);
#
#
#         function geo_json_d8fe7cec1770b448107835bc384c1882_styler(feature) {
#             switch(feature.id) {
#                 case &quot;14&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;8&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;15&quot;: case &quot;27&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;24&quot;: case &quot;12&quot;: case &quot;26&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d8fe7cec1770b448107835bc384c1882_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d8fe7cec1770b448107835bc384c1882 = L.geoJson(null, {
#                 onEachFeature: geo_json_d8fe7cec1770b448107835bc384c1882_onEachFeature,
#
#                 style: geo_json_d8fe7cec1770b448107835bc384c1882_styler,
#         });
#
#         function geo_json_d8fe7cec1770b448107835bc384c1882_add (data) {
#             geo_json_d8fe7cec1770b448107835bc384c1882
#                 .addData(data)
#                 .addTo(choropleth_b98a2f9732c7bec3b3f8708a977d14d1);
#         }
#             geo_json_d8fe7cec1770b448107835bc384c1882_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-98.6634, 35.53613], [-98.92433, 36.14397], [-99.64805, 38.96634], [-99.25666, 40.67803], [-96.13929, 41.16573], [-94.13017, 39.01331], [-98.6634, 35.53613]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;14&quot;, &quot;properties&quot;: {&quot;StartCluster&quot;: &quot;14&quot;, &quot;triptime&quot;: &quot;370.8515576323988&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-100.91697, 32.73703], [-103.20487, 34.39954], [-103.37104, 36.49583], [-102.66517, 37.27897], [-102.61573, 37.2735], [-100.92247, 37.04805], [-99.41596, 36.43398], [-98.71147, 35.5216], [-98.19786, 33.80026], [-100.91697, 32.73703]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;8&quot;, &quot;properties&quot;: {&quot;StartCluster&quot;: &quot;8&quot;, &quot;triptime&quot;: &quot;281.50843537414966&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-110.15785, 34.90902], [-111.67396, 41.04569], [-110.94062, 41.26903], [-107.31101, 41.77796], [-107.30964, 41.77796], [-10

# %% [markdown]
# # Destination Polygons

# %% [markdown]
# ## Get the number of trips in each origion cluster

# %%
# display the number of trips in each cluster
_clusters = gdf_ei_destn.groupby('EndCluster',as_index=False).agg(tripcount = ('TripId','count'))
sorted_clusters_destn = _clusters.sort_values(by ='tripcount')
sorted_clusters_destn
# Out:
#     EndCluster  tripcount
# 11          11         32
# 26          26        141
# 23          23        429
# 22          22       1328
# 20          20       2443
# 15          15      10874
# 12          12      12039
# 24          24      12067
# 6            6      12701
# 9            9      12943
# 16          16      14307
# 10          10      14529
# 19          19      17941
# 3            3      18687
# 1            1      18777
# 21          21      23511
# 0            0      26036
# 8            8      26912
# 4            4      27203
# 18          18      29483
# 7            7      30861
# 27          27      33044
# 14          14      36594
# 5            5      36735
# 17          17      39662
# 25          25      43445
# 2            2      50564
# 13          13      56110

# %%
#plt.rcParams['figure.figsize'] = [12, 15]
plt.figure(figsize=(15,18))
# Plot the figure.
cluster = list(sorted_clusters_destn.index)
tripcount = sorted_clusters_destn['tripcount']
# Plot the figure.
ax = tripcount.plot(kind='barh')
ax.set_title('Number of Trips by Clusters')
ax.set_xlabel('Number of Trips')
ax.set_ylabel('Clusters')
ax.set_yticklabels(cluster)

rects = ax.patches

# For each bar: Place a label
for rect in rects:
    # Get X and Y placement of label from rect.
    x_value = rect.get_width()
    y_value = rect.get_y() + rect.get_height() / 2

    # Number of points between bar and label. Change to your liking.
    space = 5
    # Vertical alignment for positive values
    ha = 'left'

    # If value of bar is negative: Place label left of bar
    if x_value < 0:
        # Invert space to place label to the left
        space *= -1
        # Horizontally align label at right
        ha = 'right'

    # Use X value as label and format number with one decimal place
    label = "{:d}".format(x_value)

    # Create annotation
    plt.annotate(
        label,                      # Use `label` as label
        (x_value, y_value),         # Place label at end of the bar
        xytext=(space, 0),          # Horizontally shift label by `space`
        textcoords="offset points", # Interpret `xytext` as offset in points
        va='center',                # Vertically center label
        ha=ha)                      # Horizontally align label differently for
                                    # positive and negative values.

#plt.savefig("image.png")

# %%
from scipy.spatial import ConvexHull, convex_hull_plot_2d
import matplotlib.pyplot as plt
from shapely.geometry import Polygon
polygons = []
for cluster in clusters_destn:
    points = list(zip(cluster['EndLocLon'],cluster['EndLocLat']))
    points = np.array([*points])
    hull = ConvexHull(points)
    points_l = []
    for simplex in hull.simplices:
        points_l.append(Point(points[simplex][0][0], points[simplex][0][1]))
        points_l.append(Point(points[simplex][1][0], points[simplex][1][1]))

    polygon_geom = Polygon([[p.x, p.y] for p in points_l]).convex_hull
    polygon = gpd.GeoDataFrame(index=[0], crs=crs, geometry=[polygon_geom])
    polygons.append(polygon)

# %%
# convert ['StartCluster'] column to string 
sorted_clusters_destn['EndCluster'] = sorted_clusters_destn['EndCluster'].astype('str')

# create a geojson object from the polygons
geojson_poly = pd.DataFrame()
geojson_poly['EndCluster'] = sorted_clusters_destn['EndCluster']
geojson_poly['geometry'] = ''
for i in geojson_poly['EndCluster']:
    i = int(i)
    geojson_poly['geometry'].loc[i] = polygons[i]['geometry'].loc[0]
crs = {'init': 'epsg:4326'}
geojson_poly = gpd.GeoDataFrame(geojson_poly, crs=crs, geometry=list(geojson_poly['geometry']))
geojson_poly = geojson_poly.to_json()

# %%
# Draw the gradiented polygons on map 
import folium
m = folium.Map(location=[38, -104], zoom_start=5)
crs = {'init': 'epsg:4326'}
# capturing the return of folium.Choropleth()
cp = folium.Choropleth(
  geo_data=geojson_poly,
  name="choropleth",
  data=sorted_clusters_destn,
  columns=['EndCluster','tripcount'],
  key_on="feature.id",
  fill_color="YlGn",
  fill_opacity=0.7,
  line_opacity=0.2,
  legend_name="Number of Trips",
).add_to(m)

# looping thru the geojson object and adding a new property(unemployment)
# and assigning a value from our dataframe
for s in cp.geojson.data['features']:
    s['properties']['tripcount'] = str(sorted_clusters_destn['tripcount'].loc[int(s['id'])])

# and finally adding a tooltip/hover to the choropleth's geojson
folium.GeoJsonTooltip(['EndCluster','tripcount']).add_to(cp.geojson)

folium.LayerControl().add_to(m)

m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_6dd847d43df4a096c83c1847831329dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/d3/3.5.5/d3.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_6dd847d43df4a096c83c1847831329dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_6dd847d43df4a096c83c1847831329dc = L.map(
#                 &quot;map_6dd847d43df4a096c83c1847831329dc&quot;,
#                 {
#                     center: [38.0, -104.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_0b9a9823ddac82bb748cedd4100e66b5 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_6dd847d43df4a096c83c1847831329dc);
#
#
#             var choropleth_82e8afdcc3cf7c9eff1444a09a8cad2a = L.featureGroup(
#                 {}
#             ).addTo(map_6dd847d43df4a096c83c1847831329dc);
#
#
#         function geo_json_d8d732939207d3afc0729aa1e9fff877_styler(feature) {
#             switch(feature.id) {
#                 case &quot;11&quot;: case &quot;26&quot;: case &quot;23&quot;: case &quot;22&quot;: case &quot;20&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#ffffcc&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;1&quot;: case &quot;21&quot;: case &quot;0&quot;: case &quot;8&quot;: case &quot;4&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#addd8e&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;18&quot;: case &quot;7&quot;: case &quot;27&quot;: case &quot;14&quot;: case &quot;5&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#78c679&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;17&quot;: case &quot;25&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#31a354&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 case &quot;2&quot;: case &quot;13&quot;:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#006837&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#                 default:
#                     return {&quot;color&quot;: &quot;black&quot;, &quot;fillColor&quot;: &quot;#d9f0a3&quot;, &quot;fillOpacity&quot;: 0.7, &quot;opacity&quot;: 0.2, &quot;weight&quot;: 1};
#             }
#         }
#
#         function geo_json_d8d732939207d3afc0729aa1e9fff877_onEachFeature(feature, layer) {
#             layer.on({
#             });
#         };
#         var geo_json_d8d732939207d3afc0729aa1e9fff877 = L.geoJson(null, {
#                 onEachFeature: geo_json_d8d732939207d3afc0729aa1e9fff877_onEachFeature,
#
#                 style: geo_json_d8d732939207d3afc0729aa1e9fff877_styler,
#         });
#
#         function geo_json_d8d732939207d3afc0729aa1e9fff877_add (data) {
#             geo_json_d8d732939207d3afc0729aa1e9fff877
#                 .addData(data)
#                 .addTo(choropleth_82e8afdcc3cf7c9eff1444a09a8cad2a);
#         }
#             geo_json_d8d732939207d3afc0729aa1e9fff877_add({&quot;features&quot;: [{&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-103.75556, 37.49392], [-103.75282, 37.63435], [-103.66493, 37.64414], [-103.57841, 37.64414], [-103.75556, 37.49392]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;11&quot;, &quot;properties&quot;: {&quot;EndCluster&quot;: &quot;11&quot;, &quot;tripcount&quot;: &quot;32&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&quot;: {&quot;coordinates&quot;: [[[-104.01786, 37.34668], [-104.04121, 37.35105], [-104.04121, 37.44379], [-104.03434, 37.55818], [-103.88877, 37.61259], [-103.82698, 37.56907], [-103.8256, 37.556], [-103.83247, 37.42416], [-103.88053, 37.38816], [-104.01786, 37.34668]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;26&quot;, &quot;properties&quot;: {&quot;EndCluster&quot;: &quot;26&quot;, &quot;tripcount&quot;: &quot;141&quot;}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;geometry&
