# %%
import pandas as pd
from shapely.geometry import Point # Shapely for converting latitude/longtitude to geometry
import geopandas as gpd 
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
import warnings
from datetime import datetime, timedelta
warnings.filterwarnings('ignore')
# %matplotlib widget

# %%
header = list(pd.read_csv('TripBulkReportTripsHeaders.csv',keep_default_na=True))
header.append('Unnamed 31')
header.append('Unnamed 32')
trip_df = pd.read_csv('trips.csv', keep_default_na=True, names=header)
small_trip_df = pd.read_csv('trips.csv1', keep_default_na=True, names=header)

# %%
frames = [trip_df,small_trip_df]
trips_df = pd.concat(frames)

# %%
trips_df = trips_df[(trips_df['OriginZoneName']!='Buc-ee\'s Giddings TX')& (trips_df['DestinationZoneName']!='Buc-ee\'s Giddings TX')]
# creating a geometry column 
trips_df['Startlocation'] = list(zip(trips_df.StartLocLat, trips_df.StartLocLon))
trips_df['Startlocation'] = trips_df['Startlocation'].apply(Point)

trips_df['Endlocation'] = list(zip(trips_df.EndLocLat, trips_df.EndLocLon))
trips_df['Endlocation'] = trips_df['Endlocation'].apply(Point)

trips_df= trips_df.drop(['Unnamed 31', 'Unnamed 32'], axis=1)

# %%
gdf = gpd.GeoDataFrame(trips_df)

# %%
gdf['MST_start_datetime'] = pd.to_datetime(gdf['StartDate']).apply(lambda x:x.astimezone('MST'))
gdf['MST_end_datetime'] = pd.to_datetime(gdf['EndDate']).apply(lambda x:x.astimezone('MST'))

gdf['MST_start_date'] = gdf['MST_start_datetime'].apply(lambda x:x.date())
gdf['MST_start_time'] = gdf['MST_start_datetime'].apply(lambda x:x.time())

gdf['MST_end_date'] = gdf['MST_end_datetime'].apply(lambda x:x.date())
gdf['MST_end_time'] = gdf['MST_end_datetime'].apply(lambda x:x.time())

# create df of start day, month, year 
startYear = list(pd.DatetimeIndex(gdf['MST_start_date']).year)
startMonth = list(pd.DatetimeIndex(gdf['MST_start_date']).month)
startDay = list(pd.DatetimeIndex(gdf['MST_start_date']).day)

# insert the start month, day, year column into the gdf
gdf.insert(int(gdf.columns.get_indexer(['MST_start_date'])[0]+1), 'MST_start_month',startMonth)
gdf.insert(int(gdf.columns.get_indexer(['MST_start_date'])[0]+2), 'MST_start_day',startDay)
gdf.insert(int(gdf.columns.get_indexer(['MST_start_date'])[0]+3), 'MST_start_year',startYear)

# create df of start hour, minutes, and seconds
startHour = list(pd.DatetimeIndex(gdf['MST_start_datetime']).hour)
startMin = list(pd.DatetimeIndex(gdf['MST_start_datetime']).minute)
startSec = list(pd.DatetimeIndex(gdf['MST_start_datetime']).second)

# insert the start hour, minutes, seconds column into the gdf
gdf.insert(int(gdf.columns.get_indexer(['MST_start_time'])[0]+1), 'MST_start_hour',startHour)
gdf.insert(int(gdf.columns.get_indexer(['MST_start_time'])[0]+2), 'MST_start_minute',startMin)
gdf.insert(int(gdf.columns.get_indexer(['MST_start_time'])[0]+3), 'MST_start_second',startSec)

# create df of end day, month, year 
endYear = list(pd.DatetimeIndex(gdf['MST_end_date']).year)
endMonth = list(pd.DatetimeIndex(gdf['MST_end_date']).month)
endDay = list(pd.DatetimeIndex(gdf['MST_end_date']).day)

# insert the start month, day, year column into the gdf
gdf.insert(int(gdf.columns.get_indexer(['MST_end_date'])[0]+1), 'MST_end_month',endMonth)
gdf.insert(int(gdf.columns.get_indexer(['MST_end_date'])[0]+2), 'MST_end_day',endDay)
gdf.insert(int(gdf.columns.get_indexer(['MST_end_date'])[0]+3), 'MST_end_year',endYear)

# create df of end hour, minutes, and seconds
endHour = list(pd.DatetimeIndex(gdf['MST_end_datetime']).hour)
endMin = list(pd.DatetimeIndex(gdf['MST_end_datetime']).minute)
endSec = list(pd.DatetimeIndex(gdf['MST_end_datetime']).second)


# insert the start hour, minutes, seconds column into the gdf
gdf.insert(int(gdf.columns.get_indexer(['MST_end_time'])[0]+1), 'MST_end_hour',endHour)
gdf.insert(int(gdf.columns.get_indexer(['MST_end_time'])[0]+2), 'MST_end_minute',endMin)
gdf.insert(int(gdf.columns.get_indexer(['MST_end_time'])[0]+3), 'MST_end_second',endSec)
gdf['start_year_month'] = pd.to_datetime(gdf['MST_start_datetime']).dt.to_period('M')

# %%
gdf.head()
# Out:
#                              TripId                          DeviceId  \
# 0  4e6d3859173a783b35f234126e7d84ab  0da5283cac35fa6de9a83477d1477377
# 1  a9f9b922d560178ab3bd1b773fef437d  0ec14c96079ca0e5b6afd3d0a429cf49
# 2  f6aec89e2dd3cd8fe5d09e45fc083de9  13d0412d930e3669ac09040c767f1097
# 3  b87c20dbcc739db4ff64c100398437b7  1520526e3b9c71175574099508704611
# 4  ea65f3a1f58f2431dcfe317be0bdd002  15c0082ebc282eaf14a6c80c67017142
#
#                          ProviderId  Mode                 StartDate  \
# 0  d07e70efcfab08731a97e7b91be644de     1  2020-12-28T14:49:16.000Z
# 1  42998cf32d552343bc8e460416382dca     1  2020-12-22T20:15:06.000Z
# 2  42998cf32d552343bc8e460416382dca     1  2020-12-22T01:32:52.000Z
# 3  d07e70efcfab08731a97e7b91be644de     1  2020-12-22T14:13:19.000Z
# 4  66f041e16a60928b05a7e228a89c3799     1  2020-12-22T11:46:26.000Z
#
#    StartWDay                   EndDate  EndWDay  StartLocLat  StartLocLon  \
# 0          1  2020-12-28T15:53:22.000Z        1     38.71498   -104.70176
# 1          2  2020-12-22T20:26:22.000Z        2     38.74497   -104.79377
# 2          1  2020-12-22T01:59:33.000Z        1     38.76318   -104.80476
# 3          2  2020-12-22T14:30:36.000Z        2     38.69890   -104.68940
# 4          2  2020-12-22T12:03:42.000Z        2     38.75568   -104.80339
#
#    ...            StartQk              EndQk                Startlocation  \
# 0  ...  23101211002301310  23101210113102230  POINT (38.71498 -104.70176)
# 1  ...  23101210113103011  23101211000023121  POINT (38.74497 -104.79377)
# 2  ...  23101210111320233  23101210111320232  POINT (38.76318 -104.80476)
# 3  ...  23101211002330133  23101210113101210    POINT (38.6989 -104.6894)
# 4  ...  23101210111322320  23101210113121113  POINT (38.75568 -104.80339)
#
#                    Endlocation        MST_start_datetime  \
# 0  POINT (38.73855 -104.80613) 2020-12-28 07:49:16-07:00
# 1  POINT (38.79423 -104.74708) 2020-12-22 13:15:06-07:00
# 2  POINT (38.76318 -104.80613) 2020-12-21 18:32:52-07:00
# 3  POINT (38.74926 -104.79515) 2020-12-22 07:13:19-07:00
# 4  POINT (38.73533 -104.78828) 2020-12-22 04:46:26-07:00
#
#            MST_end_datetime  MST_start_date MST_start_time MST_end_date  \
# 0 2020-12-28 08:53:22-07:00      2020-12-28       07:49:16   2020-12-28
# 1 2020-12-22 13:26:22-07:00      2020-12-22       13:15:06   2020-12-22
# 2 2020-12-21 18:59:33-07:00      2020-12-21       18:32:52   2020-12-21
# 3 2020-12-22 07:30:36-07:00      2020-12-22       07:13:19   2020-12-22
# 4 2020-12-22 05:03:42-07:00      2020-12-22       04:46:26   2020-12-22
#
#    MST_end_time
# 0      08:53:22
# 1      13:26:22
# 2      18:59:33
# 3      07:30:36
# 4      05:03:42
#
# [5 rows x 39 columns]

# %% [markdown]
# ### We are going to grab data for the month of September 2021 to run our segment criticality test

# %%
sept_2021_gdf = gdf[gdf['start_year_month'] == '2021-09']

# %%
print(sept_2021_gdf["MST_start_date"].min())
print(sept_2021_gdf["MST_start_date"].max())
# Out:
# 2021-09-01
# 2021-09-30

# %%
sept_2021_gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 323624 entries, 6446 to 1154170
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count   Dtype
# ---  ------                  --------------   -----
#  0   TripId                  323624 non-null  object
#  1   DeviceId                323624 non-null  object
#  2   ProviderId              323624 non-null  object
#  3   Mode                    323624 non-null  int64
#  4   StartDate               323624 non-null  object
#  5   StartWDay               323624 non-null  int64
#  6   EndDate                 323624 non-null  object
#  7   EndWDay                 323624 non-null  int64
#  8   StartLocLat             323624 non-null  float64
#  9   StartLocLon             323624 non-null  float64
#  10  EndLocLat               323624 non-null  float64
#  11  EndLocLon               323624 non-null  float64
#  12  GeospatialType          323624 non-null  object
#  13  ProviderType            323624 non-null  int64
#  14  ProviderDrivingProfile  323624 non-null  int64
#  15  VehicleWeightClass      323624 non-null  int64
#  16  ProbeSourceType         323624 non-null  int64
#  17  OriginZoneName          240337 non-null  object
#  18  DestinationZoneName     239974 non-null  object
#  19  EndpointType            323624 non-null  int64
#  20  TripMeanSpeedKph        323624 non-null  float64
#  21  TripMaxSpeedKph         323624 non-null  float64
#  22  TripDistanceMeters      323624 non-null  float64
#  23  MovementType            323624 non-null  int64
#  24  OriginCbg               0 non-null       float64
#  25  DestCbg                 0 non-null       float64
#  26  StartTimezone           323624 non-null  object
#  27  EndTimezone             323624 non-null  object
#  28  WaypointFreqSec         0 non-null       float64
#  29  StartQk                 323624 non-null  int64
#  30  EndQk                   323624 non-null  int64
#  31  Startlocation           323624 non-null  object
#  32  Endlocation             323624 non-null  object
#  33  MST_start_datetime      323624 non-null  datetime64[ns, MST]
#  34  MST_end_datetime        323624 non-null  datetime64[ns, MST]
#  35  MST_start_date          323624 non-null  object
#  36  MST_start_month         323624 non-null  int64
#  37  MST_start_day           323624 non-null  int64
#  38  MST_start_year          323624 non-null  int64
#  39  MST_start_time          323624 non-null  object
#  40  MST_start_hour          323624 non-null  int64
#  41  MST_start_minute        323624 non-null  int64
#  42  MST_start_second        323624 non-null  int64
#  43  MST_end_date            323624 non-null  object
#  44  MST_end_month           323624 non-null  int64
#  45  MST_end_day             323624 non-null  int64
#  46  MST_end_year            323624 non-null  int64
#  47  MST_end_time            323624 non-null  object
#  48  MST_end_hour            323624 non-null  int64
#  49  MST_end_minute          323624 non-null  int64
#  50  MST_end_second          323624 non-null  int64
#  51  start_year_month        323624 non-null  period[M]
# dtypes: datetime64[ns, MST](2), float64(10), int64(23), object(16), period[M](1)
# memory usage: 130.9+ MB

# %%
device_num = sept_2021_gdf['DeviceId'].nunique()
print('There are a total of ' + str(device_num) + ' unique devices for the month on September 2021')
# Out:
# There are a total of 137717 unique devices for the month on September 2021

# %%
count_plot = sns.countplot(sept_2021_gdf['Mode'])
count_plot.set_xticklabels(['Walk','Vehicle']) 
count_plot.bar_label(count_plot.containers[0],fmt='%9.0f')
# Out:
# [Text(0, 0, '     4824'), Text(0, 0, '   318800')]

# %%
# Since we are looking at critical roads, we will focus on data points traveled through vehicle first
sep_vehicle_gdf = sept_2021_gdf[sept_2021_gdf['Mode'] == 1]

# %%
sept_2021_gdf.DestinationZoneName.unique()
# Out:
# array(['FortCarsonCO_3', nan, 'FortCarsonCO_1', 'FortCarsonCO',
#        'FortCarsonCO_2'], dtype=object)

# %%
sept_2021_gdf.MovementType.unique()
# Out:
# array([1])

# %%
vehicle_ei_gdf = sept_2021_gdf.loc[(sept_2021_gdf['Mode']== 1) & (sept_2021_gdf['GeospatialType'] == 'EI')]

# %%
walking_ei_gdf = sept_2021_gdf.loc[(sept_2021_gdf['Mode']== 0) & (sept_2021_gdf['GeospatialType'] == 'EI')]

# %%
walking_sept_trips = walking_ei_gdf[['StartLocLat', 'StartLocLon', 'EndLocLat','EndLocLon', 'TripId', 'DeviceId', 'DestinationZoneName']].copy()
walking_sept_trips.to_csv('walking_sept_trips.csv')

# %%
sept_2021_gdf.groupby(by=['Mode', 'GeospatialType']).count()
# Out:
#                      TripId  DeviceId  ProviderId  StartDate  StartWDay  \
# Mode GeospatialType
# 0    EI                  35        35          35         35         35
#      IE                  29        29          29         29         29
#      II                4760      4760        4760       4760       4760
# 1    EI               83252     83252       83252      83252      83252
#      IE               83621     83621       83621      83621      83621
#      II              151927    151927      151927     151927     151927
#
#                      EndDate  EndWDay  StartLocLat  StartLocLon  EndLocLat  \
# Mode GeospatialType
# 0    EI                   35       35           35           35         35
#      IE                   29       29           29           29         29
#      II                 4760     4760         4760         4760       4760
# 1    EI                83252    83252        83252        83252      83252
#      IE                83621    83621        83621        83621      83621
#      II               151927   151927       151927       151927     151927
#
#                      ...  MST_start_second  MST_end_date  MST_end_month  \
# Mode GeospatialType  ...
# 0    EI              ...                35            35             35
#      IE              ...                29            29             29
#      II              ...              4760          4760           4760
# 1    EI              ...             83252         83252          83252
#      IE              ...             83621         83621          83621
#      II              ...            151927        151927         151927
#
#                      MST_end_day  MST_end_year  MST_end_time  MST_end_hour  \
# Mode GeospatialType
# 0    EI                       35            35            35            35
#      IE                       29            29            29            29
#      II                     4760          4760          4760          4760
# 1    EI                    83252         83252         83252         83252
#      IE                    83621         83621         83621         83621
#      II                   151927        151927        151927        151927
#
#                      MST_end_minute  MST_end_second  start_year_month
# Mode GeospatialType
# 0    EI                          35              35                35
#      IE                          29              29                29
#      II                        4760            4760              4760
# 1    EI                       83252           83252             83252
#      IE                       83621           83621             83621
#      II                      151927          151927            151927
#
# [6 rows x 50 columns]

# %%
vehicle_ei_gdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83252 entries, 6446 to 1154163
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TripId                  83252 non-null  object
#  1   DeviceId                83252 non-null  object
#  2   ProviderId              83252 non-null  object
#  3   Mode                    83252 non-null  int64
#  4   StartDate               83252 non-null  object
#  5   StartWDay               83252 non-null  int64
#  6   EndDate                 83252 non-null  object
#  7   EndWDay                 83252 non-null  int64
#  8   StartLocLat             83252 non-null  float64
#  9   StartLocLon             83252 non-null  float64
#  10  EndLocLat               83252 non-null  float64
#  11  EndLocLon               83252 non-null  float64
#  12  GeospatialType          83252 non-null  object
#  13  ProviderType            83252 non-null  int64
#  14  ProviderDrivingProfile  83252 non-null  int64
#  15  VehicleWeightClass      83252 non-null  int64
#  16  ProbeSourceType         83252 non-null  int64
#  17  OriginZoneName          0 non-null      object
#  18  DestinationZoneName     83252 non-null  object
#  19  EndpointType            83252 non-null  int64
#  20  TripMeanSpeedKph        83252 non-null  float64
#  21  TripMaxSpeedKph         83252 non-null  float64
#  22  TripDistanceMeters      83252 non-null  float64
#  23  MovementType            83252 non-null  int64
#  24  OriginCbg               0 non-null      float64
#  25  DestCbg                 0 non-null      float64
#  26  StartTimezone           83252 non-null  object
#  27  EndTimezone             83252 non-null  object
#  28  WaypointFreqSec         0 non-null      float64
#  29  StartQk                 83252 non-null  int64
#  30  EndQk                   83252 non-null  int64
#  31  Startlocation           83252 non-null  object
#  32  Endlocation             83252 non-null  object
#  33  MST_start_datetime      83252 non-null  datetime64[ns, MST]
#  34  MST_end_datetime        83252 non-null  datetime64[ns, MST]
#  35  MST_start_date          83252 non-null  object
#  36  MST_start_month         83252 non-null  int64
#  37  MST_start_day           83252 non-null  int64
#  38  MST_start_year          83252 non-null  int64
#  39  MST_start_time          83252 non-null  object
#  40  MST_start_hour          83252 non-null  int64
#  41  MST_start_minute        83252 non-null  int64
#  42  MST_start_second        83252 non-null  int64
#  43  MST_end_date            83252 non-null  object
#  44  MST_end_month           83252 non-null  int64
#  45  MST_end_day             83252 non-null  int64
#  46  MST_end_year            83252 non-null  int64
#  47  MST_end_time            83252 non-null  object
#  48  MST_end_hour            83252 non-null  int64
#  49  MST_end_minute          83252 non-null  int64
#  50  MST_end_second          83252 non-null  int64
#  51  start_year_month        83252 non-null  period[M]
# dtypes: datetime64[ns, MST](2), float64(10), int64(23), object(16), period[M](1)
# memory usage: 33.7+ MB

# %%
avrg_trips = vehicle_ei_gdf.groupby('DeviceId')['Startlocation'].count().mean()
avrg_trips
# Out:
# 2.1862394957983193

# %%
trip_duration = pd.to_datetime(vehicle_ei_gdf['MST_end_datetime'])-pd.to_datetime(vehicle_ei_gdf['MST_start_datetime'])

days, seconds = trip_duration.apply(lambda x:x.days), trip_duration.apply(lambda x:x.seconds)
hours = days * 24 + seconds // 3600

trip_duration_minutes = (pd.to_datetime(vehicle_ei_gdf['MST_end_datetime'])-pd.to_datetime(vehicle_ei_gdf['MST_start_datetime'])).apply(lambda x:x.seconds//60)

# %%
# %matplotlib inline
trip_duration_minutes = pd.DataFrame(trip_duration_minutes).rename(columns={0:'trips_minutes'})
trip_duration_minutes['GeospatialType'] = vehicle_ei_gdf['GeospatialType']

print('Trip duration for vehicles traveling into the Fort')
plt.figure(figsize=(15,6))
sns.boxplot(trip_duration_minutes['trips_minutes'],trip_duration_minutes['GeospatialType'],orient="h")
plt.xlabel('trip duration (minutes)')
# Out:
# Trip duration for vehicles traveling into the Fort
# Text(0.5, 0, 'trip duration (minutes)')

# %%
start.nlargest(100)
# Out:
# DeviceId
# 89e686a81e1169d803b189786c95fb09    76
# ba0c2a3b609dbbb28400f5bdb9c48f21    67
# a0ab80c245dd04ce5bdf98e93e93e817    59
# 4b30580de8d3b9d8681f9768d66ccf95    57
# 8a2e6ea518ab6b2356c0f04e0567cba0    56
#                                     ..
# 85be08a02545d5fafb5e95d5d3683cdf    40
# 95055234cab7c450f1c2f44111902e93    40
# b7bbbd7557eacbe2fd8cd234f4c06c9f    40
# dd4ffd1add1ba7978e0b4d35648b99b7    40
# e0b278b3347e74a9e7923efbbe2f70ba    40
# Name: Startlocation, Length: 100, dtype: int64

# %%
vehicle_ei_gdf = gpd.GeoDataFrame(trips_df)

sept_15_trips = df2[['StartLocLat', 'StartLocLon', 'EndLocLat','EndLocLon', 'TripId', 'DeviceId']].copy()

start_date = pd.to_datetime('2021-09-14').date()
end_date = pd.to_datetime('2021-09-16').date()

# Select DataFrame rows between two dates
mask = (vehicle_ei_gdf['MST_start_date'] > start_date) & (vehicle_ei_gdf['MST_start_date'] < end_date)
df2 = vehicle_ei_gdf.loc[mask]

# sept_15_trips.to_csv('inirix_ei_0915_2021.csv')

# vehicle_ei_gdf['point_start'] = list(zip(vehicle_ei_gdf.StartLocLat, vehicle_ei_gdf.StartLocLon))
# vehicle_ei_gdf['point_end'] = list(zip(vehicle_ei_gdf.EndLocLat, vehicle_ei_gdf.EndLocLon))
# vehicle_ei_gdf['start_end'] = list(zip(vehicle_ei_gdf['point_start'], vehicle_ei_gdf['point_end']))
# vehicle_ei_gdf.groupby(by = ['TripId'])['Startlocation'].count().mean()
# vehicle_ei_gdf.to_csv('inirix_ei_09_2021.csv')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 83252 entries, 6446 to 1154163
# Data columns (total 52 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   TripId                  83252 non-null  object
#  1   DeviceId                83252 non-null  object
#  2   ProviderId              83252 non-null  object
#  3   Mode                    83252 non-null  int64
#  4   StartDate               83252 non-null  object
#  5   StartWDay               83252 non-null  int64
#  6   EndDate                 83252 non-null  object
#  7   EndWDay                 83252 non-null  int64
#  8   StartLocLat             83252 non-null  float64
#  9   StartLocLon             83252 non-null  float64
#  10  EndLocLat               83252 non-null  float64
#  11  EndLocLon               83252 non-null  float64
#  12  GeospatialType          83252 non-null  object
#  13  ProviderType            83252 non-null  int64
#  14  ProviderDrivingProfile  83252 non-null  int64
#  15  VehicleWeightClass      83252 non-null  int64
#  16  ProbeSourceType         83252 non-null  int64
#  17  OriginZoneName          0 non-null      object
#  18  DestinationZoneName     83252 non-null  object
#  19  EndpointType            83252 non-null  int64
#  20  TripMeanSpeedKph        83252 non-null  float64
#  21  TripMaxSpeedKph         83252 non-null  float64
#  22  TripDistanceMeters      83252 non-null  float64
#  23  MovementType            83252 non-null  int64
#  24  OriginCbg               0 non-null      float64
#  25  DestCbg                 0 non-null      float64
#  26  StartTimezone           83252 non-null  object
#  27  EndTimezone             83252 non-null  object
#  28  WaypointFreqSec         0 non-null      float64
#  29  StartQk                 83252 non-null  int64
#  30  EndQk                   83252 non-null  int64
#  31  Startlocation           83252 non-null  object
#  32  Endlocation             83252 non-null  object
#  33  MST_start_datetime      83252 non-null  datetime64[ns, MST]
#  34  MST_end_datetime        83252 non-null  datetime64[ns, MST]
#  35  MST_start_date          83252 non-null  object
#  36  MST_start_month         83252 non-null  int64
#  37  MST_start_day           83252 non-null  int64
#  38  MST_start_year          83252 non-null  int64
#  39  MST_start_time          83252 non-null  object
#  40  MST_start_hour          83252 non-null  int64
#  41  MST_start_minute        83252 non-null  int64
#  42  MST_start_second        83252 non-null  int64
#  43  MST_end_date            83252 non-null  object
#  44  MST_end_month           83252 non-null  int64
#  45  MST_end_day             83252 non-null  int64
#  46  MST_end_year            83252 non-null  int64
#  47  MST_end_time            83252 non-null  object
#  48  MST_end_hour            83252 non-null  int64
#  49  MST_end_minute          83252 non-null  int64
#  50  MST_end_second          83252 non-null  int64
#  51  start_year_month        83252 non-null  period[M]
# dtypes: datetime64[ns, MST](2), float64(10), int64(23), object(16), period[M](1)
# memory usage: 35.7+ MB

# %%
vehicle_ei_gdf.groupby(by=['MST_start_date'])['TripId'].count().sort_values(ascending=False)
# Out:
# MST_start_date
# 2021-09-01    3645
# 2021-09-02    3606
# 2021-09-03    2105
# 2021-09-04    1557
# 2021-09-05    1407
# 2021-09-06    1506
# 2021-09-07    3471
# 2021-09-08    3484
# 2021-09-09    3368
# 2021-09-10    3500
# 2021-09-11    1745
# 2021-09-12    1447
# 2021-09-13    3295
# 2021-09-14    3081
# 2021-09-15    3671
# 2021-09-16    3544
# 2021-09-17    3365
# 2021-09-18    1823
# 2021-09-19    1413
# 2021-09-20    3282
# 2021-09-21    3360
# 2021-09-22    3089
# 2021-09-23    3297
# 2021-09-24    3333
# 2021-09-25    1541
# 2021-09-26    1393
# 2021-09-27    3122
# 2021-09-28    3340
# 2021-09-29    3334
# 2021-09-30    3128
# Name: TripId, dtype: int64

# %%
vehicle_ei_gdf.groupby(by=['MST_start_hour'])['TripId'].count().sort_values(ascending=False)
# Out:
# MST_start_hour
# 4     10702
# 7      8718
# 11     6854
# 5      6672
# 6      6423
# 8      4683
# 12     4114
# 14     4014
# 10     3852
# 16     3489
# 9      3326
# 13     3316
# 15     3172
# 17     3052
# 18     2782
# 19     2225
# 3      1848
# 20     1455
# 21      826
# 22      559
# 2       383
# 23      334
# 0       238
# 1       215
# Name: TripId, dtype: int64

# %% [markdown]
# ## Visualizing route for vehicles traveling to Fort Carson in September 2021

# %% [markdown]
# ### Start Point
# Note: the darker the color the more densely concentrated the area is
#
# <img src="Start3.png" width=600 height=600 />
# <img src="Start1.png" width=600 height=600 />
# <img src="Start2.png" width=600 height=600 />

# %% [markdown]
# ### Destination End Point
#
# <!-- # ![Destination](Destination.png) -->
#
# <img src="Destination.png" width=600 height=600 />

# %% [markdown]
# #### Route
#
# <img src="Route.png" width=600 height=600 />
# <img src="Route1.png" width=600 height=600 />
# <img src="Route2.png" width=600 height=600 />
# <img src="starttoend.png" width=600 height=600 />

# %% [markdown]
# #### Roads and Intersection near End point
#
# <img src="Deduction.png" width=600 height=600 />
#
# ##### Image of the road without end points to better visualize
# <img src="Deduction Road.png" width=600 height=600 />
#
# #### Based on the visualizations, we observe that some of the commonly traveled roads near Fort Carson include:
#
# - **S Academy Blvd**
# - Barkeley Ave
# - Tank Rd
# - Ellis St
# - Magrath Ave
# - Barkeley Ave
# - Specker Ave
# - Wetzel Ave
# - **115 Highway**
# - Ware St
# - Vietnam Veterans Memorial Hwy
# - Ronald Reagan Hwy

# %% [markdown]
# ### Roads and Intersections near starting point
#
# <img src="Deduction Start.png" width=600 height=600 />
# <img src="Deduction Start1.png" width=600 height=600 />
#
# #### Based on the visualizations, we focused on denser starting point areas and recorded the following commonly traveled on roads near the starting point:
#
# - Lake Ave
# - South Circle Dr
# - **S Union Blvd**
# - **E Fountain Blvd**
# - S Nevada Ave
# - **Hancock Expy**
# - **Monterey Road**
# - Monica Dr W
# - **S Academy blvd**
# - Martin Luther King Jr Expressway
# - Bradley Road
# - **Highway 85**
# - **Fountain Mesa Road**
# - C & S Road
# - Cross Creek Ave
# - Fountain Mesa Road
# - Bandley Dr
# - Mesa Ridge Pkwy
# - **S Powers Blvd**
# - **Interstate Highway**
# - **Colorado State Highway 21**
#
#
# Intersections:
# - Monterey Road & South Circle Dr
# - Monterey Road & S Union Blvd

# %% [markdown]
# <img src="startend1.png" width=600 height=600 />

# %% [markdown]
# #### Visualizations for people walking to Fort Carson on September 2021
#
# Note: There are only 35 data points of people walking to Fort Carson during the month of September 2021, suggesting insufficient data or that most people's preferred means of commuting is by driving
#
# <img src="Walking.png" width=600 height=600 />

# %% [markdown]
# ### Google Maps API

# %%
# convert lat and longitude to format acceptable for API call
vehicle_ei_gdf['point_start'] = vehicle_ei_gdf.StartLocLat.astype(str)+','+ vehicle_ei_gdf.StartLocLon.astype(str)
vehicle_ei_gdf['point_end'] = vehicle_ei_gdf.EndLocLat.astype(str)+','+ vehicle_ei_gdf.EndLocLon.astype(str)
origin_dest = zip(vehicle_ei_gdf['point_start'],vehicle_ei_gdf['point_end'])

# %%
import json
import googlemaps 
from datetime import datetime
import requests
from requests.exceptions import HTTPError
from html.parser import HTMLParser

# testing sample
origin = '38.66996,-104.68254'
destination = '38.74176, -104.79927'


url = 'https://maps.googleapis.com/maps/api/directions/json?origin='+origin+'&destination='+destination+'&mode=driving&key='+API_KEY
response = requests.get(url, headers=headers, data=payload)

json_data = json.loads(response.text)

# %%
json_data
# Out:
# {'geocoded_waypoints': [{'geocoder_status': 'OK',
#    'place_id': 'ChIJ3ZjbDhhrE4cRL6HrERwuYr4',
#    'types': ['premise']},
#   {'geocoder_status': 'OK',
#    'place_id': 'ChIJyeK4Tv9CE4cRGztycRMavm0',
#    'types': ['premise']}],
#  'routes': [{'bounds': {'northeast': {'lat': 38.7436247, 'lng': -104.6827892},
#     'southwest': {'lat': 38.6699324, 'lng': -104.7994533}},
#    'copyrights': 'Map data ©2022',
#    'legs': [{'distance': {'text': '10.9 mi', 'value': 17566},
#      'duration': {'text': '22 mins', 'value': 1335},
#      'end_address': '5925 Ware St, Colorado Springs, CO 80913, USA',
#      'end_location': {'lat': 38.7417498, 'lng': -104.7993203},
#      'start_address': '801 Marshall Dr, Fountain, CO 80817, USA',
#      'start_location': {'lat': 38.6699324, 'lng': -104.6827892},
#      'steps': [{'distance': {'text': '1.1 mi', 'value': 1714},
#        'duration': {'text': '2 mins', 'value': 135},
#        'end_location': {'lat': 38.68401950000001, 'lng': -104.6875575},
#        'html_instructions': 'Head <b>north</b> on <b>Jimmy Camp Rd</b> toward <b>Hayloft Ln</b>',
#        'polyline': {'points': 'av_kFlz|}RiALi@Xa@Xk@n@SRaCbDQZY^gBdCkBtCaArA]f@YZ_@\\{@h@kAXa@Bc@BaHHeCHaADs@D}@?oB@i@AkB@eBB]?yBBoDDkB@gA?wB@gA@qA?kB?'},
#        'start_location': {'lat': 38.6699324, 'lng': -104.6827892},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.9 mi', 'value': 1509},
#        'duration': {'text': '3 mins', 'value': 165},
#        'end_location': {'lat': 38.68308529999999, 'lng': -104.7045596},
#        'html_instructions': 'Turn <b>left</b> onto <b>E Ohio Ave</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'cnbkFfx}}RMA@v@?x@?^@fC@lE@nAD^@dD?P@jD?t@@h@B\\DTDPDRBHFNHRLVJPNXJPHNJTFPFRDJBJBNBTDf@@lCB`G@zF@`G@xB?jC@hC@xC?|D@fB?v@?^@P?\\?v@'},
#        'start_location': {'lat': 38.68401950000001, 'lng': -104.6875575},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.7 mi', 'value': 1165},
#        'duration': {'text': '2 mins', 'value': 110},
#        'end_location': {'lat': 38.6734014, 'lng': -104.708033},
#        'html_instructions': 'Turn <b>left</b> onto <b>S Santa Fe Ave</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'ihbkFnba~RpAAfAA`C?rDCbDAxAAjAB\\BN@RBTBHBB?D@H@JBHBRFZJjBn@j@RbA\\jA`@XJJLNJJDNF\\Lb@Nt@Th@PlAb@j@Tf@TLHFDNJFDBBNLJJJJHJLNDFFFJNDF?@FHJNFLP\\|@dB'},
#        'start_location': {'lat': 38.68308529999999, 'lng': -104.7045596},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '3.6 mi', 'value': 5812},
#        'duration': {'text': '4 mins', 'value': 212},
#        'end_location': {'lat': 38.7220048, 'lng': -104.7301419},
#        'html_instructions': 'Turn <b>right</b> to merge onto <b>I-25 N</b>',
#        'maneuver': 'ramp-right',
#        'polyline': {'points': 'wk`kFdxa~RA^@N?F?NARIXATYZYZCBUVORSRONONKJ_@^UT_@\\MJ[ZSTa@^EDIVQLUPOJOLOJOJg@\\SNOJOJOJmAz@yAdAEBsErCk@ZMFg@Ve@T_@P[LYLUJm@TOFYJc@NUJg@PWJQFk@RSHSFaA^c@Ni@Rk@RSHw@Xo@R}@Zc@N[Ly@Xi@Ro@Te@Pe@PWHi@Rc@Ni@R{@XSHe@Pm@ToAb@{@Zw@Xu@V[L]L{@ZqAd@qAb@aA\\QHg@Pg@R}@Zg@Pc@Nk@RMFcA\\}@\\m@Ri@PSHw@XYJUHQHQFUHg@Pi@Re@Pe@L[LSFi@Pc@LUD{EdAWDSBSDWDUBSDUBWDUDUDSBUDSBUBUDUBUDi@HUBUDSBWDUDWBSDUBWDUDSBUDUDUBUDSDUBOBWDUBUDQBYBSDUBUDUBUDUBUDUBSDSBUBUDSBSDUBSDUBSDUBQBUDUBUDUDWBUDk@HUDWDSBWDSDWDQBUDWDUBSDSBUDSBUDUBSDUBSDSBUDUBQDWBSDUBSDWDSBSDUDQBWDUDWFUDUDSDSFUFSFUFSDSFSFUHSFUFSFUHSDUHUFSHUFQFUFSHSFSFKBIBUHQFUFUHSFSFWHSFSFWJSDUHQFUHWFQFSFSHSFSFSFUHSFQFg@PsQzFy@VwAd@wDjAqC|@iIhCoC|@aA\\MFWJWHKFYJ_@Pq@Zu@^m@XeAn@k@\\UNID[R'},
#        'start_location': {'lat': 38.6734014, 'lng': -104.708033},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.2 mi', 'value': 397},
#        'duration': {'text': '1 min', 'value': 34},
#        'end_location': {'lat': 38.7251181, 'lng': -104.7323114},
#        'html_instructions': 'Take exit <b>132</b> for <b>CO-16</b>/<wbr/><b>Mesa Ridge Pkwy</b> toward <b>CO-21</b>/<wbr/><b>Ft Carson Gate 20</b>',
#        'maneuver': 'ramp-right',
#        'polyline': {'points': 'o{ikFjbf~RS?GBGDMH_@T_@T_Ah@SL]RA?A@i@VSJc@TWNE@i@XUNQHSJKFKHIDIHKJq@n@[Z[\\'},
#        'start_location': {'lat': 38.7220048, 'lng': -104.7301419},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.1 mi', 'value': 237},
#        'duration': {'text': '1 min', 'value': 39},
#        'end_location': {'lat': 38.7245017, 'lng': -104.7347426},
#        'html_instructions': 'Turn <b>left</b> onto <b>CO-16 W</b>/<wbr/><b>Mesa Ridge Pkwy</b>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': '_ojkF|of~R]`@HTNh@Pr@Tx@XfALf@Pp@FVFXL`A'},
#        'start_location': {'lat': 38.7251181, 'lng': -104.7323114},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.8 mi', 'value': 1221},
#        'duration': {'text': '2 mins', 'value': 139},
#        'end_location': {'lat': 38.7257722, 'lng': -104.7485271},
#        'html_instructions': 'Keep <b>right</b> to continue on <b>Magrath Ave</b><div style="font-size:0.9em">Partial restricted usage road</div>',
#        'maneuver': 'keep-right',
#        'polyline': {'points': 'ckjkFb_g~R@N@`@?D?XCr@CTEXALCRCLABEPmAhFKh@Kl@OfAOv@WvAI^a@|BE\\El@AZ?n@?t@?HAp@]bJ?d@?P@hA@hBD^BrC?`@B|A@zB@x@@~AAlJ'},
#        'start_location': {'lat': 38.7245017, 'lng': -104.7347426},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.2 mi', 'value': 279},
#        'duration': {'text': '1 min', 'value': 19},
#        'end_location': {'lat': 38.7251817, 'lng': -104.7516042},
#        'html_instructions': 'Keep <b>left</b> to continue on <b>Specker Ave</b><div style="font-size:0.9em">Restricted usage road</div>',
#        'maneuver': 'keep-left',
#        'polyline': {'points': 'asjkFhui~RAtA@hA@j@Dd@LdA~AlH'},
#        'start_location': {'lat': 38.7257722, 'lng': -104.7485271},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '2.7 mi', 'value': 4287},
#        'duration': {'text': '6 mins', 'value': 356},
#        'end_location': {'lat': 38.7436247, 'lng': -104.7912775},
#        'html_instructions': 'Continue straight to stay on <b>Specker Ave</b><div style="font-size:0.9em">Partial restricted usage road</div>',
#        'maneuver': 'straight',
#        'polyline': {'points': 'kojkFnhj~RJ|@L|@RdCFvA@nBErB?DCh@MpAWtBERa@jBGT]pAY`AU`AIb@q@bDo@fEKn@UjB[`CMjAU|BKx@Ix@AVQhCKjBGxAOdDC~@GzBArE?tDBj@@nC?R@hC@n@?jAGpBUlBWtAKXQl@]bAGH}@hBQJEDA?}BnE}DxHsCtEgDpFmDpFu@fA}BbDmAdBWZKNaBxBQVuAdBiDfEYZo@v@iBrBcAhAeAhAaAdAeAfAKLEDs@v@}A`BwBrBg@h@MHmCfCuBfB_Av@a@\\_Av@UN]ZWTaBrAaAr@eAt@u@j@UR'},
#        'start_location': {'lat': 38.7251817, 'lng': -104.7516042},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.5 mi', 'value': 740},
#        'duration': {'text': '2 mins', 'value': 92},
#        'end_location': {'lat': 38.7401136, 'lng': -104.7985277},
#        'html_instructions': 'Turn <b>left</b> onto <b>Nelson Blvd</b><div style="font-size:0.9em">Restricted usage road</div>',
#        'maneuver': 'turn-left',
#        'polyline': {'points': 'sbnkFn`r~RVr@N^n@`BhAtCv@nB`AdClBzEt@pBv@tBx@xBRh@\\z@xAbE'},
#        'start_location': {'lat': 38.7436247, 'lng': -104.7912775},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '0.1 mi', 'value': 175},
#        'duration': {'text': '1 min', 'value': 25},
#        'end_location': {'lat': 38.7415161, 'lng': -104.7994533},
#        'html_instructions': 'Turn <b>right</b> onto <b>Ware St</b><div style="font-size:0.9em">Restricted usage road</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'ulmkFxms~ReDjBsBjA'},
#        'start_location': {'lat': 38.7401136, 'lng': -104.7985277},
#        'travel_mode': 'DRIVING'},
#       {'distance': {'text': '98 ft', 'value': 30},
#        'duration': {'text': '1 min', 'value': 9},
#        'end_location': {'lat': 38.7417498, 'lng': -104.7993203},
#        'html_instructions': 'Turn <b>right</b> onto <b>Falaise Gap Rd</b><div style="font-size:0.9em">Restricted usage road</div><div style="font-size:0.9em">Destination will be on the right</div>',
#        'maneuver': 'turn-right',
#        'polyline': {'points': 'oumkFpss~RIKEECAECGCA?C?C@A?'},
#        'start_location': {'lat': 38.7415161, 'lng': -104.7994533},
#        'travel_mode': 'DRIVING'}],
#      'traffic_speed_entry': [],
#      'via_waypoint': []}],
#    'overview_polyline': {'points': 'av_kFlz|}RiALi@Xa@Xk@n@uCvDk@z@gBdCkBtC_BzBy@x@{@h@kAXeAFaHHeCHuBJmD@i@AkB@cCBiHHsD@}JBMA@v@?xABtIFnBBxKDfAJf@Z`At@tAd@jAP|@Df@@lCD|NDpSBvN@fCnMG|FChBFbAL^FdDfAtE~AZXZL`DdAxBx@t@^b@Zp@p@`ArAXj@|@dBA^@VAb@Kn@s@v@}@bAkDfD{@z@IVQLe@\\wAbAcAr@gD`CyEvCgCpAkBx@{Bx@}FvBwIzC{TbIoVzIiQjGwBl@sFjAg@HwARwATaEj@qDh@uInAsInAcUhDkDh@kDp@oIbCqSrG}[dK{MfEqEzAiAd@aDxAsBhAaAl@e@X[BuAz@sBjAaEvB}@f@qAjAw@x@]`@HT`@|AnAzENp@NpA@f@ClAOpAyAlGw@vEiArGGhA?dBAz@]hK@zA@hBD^BtDDxEBxCCbMBtBRjB~AlHJ|@L|@RdCFvA@nBExBQzB]hCi@`Cw@rC_@dBq@bDo@fEa@zCi@lEm@hG]tFW~FKzDAhKFxI@zBGpBUlBc@nBo@pBeArBWP_CnE}DxHsCtEuIbNsDjFsEjGgB|BcEbFcH~HyC`DqCxC_D|C{CpCuD~CuC`CyBhBgChBkA~@f@rArFlNtG|Pp@dBxAbEeDjBsBjAIKEESII@'},
#    'summary': 'I-25 N and Specker Ave',
#    'warnings': [],
#    'waypoint_order': []}],
#  'status': 'OK'}

# %%
# to sleep 
import time

# store formatted start and end coordinates for running snap to road API
start_coord = []
end_coord = []
# to store starting and ending coordinate address
start_address = []
end_address = []

def remove_html_tags(text):
    """Remove html tags from a string"""
    import re
    clean = re.compile('<.*?>')
    return re.sub(clean, '', str(text))
            
# parse json data obtained from directions api to retrive lattitude and longitude 
def get_route_info(json_data):
    start_text = ''
    end_text = ''
    l = json_data['routes'][0]['legs']
    for leg in l:
        startAddress = leg['start_address']
        start_address.append(startAddress)
        endAddress = leg['end_address']
        end_address.append(endAddress)
        for step in leg['steps']:
            start_location = step['start_location']
            start_text += str(start_location['lat']) + ','
            start_text += str(start_location['lng']) + '|'
            start = ''.join(start_text)
            start_clean = re.sub(r".$", "", start)
            end_location = step['end_location']
            end_text += str(end_location['lat']) + ','
            end_text += str(end_location['lng']) + '|'
            end = ''.join(end_text)
            end_clean = re.sub(r".$", "", end)
#             start_loc.append(start_location)
#             end_loc.append(end_location)
        start_coord.append(start_clean)
        end_coord.append(end_clean)
        
# get route information from directions api  
def get_api_data(start_end):
    for i in start_end:
        origin = i[0]
        destination = i[1]
        url = 'https://maps.googleapis.com/maps/api/directions/json?origin='+origin+'&destination='+destination+'&mode=driving&key='+API_KEY
        response = requests.get(url, headers=headers, data=payload, timeout=10)
        if response.status_code == 200:
            json_data = json.loads(response.text)
            # parse json data retrieved from route API 
            get_route_info(json_data)
            time.sleep(0.1)
        else:
            print(response.status_code)
            break

# %%
# retrive route data by feeding starting lat/long and ending lat/long to route API 
get_api_data(origin_dest)

# %%
# number of coordinates retrieved
len(end_coord)
# Out:
# 6285

# %%
placeid = get_place_api(end_coord)

# %%
# number of placeid retrived from calling road api
len(placeid)
# Out:
# 80345

# %%
# retrieve address from place api by feeding placeid obtained from road api
address = get_address(placeid)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-911-105be881d2a6> in <module>
#       1 # retrieve address from place api by feeding placeid obtained from road api
# ----> 2 get_address(placeid)
#
# <ipython-input-779-01004f3ca401> in get_address(place_id)
#       5         payload={}
#       6         headers = {}
# ----> 7         response = requests.get(place_url, headers=headers, data=payload, timeout=10)
#       8         if response.status_code == 200:
#       9             place_data = response.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     437         try:
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#     441                     url=url,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     697
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#     701                 method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     380         # Trigger any extra validation we need to do.
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#     384             # Py2 raises this as a BaseSSLError, Py3 raises it as socket timeout.
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1008         # Force connect early to allow us to validate the connection.
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#    1012         if not conn.is_verified:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     409             context.load_default_certs()
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#     413             keyfile=self.key_file,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     426
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#     430         )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     470
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#     474         return ssl_context.wrap_socket(sock)
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     498         # SSLSocket class handles server_hostname encoding before it calls
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#     502             server_side=server_side,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1038                         # non-blocking
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#    1042                 self.close()
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1307             if timeout == 0.0 and block:
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#    1311             self.settimeout(timeout)
#
# KeyboardInterrupt:

# %%
word_counts = Counter(route)

# %%
word_counts
# Out:
# Counter({'Head north on Jimmy Camp Rd toward Hayloft Ln': 1,
#          'Turn left onto E Ohio Ave': 92,
#          'Turn left onto S Santa Fe Ave': 111,
#          'Turn right to merge onto I-25 N': 153,
#          'Take exit 132 for CO-16/Mesa Ridge Pkwy toward CO-21/Ft Carson Gate 20': 181,
#          'Turn left onto CO-16 W/Mesa Ridge Pkwy': 181,
#          'Keep right to continue on Magrath AvePartial restricted usage road': 864,
#          'Keep left to continue on Specker AveRestricted usage road': 747,
#          'Continue straight to stay on Specker AvePartial restricted usage road': 155,
#          'Turn left onto Nelson BlvdRestricted usage road': 51,
#          'Turn right onto Ware StRestricted usage road': 5,
#          'Turn right onto Falaise Gap RdRestricted usage roadDestination will be on the right': 5,
#          'Head west on Witcher Dr toward Skuna Dr': 2,
#          'Turn right at the 1st cross street onto Skuna Dr': 2,
#          'Turn left at the 1st cross street': 11,
#          'Continue onto Lorson Blvd': 6,
#          'Turn left onto S Marksheffel Rd': 31,
#          'Turn right onto Mesa Ridge Pkwy': 62,
#          'Turn left onto CO-16 W': 221,
#          'Continue straight to stay on Specker AveRestricted usage road': 525,
#          'Turn left onto Ardennes StRestricted usage road': 99,
#          'Continue straightRestricted usage road': 44,
#          'Turn leftRestricted usage roadDestination will be on the left': 164,
#          'Head south on Lodi Ln toward Concoran Ln': 1,
#          'Turn left onto Concoran Ln': 1,
#          "Turn left at the 1st cross street onto Fountain Mesa RdPass by Culver's (on the right)": 3,
#          'Keep right to stay on Fountain Mesa RdPass by Chick-fil-A (on the right)': 115,
#          'Turn left onto Titus BlvdRestricted usage road': 505,
#          'Turn left onto Bad Toelz RdRestricted usage road': 26,
#          'Turn rightRestricted usage road': 367,
#          'Turn leftRestricted usage road': 407,
#          'Head south on Anthem Pl toward Lindamood Dr': 1,
#          'Turn left onto Lindamood Dr': 1,
#          'Turn left at the 1st cross street onto Legend Oak Dr': 2,
#          'Turn left at the 1st cross street onto C &amp; S Rd': 4,
#          "Turn right onto Fountain Mesa RdPass by Culver's (on the right in 0.6&nbsp;mi)": 49,
#          'At the traffic circle, take the 2nd exit and stay on Titus BlvdRestricted usage road': 128,
#          'Turn right onto Harr AveRestricted usage road': 79,
#          'Turn left onto Okinawa DrRestricted usage road': 4,
#          'Head west': 47,
#          'Turn left': 380,
#          'Turn left toward CO-16 W': 16,
#          'Turn right onto Bastogne DrRestricted usage roadDestination will be on the right': 3,
#          'Head south toward Pikes Peak Ave': 2,
#          'Turn right onto Pikes Peak Ave': 9,
#          'Continue onto E Colorado Ave': 2,
#          'Turn left onto S Nevada Ave': 55,
#          'Continue straight to stay on S Nevada Ave': 33,
#          'Continue straight onto CO-115 S/S Nevada AveContinue to follow CO-115 S': 366,
#          'Turn left onto Nelson BlvdPartial restricted usage road': 658,
#          'Nelson Blvd turns slightly right and becomes Harr AveRestricted usage road': 662,
#          'Turn left onto Marne Ct.Restricted usage road': 7,
#          'Head east on Petrified Forest Trail toward Lizard Rock Trail': 1,
#          'Turn right onto Lizard Rock Trail': 1,
#          'Turn right at the 1st cross street onto Happy Meadows Trail': 1,
#          'Turn right onto Grand Cordera Pkwy': 4,
#          'Turn left onto Briargate PkwyPass by Wells Fargo Bank (on the right in 0.3&nbsp;mi)': 6,
#          'Keep left at the fork, follow signs for I-25 S/Pueblo and merge onto I-25 S': 66,
#          'Take exit 135 for Academy Blvd toward Airport': 255,
#          'Keep right at the fork, follow signs for Pikes Peak Community College/Fort Carson and merge onto S Academy Blvd': 256,
#          'Take the exit toward B Street': 626,
#          'Turn left onto Magrath AvePartial restricted usage road': 627,
#          'Continue onto Barkeley AveRestricted usage road': 699,
#          'Turn left onto Hogan StRestricted usage road': 29,
#          'Turn right at Porter St': 16,
#          'Turn rightDestination will be on the left': 160,
#          'Head south on Horizonview Dr toward Anvil Dr': 2,
#          'Turn right onto Bradley Rd': 77,
#          'Slight left to stay on Bradley Rd': 53,
#          'Merge onto CO-21 S': 56,
#          'Continue onto CO-16 W': 117,
#          'Turn left onto Tank RdRestricted usage road': 6,
#          'Turn leftRestricted usage roadDestination will be on the right': 133,
#          'Head north on Hybrook Rd S toward Weaverville Rd': 1,
#          "Turn right onto US-24 E/W Hwy 24Pass by O'Reilly Auto Parts (on the right in 6.5&nbsp;mi)": 1,
#          'Continue straight onto US-24 E/W Cimarron St': 51,
#          'Slight right onto the Interstate 25 S/U.S. 24 E ramp': 63,
#          'Merge onto I-25 S/US-24 E': 28,
#          'Take exit 140 for Tejon St': 230,
#          'Turn right onto S Nevada Ave': 277,
#          'Turn left onto Sheridan AveRestricted usage road': 332,
#          'Turn left onto Prussman BlvdRestricted usage road': 182,
#          'Turn right': 423,
#          'Head north on Prestige Point toward Mountain Crest ViewRestricted usage road': 3,
#          'Turn right onto Pebble Ridge CirRestricted usage road': 3,
#          'Turn right at the 1st cross street onto Westmeadow DrPartial restricted usage road': 5,
#          'Continue onto Chiles AveRestricted usage road': 199,
#          'Turn right onto Funk AveRestricted usage road': 181,
#          'Turn left onto Harr AveRestricted usage road': 139,
#          'Turn right onto Chiles AveRestricted usage road': 121,
#          "Turn left onto O'Connell BlvdRestricted usage roadDestination will be on the left": 1,
#          'Head south': 42,
#          'Turn right toward Old Ranch Rd': 1,
#          'Turn left toward Old Ranch RdRestricted usage road': 1,
#          'Turn right onto Old Ranch Rd': 1,
#          'Turn left onto Voyager Pkwy': 25,
#          'Turn right onto Briargate Pkwy': 34,
#          'Turn left onto Cochrane CirRestricted usage road': 115,
#          'Turn rightRestricted usage roadDestination will be on the right': 269,
#          'Head north': 41,
#          'Turn left toward Trojan Pt': 11,
#          'Continue onto Trojan Pt': 19,
#          'Turn right onto Jimmy Camp Rd': 60,
#          'Turn right onto Sheridan AveRestricted usage roadDestination will be on the right': 5,
#          'Head east on Hanham Dr toward Herd St': 2,
#          'Hanham Dr turns left and becomes Herd St': 2,
#          'Turn right onto Gilpin Ave': 2,
#          'Turn right onto Flintshire St': 8,
#          'Turn left onto Monterey Rd': 13,
#          'Turn right onto S Circle Dr': 32,
#          'Continue onto Lake Ave': 99,
#          'Turn left to merge onto I-25 S toward Pueblo': 62,
#          'Take exit 132B toward Ft Carson Gate 20': 284,
#          'Merge onto Magrath AvePartial restricted usage road': 278,
#          'Head north on Becket Dr toward Wembleton Pl': 1,
#          'Turn left onto Wycliffe Dr': 1,
#          'Turn right onto Star Ranch Rd': 10,
#          'Turn right onto CO-115 S': 34,
#          'Turn left onto Martinez StRestricted usage road': 65,
#          'Turn right onto Nelson BlvdRestricted usage roadDestination will be on the right': 8,
#          'Head south on Fortman Terrace toward Fortman Ave': 1,
#          'Turn left onto Fortman Ave': 1,
#          'Turn right at the 1st cross street onto Medicine Bow Ave': 1,
#          'Continue onto Grand Valley Dr': 3,
#          'Turn right onto Sneffels St': 8,
#          'Turn right onto CO-16 W': 73,
#          'Turn right onto Manhart StRestricted usage roadDestination will be on the left': 1,
#          'Head southwest on Harvest Moon Rd toward Fountain Mesa Rd': 2,
#          'Turn right onto Fountain Mesa Rd': 43,
#          'Turn left onto Comanche Village Dr': 46,
#          'Turn right onto N Santa Fe Ave': 52,
#          'Turn left to merge onto CO-16 W toward Ft Carson/I-25': 87,
#          'Continue straight to stay on Specker AveRestricted usage roadDestination will be on the left': 15,
#          'Turn right toward Broadmoor Bluffs Dr': 26,
#          'Turn left toward Broadmoor Bluffs Dr': 14,
#          'Turn left onto Broadmoor Bluffs Dr': 40,
#          'Turn left onto S Academy Blvd': 175,
#          'Turn right to merge onto CO-115 S toward Cañon City S': 57,
#          'Continue straight to stay on CO-115 S': 259,
#          'Turn left onto Wilderness RdRestricted usage road': 183,
#          'Turn right onto Warfighter RdRestricted usage roadDestination will be on the left': 24,
#          'Head west on CO-16 W': 13,
#          'Keep left to continue on Butts RdRestricted usage road': 151,
#          'At the traffic circle, take the 2nd exit and stay on Butts RdRestricted usage road': 45,
#          'Turn right onto Warfighter RdRestricted usage road': 86,
#          'Head north on Jet Wing Dr toward Astrozon Blvd': 3,
#          'Turn left onto Astrozon Blvd': 6,
#          'Turn left onto S Academy BlvdPass by Burger King (on the right in 0.2&nbsp;mi)': 32,
#          'Continue onto S Academy Blvd': 498,
#          'Turn right onto Prussman BlvdRestricted usage road': 66,
#          'Turn rightRestricted usage roadDestination will be on the left': 135,
#          'Head southwest on Larch Dr toward Security Blvd': 1,
#          'Turn left onto Security Blvd': 21,
#          'Turn right onto Main St': 24,
#          'Turn left onto CanAm HwyPass by Jack in the Box (on the right in 0.9&nbsp;mi)': 17,
#          'Turn right to merge onto CO-16 W toward Ft Carson/I-25': 156,
#          'Turn right to stay on Ardennes StRestricted usage road': 47,
#          'Head southeast toward Suffolk StRestricted usage road': 2,
#          'Turn left onto Suffolk StRestricted usage road': 2,
#          'Turn left onto Stewart AvePartial restricted usage road': 5,
#          'Continue straight': 93,
#          'Turn left onto Airport Rd': 16,
#          'Turn left onto CO-21 S/US-24 W': 13,
#          'Continue onto CO-21 S': 172,
#          'Continue straight to stay on CO-21 S': 223,
#          'Turn right onto Milton E Proby Pkwy': 207,
#          'Keep left, follow signs for Academy Blvd South': 232,
#          'Take the SH-115 exit on the left': 300,
#          'Merge onto CO-115 S': 302,
#          'Turn left onto Cochrane CirRestricted usage roadDestination will be on the right': 15,
#          'Head north on Vinewood Ln toward S Pueblo Blvd': 1,
#          'Turn right at the 1st cross street onto W Pueblo Blvd': 1,
#          'Turn left to merge onto I-25 N toward Colo Spgs': 4,
#          'Turn left onto Bad Toelz RdRestricted usage roadDestination will be on the left': 6,
#          'Head south toward E St Elmo Ave': 1,
#          'Turn left onto E St Elmo Ave': 5,
#          'Slight left to stay on E St Elmo Ave': 1,
#          'Turn left onto E Cheyenne Rd': 2,
#          'Continue onto Venetucci Blvd': 4,
#          'Slight right toward B St': 40,
#          'Continue onto B St': 43,
#          'Continue onto Magrath AvePartial restricted usage road': 89,
#          "Keep right to continue toward O'Connell BlvdRestricted usage road": 317,
#          "Slight right onto O'Connell BlvdRestricted usage road": 297,
#          'Turn right onto Specker AveRestricted usage roadDestination will be on the right': 4,
#          'Head west on Baptist Rd toward Wildhaven Ln': 2,
#          'Turn left to merge onto I-25 S': 143,
#          'Turn left onto Wilderness RdRestricted usage roadDestination will be on the right': 17,
#          'Head northwest on Arlington Dr toward Shasta Dr': 1,
#          'Turn left onto Shasta Dr': 1,
#          'Turn right onto Monterey Rd': 9,
#          'Turn left onto S Circle Dr': 23,
#          'Turn right onto Ellis StRestricted usage road': 62,
#          'Turn leftDestination will be on the right': 76,
#          'Head west on Old Glory Dr toward Journey Dr': 3,
#          'Turn right onto Fontaine Blvd': 100,
#          'Turn left onto CO-21 S': 86,
#          'Keep left at the fork, follow signs for Arapahoe Road West/S.Alton Way/Boston Street': 1,
#          'Turn left onto E Arapahoe Rd': 1,
#          'Merge onto I-25 S via the ramp to Arapahoe Rd': 1,
#          'Keep left to stay on I-25 S': 42,
#          'Nelson Blvd turns slightly right and becomes Harr AveRestricted usage roadDestination will be on the left': 6,
#          'Head east on E Moreno Ave toward S Tejon St': 2,
#          'Slight left to stay on Wilderness RdRestricted usage road': 60,
#          'At the traffic circle, take the 1st exit onto Butts RdRestricted usage road': 57,
#          'Head southwest on Sandalwood DrRestricted usage road': 1,
#          'Turn left to stay on Sandalwood DrRestricted usage road': 1,
#          'Turn right onto Michelle CtRestricted usage road': 1,
#          'Turn left to stay on Michelle CtRestricted usage road': 3,
#          'Turn right at the 1st cross street onto S Murray Blvd': 20,
#          'Turn right onto Chelton Rd': 38,
#          'Turn left onto S Academy BlvdPass by Burger King (on the right in 0.8&nbsp;mi)': 32,
#          'Continue onto Airfield RdRestricted usage road': 53,
#          'At the traffic circle, take the 1st exit onto Son Tay RdRestricted usage roadDestination will be on the left': 21,
#          'Head south toward Meadow Peak ViewRestricted usage road': 7,
#          'Turn right onto Meadow Peak ViewRestricted usage road': 13,
#          'Turn left onto Westmeadow DrPartial restricted usage road': 142,
#          'Turn left onto Ellis StRestricted usage roadDestination will be on the left': 13,
#          'Head west on Falcons Hood Point': 2,
#          'Turn left to stay on Falcons Hood Point': 2,
#          'Turn right onto Hawkbill View': 2,
#          'Turn right at the 1st cross street onto Desert Varnish Dr': 2,
#          'Turn right at the 1st cross street onto Barnes Rd': 2,
#          'Turn right onto Marksheffel Rd': 29,
#          'Head west on Walmart Hts toward Venetucci Blvd': 40,
#          'Turn left at the 1st cross street onto Venetucci Blvd': 53,
#          'Turn right onto S Academy Blvd': 197,
#          'Turn right toward S Academy Blvd': 2,
#          'Turn right onto S Academy BlvdPass by Burger King (on the right in 1.7&nbsp;mi)': 1,
#          'Turn left onto Chiles AveRestricted usage road': 63,
#          'Turn right onto Nelson BlvdRestricted usage road': 100,
#          'At the traffic circle, take the 1st exit onto Harr AveRestricted usage road': 44,
#          'Turn left onto Normandy RdRestricted usage roadDestination will be on the left': 5,
#          'Head east on Countryside Grove toward Wells Point': 2,
#          'Turn left onto Jimmy Camp Rd': 23,
#          'Head south on Elm Grove Dr toward Leta DrRestricted usage road': 1,
#          'Elm Grove Dr turns slightly right and becomes Leta Dr': 1,
#          'Turn left onto Bradley Rd': 12,
#          'At the traffic circle, take the 2nd exit and stay on Bradley Rd': 42,
#          'Turn right onto the ramp to I-25': 47,
#          'Merge onto S Academy Blvd': 106,
#          'Turn left onto Pershing DrRestricted usage road': 23,
#          'Head south toward E Cheyenne Mountain Blvd': 2,
#          'Turn left toward E Cheyenne Mountain Blvd': 34,
#          'Turn left at the 1st cross street onto E Cheyenne Mountain Blvd': 12,
#          'Head east on E Colorado Ave toward S Tejon St': 3,
#          'Turn right onto St Lo DrRestricted usage roadDestination will be on the right': 4,
#          'Head north on E Pine Loop toward Pine DrRestricted usage road': 1,
#          'Turn right onto Pine DrRestricted usage road': 11,
#          'Turn right onto S Gate BlvdPartial restricted usage road': 13,
#          'Take the ramp onto I-25 S': 68,
#          'Head southeast on Traders Pkwy toward Calista Wy': 1,
#          'Turn right onto Calista Wy': 1,
#          'Turn right onto Primavera Ln': 4,
#          'Turn left onto Hidden Pr Pkwy': 19,
#          'Turn right onto Old Pueblo Rd': 46,
#          'Old Pueblo Rd turns slightly right and becomes S Main St': 48,
#          'Turn left onto W Illinois Ave': 49,
#          'Turn left at the 2nd cross street onto S Santa Fe Ave': 49,
#          'Turn left onto Charter Oak Ranch Rd': 38,
#          'Continue straight onto Eassayons RdRestricted usage road': 38,
#          'Eassayons Rd turns slightly left and becomes Military Reservation Boundary RdRestricted usage road': 35,
#          'Continue onto Butts RdRestricted usage road': 23,
#          'At the traffic circle, take the 3rd exit onto Wilderness RdRestricted usage road': 10,
#          'Turn left onto Warfighter RdRestricted usage road': 37,
#          'Turn leftDestination will be on the left': 111,
#          'Head northeast toward Cheyenne Meadows Rd': 10,
#          'Turn left onto Cheyenne Meadows Rd': 62,
#          'Turn right onto Westmeadow DrPartial restricted usage road': 16,
#          'Head east on Springlake Cir E toward W Cheyenne Mountain Blvd': 1,
#          'Turn right at the 1st cross street onto W Cheyenne Mountain Blvd': 1,
#          'At the traffic circle, take the 2nd exit onto E Cheyenne Mountain Blvd': 9,
#          'Turn right onto Okinawa DrRestricted usage road': 3,
#          'Head south on Piros Dr toward Lonsdale Dr': 3,
#          'Turn right onto Peterson Rd': 10,
#          'Turn right onto Palmer Park Blvd': 16,
#          'Continue onto CO-21 S/US-24 W': 153,
#          'Turn left onto Wetzel AveRestricted usage road': 76,
#          'Turn left onto Evans StRestricted usage roadDestination will be on the right': 6,
#          'Head north on Kearsarge Dr toward Thunderbolt Trail': 1,
#          'Turn right onto Declaration Dr': 2,
#          'Turn left at the 2nd cross street onto Old Glory Dr': 3,
#          'Turn left at the 1st cross street onto Fontaine Blvd': 9,
#          'Slight left': 94,
#          'Head west toward Stewart AveRestricted usage road': 2,
#          'Turn right onto Stewart AvePartial restricted usage road': 3,
#          'At the traffic circle, take the 1st exit and stay on Stewart AvePartial restricted usage road': 1,
#          'Take the Westmeadow Dr exit toward Ft Carson': 118,
#          'Turn left onto Westmeadow Dr': 22,
#          'Turn left onto the rampDestination will be on the right': 2,
#          'Head southwest toward Southmoor DrRestricted usage road': 1,
#          'Turn left onto Southmoor DrParts of this road may be closed at certain times or days': 1,
#          'Turn left onto Carson Blvd': 2,
#          'Turn right onto CanAm Hwy': 35,
#          'Slight right to stay on Magrath AveRestricted usage road': 357,
#          'Turn right onto Womack St': 37,
#          'Turn left onto Minick Ave': 35,
#          'Turn right to stay on Minick Ave': 32,
#          'Continue straight onto Marauder WyDestination will be on the left': 8,
#          'Head north on Yocona Dr toward Witcher Dr': 1,
#          'Turn left onto Witcher Dr': 1,
#          'Witcher Dr turns left and becomes Volga Dr': 1,
#          'Turn right onto Magothy Dr': 1,
#          'Turn right at Trappe Dr': 1,
#          'Turn left at the 1st cross street onto Lorson Blvd': 5,
#          "Turn right onto O'Connell BlvdRestricted usage road": 27,
#          'Head west on S Circle Dr': 3,
#          'Head northwest': 17,
#          'Turn left toward Airport Rd': 1,
#          'Turn left at the 1st cross street onto S Academy BlvdPass by Burger King (on the right in 2.2&nbsp;mi)': 1,
#          'Turn left onto Wallace StRestricted usage road': 14,
#          'Head south on Venetucci Blvd toward S Academy Blvd': 8,
#          "Slight right onto O'Connell BlvdRestricted usage roadDestination will be on the right": 20,
#          'Head southwest on Co Rd 22/Rampart Range Rd toward Forest Srv RdContinue to follow Co Rd 22': 1,
#          'Continue onto N Baldwin St': 2,
#          'Turn left onto US-24 E/W Hwy 24': 4,
#          'Turn left onto Woodfill RdRestricted usage road': 31,
#          'Turn left onto St Lo DrRestricted usage road': 3,
#          'Turn left onto St Lo CirRestricted usage roadDestination will be on the right': 2,
#          'Head southeast on N Academy Blvd toward Jamboree DrPass by IHOP (on the left)': 2,
#          'Take the Woodmen Road W ramp': 3,
#          "Merge onto E Woodmen RdPass by Carl's Jr (on the right in 0.4&nbsp;mi)": 3,
#          'Continue onto Barkeley AveRestricted usage roadDestination will be on the left': 16,
#          'Head southwest toward Geyser Dr': 9,
#          'Turn right onto Geyser Dr': 9,
#          'Turn left onto E Cheyenne Mountain Blvd': 26,
#          'Turn left onto Venetucci Blvd': 127,
#          "Turn left onto O'Connell BlvdRestricted usage road": 106,
#          'Turn left onto Abbot StRestricted usage road': 9,
#          'Head southwest': 81,
#          'Continue onto Walmart Hts': 4,
#          'Turn left at Sam Houston LoopRestricted usage road': 17,
#          'Turn left onto Bastogne DrRestricted usage roadDestination will be on the left': 13,
#          'Head north toward Citadel Dr E': 3,
#          'Turn left toward Citadel Dr E': 10,
#          'Turn right toward Citadel Dr E': 7,
#          'Turn right onto Citadel Dr E': 3,
#          'Turn right onto Citadel Dr N': 5,
#          'Turn right onto N Academy BlvdPass by Burger King (on the right in 3.6&nbsp;mi)': 5,
#          'Turn left at the 1st cross street onto Magrath AveRestricted usage road': 13,
#          'Head southwest on Ouray Ave toward Southgate RdRestricted usage road': 2,
#          'Turn right onto Southgate Rd': 5,
#          'Turn left onto Ellis StRestricted usage roadDestination will be on the right': 5,
#          'Head southwest on Shenandoah Dr toward Olympic Dr': 3,
#          'Head northwest toward Pinion DrRestricted usage road': 1,
#          'Turn left onto Pinion DrRestricted usage road': 1,
#          'Turn left onto Pine DrRestricted usage road': 2,
#          'Turn right onto Bastogne DrRestricted usage road': 1,
#          'Turn left to stay on Bastogne DrRestricted usage road': 1,
#          'Turn right onto Leyte CtRestricted usage roadDestination will be on the left': 1,
#          'Head southwest toward Wycliffe Dr': 3,
#          'Turn right onto Wycliffe Dr': 5,
#          'At the traffic circle, take the 3rd exit onto Titus BlvdRestricted usage road': 36,
#          'Turn left onto Butts RdRestricted usage road': 3,
#          'Continue onto Titus BlvdRestricted usage road': 3,
#          'Turn right toward Ardennes StRestricted usage road': 3,
#          'Turn right onto Ardennes StRestricted usage roadDestination will be on the left': 2,
#          'Head southwest toward E Cheyenne Mountain Blvd': 7,
#          'Head northeast toward Lake Plaza Dr': 1,
#          'Turn left onto Lake Plaza Dr': 3,
#          'Turn right onto Lake Ave': 62,
#          'Turn right onto Venetucci Blvd': 34,
#          'Turn left onto Mcnerney StRestricted usage road': 13,
#          'Turn left onto Kit Carson DrRestricted usage road': 10,
#          'Turn right to stay on Kit Carson DrRestricted usage roadDestination will be on the left': 6,
#          'Head north on Samuel PointRestricted usage road': 6,
#          'Turn left to stay on Samuel PointRestricted usage road': 7,
#          'Turn right onto Westmeadow Dr': 20,
#          'Turn left onto CO-115 S': 116,
#          'Turn right onto Butts RdRestricted usage road': 10,
#          'Head west toward Westmeadow Dr': 6,
#          'Turn right onto Wetzel AveRestricted usage road': 53,
#          'Turn left onto Polio StRestricted usage roadDestination will be on the left': 1,
#          'Slight left toward Citadel Dr N': 1,
#          'Turn right onto Stumpf RdRestricted usage road': 5,
#          'Turn right onto Carpenter CtRestricted usage roadDestination will be on the right': 5,
#          'Head east on El Morro Rd toward S Academy Blvd': 2,
#          'Turn right at the 1st cross street onto S Academy BlvdPass by Burger King (on the right in 0.5&nbsp;mi)': 2,
#          'Turn rightDestination will be on the right': 120,
#          'Head northeast on Creek Legend View toward Cortez Dr': 4,
#          'Turn left onto Cortez Dr': 3,
#          'Turn left onto Frontier Dr': 3,
#          'Turn right at the 1st cross street onto Ivanhoe Dr': 3,
#          'Turn right onto Cody Dr': 4,
#          'At the traffic circle, take the 3rd exit onto Bradley Rd': 5,
#          'Turn left onto Pershing DrRestricted usage roadDestination will be on the right': 7,
#          'Head south on Mesita Ct toward W Cheyenne Rd': 1,
#          'Turn left onto W Cheyenne Rd': 36,
#          "Slight right after McDonald's (on the left)": 41,
#          'Slight right onto S Nevada Ave': 41,
#          'Turn right onto Sutherland CirRestricted usage road': 39,
#          'Head east on Black Maple Ln toward Wildwood Pass Dr': 4,
#          'Turn right onto Jet Stream Dr': 4,
#          'Slight right to stay on Magrath AveRestricted usage roadDestination will be on the left': 19,
#          'Head southwest on Mark Dabling Blvd': 1,
#          'Turn right onto W Fillmore St': 2,
#          'Slight left onto the Fillmore St ramp': 23,
#          'Merge onto I-25 S': 62,
#          'Head east on Airport Rd toward Gahart Dr': 1,
#          'Turn right onto Crestline Dr': 2,
#          'Turn left onto S Murray Blvd': 5,
#          'Turn right toward Walmart Hts': 69,
#          'Turn left at the 1st cross street onto Walmart Hts': 39,
#          'Turn right onto Karopczyc CirRestricted usage road': 3,
#          'Turn left onto Yabes CtRestricted usage road': 3,
#          'Head west on Plum Creek Pkwy toward Fairgrounds Dr': 1,
#          'Turn left onto Frontage Rd': 1,
#          'Turn left onto Cochrane CirRestricted usage roadDestination will be on the left': 26,
#          'Head south on Ross Lake Dr toward Angeles Rd': 1,
#          'Turn left onto Angeles Rd': 1,
#          'Turn right onto Londonderry Dr': 5,
#          'Turn left onto Meridian Rd': 11,
#          'Turn right onto US-24 W': 58,
#          'Take the exit onto CO-21 S/US-24 W/N Powers Blvd toward S. Powers Blvd': 48,
#          'Continue onto CO-21 S/S Powers Blvd': 47,
#          'Turn right onto Titus BlvdRestricted usage roadDestination will be on the left': 3,
#          'Turn right toward Grand Cordera Pkwy': 1,
#          'Turn left at the 1st cross street onto Grand Cordera Pkwy': 2,
#          'Head west toward Van Teylingen Dr': 2,
#          'Turn left onto Van Teylingen Dr': 2,
#          'Turn left onto Rebecca Ln': 7,
#          'Turn right onto N Academy BlvdPass by Burger King (on the right in 6.0&nbsp;mi)': 8,
#          'Turn right onto Minick AvePartial restricted usage road': 9,
#          'Turn right onto Yano St': 8,
#          'Head northeast on Sierra Springs Dr toward Sierra Park Dr': 2,
#          'Turn right to stay on Sierra Springs Dr': 2,
#          'Turn left onto Jet Wing Dr': 16,
#          'Turn right at the 1st cross street to stay on Jet Wing Dr': 3,
#          'Turn right onto Astrozon Blvd': 26,
#          'Turn right onto Cochrane CirRestricted usage road': 19,
#          'Head north on Westmeadow Dr toward Pebble Ridge Cir': 3,
#          'Slight left to stay on Wetzel AveRestricted usage road': 10,
#          'Turn left onto Specker AveRestricted usage roadDestination will be on the right': 6,
#          'Head north on Palisades Park View toward Concerto Dr': 9,
#          'Turn right onto Concerto Dr': 9,
#          'Turn right onto Broadmoor Bluffs Dr': 16,
#          'Turn left onto Bastogne DrRestricted usage roadDestination will be on the right': 18,
#          'Head north on Hancock Expy toward Morning Mist DrPass by Taco Bell (on the right in 1.2&nbsp;mi)': 1,
#          'Turn right at Huertgen Forest RdRestricted usage road': 3,
#          'Head west on Samuel Point toward Christy HeightsRestricted usage road': 1,
#          'Turn right to stay on Samuel PointRestricted usage road': 2,
#          'Head north toward N Wenatchee St': 2,
#          'Turn left toward N Wenatchee St': 2,
#          'Turn right onto N Wenatchee St': 3,
#          'Turn left onto E 77th Ave': 2,
#          'Turn left onto E 78th Ave Connector': 2,
#          'Merge onto Peña Blvd': 3,
#          'Take exit 6A toward I-70 S': 6,
#          "Keep left at the fork to continue on Exit 28A, follow signs for Denver Int'l Airport and merge onto Colorado E470 SToll road": 6,
#          'Take exit 1A for Interstate 25 S toward Colo Spgs': 14,
#          'Turn left onto Nelson Blvd': 62,
#          'Head south on Beacon Hill Way': 1,
#          'Turn left to stay on Beacon Hill Way': 1,
#          'Beacon Hill Way turns right and becomes Skyway Blvd': 1,
#          'Turn left onto Arcturus Dr': 8,
#          'Continue straight onto W Ramona Ave': 9,
#          'Turn right onto Lorraine St': 14,
#          'Turn right onto Barkeley AveRestricted usage road': 10,
#          'Head west on Auto Mall Loop toward Razorback Rd': 1,
#          'Turn right onto Razorback Rd': 1,
#          'Turn left at the 1st cross street onto Voyager Pkwy': 3,
#          'Turn right onto N Academy Blvd': 17,
#          'Head north on Medicine Bow Ave toward Centennial St': 1,
#          'Turn left onto Fountain Mesa Rd': 37,
#          'Head east on CO-16 E': 8,
#          'Make a U-turn': 25,
#          'Turn left onto Sutherland CirRestricted usage road': 24,
#          'Head east on Lake Ave': 2,
#          'Turn right onto Cheyenne Meadows Rd': 22,
#          'Turn right onto Sam Houston LoopRestricted usage roadDestination will be on the right': 4,
#          'Head northeast on Bear Gulch Ln toward E Blackstone Dr': 1,
#          'Turn right at the 1st cross street onto E Blackstone Dr': 1,
#          'Turn right onto E Laramie Ave': 1,
#          'Turn left onto N Platteville Blvd': 1,
#          'Turn left onto N Purcell Blvd': 8,
#          'Turn left to merge onto I-25 N': 40,
#          'Head south toward Westview Rd': 1,
#          'Turn left at the 1st cross street onto Westview Rd': 1,
#          'Turn left at the 1st cross street onto Chester St': 1,
#          'Turn right onto E County Line Rd': 1,
#          'Slight right to merge onto I-25 S': 11,
#          'Turn left onto Barkeley AveRestricted usage roadDestination will be on the left': 9,
#          'Turn left onto Titus BlvdRestricted usage roadDestination will be on the right': 10,
#          'Head north on S Cascade Ave toward E Costilla StPass by Wells Fargo Bank (on the left)': 1,
#          'Turn left at the 1st cross street onto Costilla St': 1,
#          'Turn left onto Sahwatch St': 1,
#          'Turn right onto W Cimarron St': 7,
#          'Head south toward Pacific Hills PointRestricted usage road': 14,
#          'Turn right onto Pacific Hills PointRestricted usage road': 14,
#          'Turn left to stay on Pacific Hills PointRestricted usage road': 14,
#          'Turn left at the 1st cross street onto Westmeadow DrPartial restricted usage road': 10,
#          'Continue onto Chiles AvePartial restricted usage roadDestination will be on the left': 24,
#          'Head southwest toward Jimmy Camp Rd': 9,
#          'Turn right at the 1st cross street onto Jimmy Camp Rd': 6,
#          'Take exit 135 for S Academy Blvd toward Airport': 48,
#          'Keep left at the fork, follow signs for Pikes Peak Community College Centennial Campus': 49,
#          'Head southeastRestricted usage road': 2,
#          'Turn left toward Broadmoor Valley RdRestricted usage road': 2,
#          'Turn right onto Broadmoor Valley Rd': 5,
#          'Turn right onto E Cheyenne Mountain Blvd': 17,
#          'Slight right onto Specker AveRestricted usage road': 18,
#          'Turn left at the 1st cross street onto Titus BlvdRestricted usage road': 6,
#          'Head south on Shaft Ave toward North St': 1,
#          'Turn left onto May St': 1,
#          'Continue onto Churchill Ave': 1,
#          'Turn right onto Quincy Ave': 1,
#          'Turn left onto Central Ave': 1,
#          'Continue onto Co Rd 13A': 1,
#          'Co Rd 13A turns slightly left and becomes S Frazier Ave': 2,
#          'Turn right onto W Main St': 2,
#          'Continue onto CO-115 S': 2,
#          'Turn right onto Turkey Creek RdRestricted usage roadDestination will be on the left': 1,
#          'Head west toward Space Center Dr': 3,
#          'Turn left toward Space Center Dr': 2,
#          'Turn left onto Space Center Dr': 5,
#          'Turn left at the 1st cross street onto Galley Rd': 5,
#          'Turn right onto CO-21 S': 27,
#          'Turn right onto Grinnell Blvd': 46,
#          'Turn left onto CanAm Hwy': 87,
#          'Continue straight to stay on Specker AvePartial restricted usage roadDestination will be on the right': 31,
#          'Head south on Eagle View Dr toward E Caramillo St': 1,
#          'Turn left onto N Union Blvd': 12,
#          'Merge onto US-24 W via the ramp to Woodland Park': 29,
#          'Take the exit on the left onto I-25 S toward Pueblo': 114,
#          'Head westRestricted usage road': 4,
#          'Slight leftRestricted usage road': 3,
#          'Turn left toward Woodland Hills DrRestricted usage road': 1,
#          'Turn right onto Woodland Hills Dr': 4,
#          'Turn right onto N Union Blvd': 20,
#          "Turn left onto E Woodmen RdPass by Carl's Jr (on the right in 1.8&nbsp;mi)": 18,
#          'Head east on Esther Dr toward Evergreen Dr': 2,
#          'Turn right onto Evergreen Dr': 2,
#          'Evergreen Dr turns right and becomes Holly Dr': 2,
#          'Turn left onto Main St': 13,
#          'Slight rightRestricted usage roadDestination will be on the right': 3,
#          'Head east toward Norad RdRestricted usage road': 1,
#          'Turn left toward Norad RdRestricted usage road': 1,
#          'Turn right onto Norad RdPartial restricted usage road': 1,
#          'Merge onto CO-115 S via the ramp to Cañon City': 3,
#          'Turn right onto Wallace StRestricted usage road': 1,
#          'Head north on Davis St toward Benny Ave': 1,
#          'Turn left at the 1st cross street onto Benny Ave': 1,
#          'Turn right at the 2nd cross street onto Brookside Ave': 1,
#          'Turn right onto CO-115 S/Cedar Ave': 2,
#          'Turn left onto MacKenzie Ave': 2,
#          'Turn right onto US-50 E': 7,
#          'Take the CO-115 exit toward Penrose/Colo Spgs': 7,
#          'Turn left onto CO-115 N': 11,
#          'Turn right onto Nelson BlvdPartial restricted usage road': 24,
#          'Turn left onto Bennett StRestricted usage roadDestination will be on the left': 7,
#          'Head south on CO-21 S': 5,
#          'Continue straight onto Marauder Wy': 18,
#          'Head west on Holly Dr toward Rosemont Dr': 1,
#          'Head east on Carefree Cir N': 1,
#          'Head southwest toward Walmart Hts': 40,
#          'Turn left onto Walmart Hts': 45,
#          'Turn left onto Light Fighter DrRestricted usage roadDestination will be on the right': 7,
#          'Turn right onto Inchon CirRestricted usage roadDestination will be on the right': 25,
#          'Head northwest on CanAm HwyPass by IHOP (on the left)': 1,
#          'Make a U-turn at Plaza BlvdPass by Jack in the Box (on the right in 0.2&nbsp;mi)': 5,
#          'Head northwest toward Factory Shops Blvd': 2,
#          'Slight right onto Factory Shops Blvd': 2,
#          'Make a U-turn at New Memphis Ct': 2,
#          'Turn left at the 1st cross street onto Meadows Pkwy': 2,
#          'Turn right to merge onto I-25 S/US-85 S toward Colo Spgs': 2,
#          'Keep left to continue on I-25 S': 2,
#          'Head southwest on S Ireland St toward S Himalaya Way/E Purdue Pl': 1,
#          'Turn left onto E Quincy Ave': 1,
#          'Keep left to stay on E Quincy Ave': 1,
#          'Keep right to stay on E Quincy Ave': 1,
#          'Turn right to merge onto E-470 S/Colorado E470 SToll road': 2,
#          'Head southwest on E Cheyenne Mountain Blvd toward Venetucci Blvd': 6,
#          'Turn right at the 1st cross street onto Cheyenne Meadows Rd': 18,
#          'Turn left onto Briargate Pkwy': 8,
#          'Turn left toward Prussman BlvdRestricted usage road': 49,
#          'Slight left onto Prussman BlvdRestricted usage road': 48,
#          'Turn left onto Sasser DrRestricted usage roadDestination will be on the right': 11,
#          'Turn right onto Old Hospital StRestricted usage roadDestination will be on the right': 9,
#          'Head west on Constitution Ave': 1,
#          'Turn right onto Rio Vista Dr': 2,
#          'Turn left at the 1st cross street onto Constitution Ave': 9,
#          "Turn right onto CO-21 S/State Hwy 21 SPass by Wendy's (on the left in 1.0&nbsp;mi)": 4,
#          'Continue onto CO-21 S/State Hwy 21 S/US-24 W': 4,
#          'Turn left onto Grove StRestricted usage road': 67,
#          'Turn left onto Coleman StRestricted usage roadDestination will be on the right': 4,
#          'Head west toward Galley Rd': 3,
#          'Turn right toward Galley Rd': 4,
#          'Turn right onto Galley Rd': 10,
#          'Turn right onto N Academy BlvdPass by Burger King (on the right in 3.7&nbsp;mi)': 7,
#          'Head west toward S Academy Blvd': 10,
#          'Head west on S Academy Blvd': 3,
#          'Turn right onto Titus BlvdRestricted usage road': 20,
#          'Turn left onto Utah Beach Dr': 3,
#          'Head south on Cobblestone DrRestricted usage road': 2,
#          'Turn right to stay on Cobblestone DrRestricted usage road': 2,
#          'Turn left onto Star Ranch Rd': 5,
#          'Take the Westmeadow Dr exit toward Ft. Carson': 50,
#          'Turn right onto Westmeadow DrRestricted usage road': 50,
#          'Turn right at the 1st cross street onto Westmeadow Dr': 20,
#          'Turn right onto Chiles Ave': 4,
#          'Head north toward S Parkside Dr': 5,
#          'Turn right onto S Parkside Dr': 2,
#          'Turn right onto Printers Pkwy': 1,
#          'Slight left onto Airport Rd': 1,
#          'Turn left to merge onto CO-115 S toward Cañon City': 72,
#          'Turn left onto Picket StRestricted usage road': 7,
#          'Head east on Hubbell Dr toward Monk St': 1,
#          'Turn right onto Monk St': 1,
#          'Turn right onto Watson Blvd': 1,
#          'Turn left at the 1st cross street onto Willis Dr': 1,
#          'Turn right onto Sheridan AveRestricted usage road': 98,
#          'Turn left onto Old Hospital StRestricted usage road': 13,
#          'Turn left onto Shea DrRestricted usage roadDestination will be on the right': 4,
#          'Head southwest toward Milton E Proby Pkwy': 1,
#          'Merge onto Milton E Proby Pkwy': 3,
#          'Head south on Crestline Dr toward Welsh Cir': 1,
#          'Head southeast on Stonehaven Dr toward Wycliffe Dr': 1,
#          'Turn right at the 1st cross street onto Wycliffe Dr': 1,
#          'Head northwest on Venetucci Blvd toward Cheyenne Meadows Rd': 3,
#          'Turn left at the 1st cross street onto Cheyenne Meadows Rd': 3,
#          'Head south toward Venetucci Blvd': 2,
#          'Turn right toward E Cheyenne Mountain Blvd': 27,
#          'Turn right onto Mekong StRestricted usage road': 20,
#          'Turn right onto Woodfill RdRestricted usage road': 13,
#          'Turn left onto Iwo Jima DrRestricted usage road': 8,
#          'Turn left onto Attu DrRestricted usage roadDestination will be on the right': 3,
#          'Head west toward Drew Dix Pkwy': 2,
#          'Continue onto Drew Dix Pkwy': 2,
#          'Head southwest on Trout Haven Rd toward Mt Massive Rd': 1,
#          'Turn right onto Uintah Vale Dr': 1,
#          'Turn left onto Unitah Ridge Dr': 1,
#          'Turn left onto Trout Haven Rd/Tuputso RdContinue to follow Trout Haven Rd': 1,
#          'Turn right onto Twin Rocks Rd': 1,
#          "Turn right onto US-24 E/W Hwy 24Pass by O'Reilly Auto Parts (on the right in 8.2&nbsp;mi)": 1,
#          'Merge onto I-25 S/US-24 EContinue to follow I-25 S': 35,
#          'Head north on Wago Dr toward US-50 BUS W': 2,
#          'Turn left onto US-50 BUS W/Santa Fe Dr': 2,
#          'Continue straight onto S Santa Fe Ave': 2,
#          'Turn right onto D St': 2,
#          'D St turns slightly left and becomes Stanton Ave': 2,
#          'Merge onto I-25 N': 18,
#          'Turn right onto Pershing DrRestricted usage roadDestination will be on the right': 3,
#          'Head southeast on CanAm Hwy': 4,
#          'Turn right onto Southmoor Dr': 2,
#          'Turn left onto Center Valley Dr': 2,
#          'Turn left at the 2nd cross street onto CanAm Hwy': 2,
#          'Turn right onto Alamo AveRestricted usage roadDestination will be on the left': 2,
#          'Enter the traffic circleDestination will be on the right': 2,
#          'Turn right toward CanAm Hwy': 23,
#          "Turn left onto CanAm HwyPass by O'Reilly Auto Parts (on the left in 0.5&nbsp;mi)": 3,
#          'Turn right onto Inchon CirRestricted usage roadDestination will be on the left': 6,
#          'Head southeast on Mountain Top Ln toward Ravencrest Dr': 3,
#          'Turn left onto Ravencrest Dr': 3,
#          'Turn right onto E Rockrimmon Blvd': 3,
#          'Continue onto E Woodmen Rd': 3,
#          'Turn right onto Mekong StRestricted usage roadDestination will be on the left': 3,
#          'Head north on Canoe Creek Dr N toward Gypsy Ct': 1,
#          'Turn right onto Eastmeadow Dr': 10,
#          'Turn right at the 1st cross street onto Red Cedar Dr': 2,
#          'Turn left onto Meadowdale Pl': 3,
#          'Turn right onto Catalina Pl': 3,
#          'Turn right onto Catalina Dr': 5,
#          'Turn left onto Loomis Ave': 5,
#          'Turn right onto Crestridge Ave': 8,
#          'Turn right at the 1st cross street onto B St': 7,
#          'Turn left onto Titus BlvdRestricted usage roadDestination will be on the left': 6,
#          'Head north on Baling Wire Way toward Lake Ave': 1,
#          'Turn left onto Lake Ave': 25,
#          'Continue straight to stay on Specker AvePartial restricted usage roadDestination will be on the left': 10,
#          'Head west on Tributary Ct toward Lake Ave': 6,
#          "Turn left onto O'Connell BlvdRestricted usage roadDestination will be on the right": 11,
#          'Head north on Sun Prairie Dr toward Crossfire Ct': 1,
#          'Turn right onto Waterville Way': 1,
#          'Turn right at the 1st cross street onto Autumn Glen Ave': 2,
#          'At the traffic circle, take the 1st exit onto Wilderness RdRestricted usage roadDestination will be on the left': 7,
#          'Head south on Widick St toward Binger Dr': 1,
#          'Turn right onto Crawford Ave': 4,
#          'Turn left onto Sutherland CirRestricted usage roadDestination will be on the left': 2,
#          'Head south on Cottage Grove Ct toward Woody Creek Dr': 3,
#          'Turn right onto Woody Creek Dr': 3,
#          'Turn left onto Sneffels St': 18,
#          'Head southwest on CO-83 S toward E Best Rd/Jones Rd': 1,
#          'Turn right onto County Line Rd/E Palmer Divide Ave': 5,
#          'Turn left to merge onto I-25 S toward Monument Hill Road': 7,
#          'Head east on Orange Sunset Dr toward Antelope Ridge Dr': 2,
#          'Turn right at the 1st cross street onto Antelope Ridge Dr': 2,
#          'At the traffic circle, continue straight to stay on Antelope Ridge Dr': 2,
#          'Turn left onto Barnes Rd': 12,
#          'Turn right toward Fountain Mesa Rd': 18,
#          'Turn left onto Fountain Mesa RdPass by Chick-fil-A (on the right)': 11,
#          'Head south on Shahara Rd toward Higby Rd': 1,
#          'Continue onto Roller Coaster Rd': 5,
#          'Turn right onto Old North Gate Rd': 5,
#          'Turn right onto North Gate Blvd': 11,
#          'Turn right onto the ramp to I-25 S': 13,
#          'Keep left at the fork and merge onto I-25 S': 16,
#          'Turn left onto Felkins StRestricted usage road': 9,
#          'Head east toward N Arcadia St': 2,
#          'Turn left onto N Arcadia St': 2,
#          "Turn left after KFC (on the left)Pass by McDonald's (on the right in 0.3&nbsp;mi)": 2,
#          'Head northwest toward E Bighorn DrRestricted usage road': 2,
#          'Turn left onto E Bighorn DrRestricted usage road': 2,
#          'Turn right to stay on E Bighorn DrRestricted usage road': 2,
#          'Turn right onto W Douglass DrRestricted usage road': 7,
#          'Turn right onto E Douglass DrRestricted usage road': 7,
#          'Turn left onto Community Center DrRestricted usage road': 7,
#          'Turn right onto Stadium BlvdRestricted usage road': 9,
#          'Continue onto S Gate BlvdPartial restricted usage road': 10,
#          'Head southeast toward S 7th St': 1,
#          'Continue onto S 7th St': 1,
#          'Turn left onto W Cucharras St': 4,
#          'Turn left at the 2nd cross street onto S Limit St': 1,
#          'Turn left onto US-24 E/W Cimarron St': 5,
#          'Turn right onto Utah Beach Dr': 45,
#          'Head north on Franconia Dr toward Killington St': 2,
#          'Turn left onto Killington St': 3,
#          'Turn right onto Loveland Ave': 3,
#          'Turn left onto Medicine Bow Ave': 7,
#          'Head east on Kasson Dr toward Maram Way': 1,
#          'Turn left onto Maram Way': 2,
#          'Turn right onto Village Meadows Dr': 1,
#          "Turn left at the 1st cross street onto Fountain Mesa RdPass by Culver's (on the right in 0.4&nbsp;mi)": 1,
#          'Head northwest on Songglen Cir toward Chaseglen Dr': 4,
#          'Turn right at the 1st cross street onto Chaseglen Dr': 5,
#          'Turn left onto Polio StRestricted usage road': 1,
#          'Head northeast on Golden Briar Ln toward Vista del Tierra': 1,
#          'Turn right at the 1st cross street onto Vista del Tierra': 1,
#          'Turn right onto Dublin Blvd': 11,
#          'Slight left toward Marksheffel Rd': 7,
#          'Turn left onto Marksheffel Rd': 12,
#          'Head south on Cast Iron Dr toward Desert Bloom Way': 2,
#          'Turn left onto Desert Bloom Way': 2,
#          'Turn right onto Cattle Baron Wy': 5,
#          'Turn left at the 1st cross street onto Old Glory Dr': 3,
#          'Turn right at the 1st cross street onto Fontaine Blvd': 14,
#          'Turn left onto Bad Toelz RdRestricted usage roadDestination will be on the right': 3,
#          'Head south on Terminal Rd': 2,
#          'Continue onto Peña Blvd (signs for I-70/Airport Exit/Airport Return to Terminal)': 2,
#          'Head northeast on Poughkeepsie Dr toward Silver Hawk Ave': 1,
#          'Turn left at the 1st cross street onto Silver Hawk Ave': 1,
#          'Turn left onto Magellans Eagle Dr': 1,
#          'Turn right onto Harrier Ridge Dr': 3,
#          'Turn left onto Hancock Expy': 26,
#          'Continue straight to stay on Hancock Expy': 15,
#          'Head west on Benny Ave toward Brookside Ave': 1,
#          'Turn right at the 1st cross street onto Brookside Ave': 1,
#          'Turn left onto Bennett StRestricted usage road': 8,
#          'Head south toward Walmart Hts': 2,
#          'Head east toward N Academy Blvd': 5,
#          'Turn left toward N Academy Blvd': 13,
#          'Make a U-turn at Maizeland RdPass by Burger King (on the right in 5.2&nbsp;mi)': 4,
#          'Turn left onto Light Fighter DrRestricted usage road': 16,
#          'Turn right onto Just Cause DrRestricted usage roadDestination will be on the left': 14,
#          'Head northwest on Magnolia St toward Mariposa St': 2,
#          'Turn left onto Mt View LnPass by 7-Eleven (on the right in 0.3&nbsp;mi)': 4,
#          'Turn left onto N Nevada Ave': 7,
#          'Turn right onto E Fillmore StPass by Dairy Queen Grill &amp; Chill (on the left in 0.4&nbsp;mi)': 5,
#          'Head north on Brisco Ct toward Willow Pines Pl': 1,
#          'Turn right onto Willow Pines Pl': 1,
#          'Turn right onto Oakshire Way': 1,
#          'Head northwest on CanAm Hwy toward Plaza Blvd': 4,
#          'At the traffic circle, take the 1st exit onto Wilderness RdRestricted usage road': 32,
#          'Turn left onto Warfighter RdRestricted usage roadDestination will be on the right': 6,
#          'Head south on Olympic Plaza': 1,
#          'Turn left toward N Meade Ave': 1,
#          'Turn right onto N Meade Ave': 1,
#          'Turn right at the 1st cross street onto E Boulder St': 3,
#          'Turn left onto Farragut Ave': 1,
#          'Turn right at the 1st cross street onto E Platte Ave': 1,
#          'Turn left after Taco Bell (on the left)': 2,
#          'Turn right onto E Cimarron St': 8,
#          'Turn right onto McCoy StRestricted usage road': 25,
#          'Turn left at the 1st cross street onto Sam Houston LoopRestricted usage road': 4,
#          'Turn right onto Picatinny LnRestricted usage roadDestination will be on the left': 4,
#          'Turn right onto St Lo DrRestricted usage road': 2,
#          'Turn right onto St Lo CirRestricted usage roadDestination will be on the left': 1,
#          'Head east toward Chapman DrRestricted usage road': 2,
#          'Turn right onto Chapman Dr': 2,
#          'Turn left onto Academy Park Loop': 2,
#          'Turn left onto S Academy BlvdPass by Burger King (on the right in 1.3&nbsp;mi)': 4,
#          'Head south on Falling Star Rd toward Diamond E Rd/McGahan Dr': 1,
#          'Turn right onto Link Rd': 13,
#          'Head south on S Nevada Ave toward E Las Vegas St': 3,
#          'Slight right': 12,
#          'Head south on Phantom Way toward Liberator Trl': 2,
#          'Turn right onto Kearsarge Dr': 4,
#          'Turn right at the 1st cross street': 20,
#          'Turn left onto Ellis StRestricted usage road': 38,
#          'Head southwest toward S 1st St': 1,
#          'Turn right onto US-87 N/S 1st StContinue to follow US-87 N': 1,
#          'Turn right to merge onto I-25 NEntering Colorado': 3,
#          'Take exit 128 toward US-85 N/Fountain': 12,
#          'Keep left at the fork, follow signs for Industrial Pk': 12,
#          'Turn left onto Santa Fe Ave': 14,
#          'Head east toward Galley Rd': 1,
#          'Turn left onto Galley Rd': 18,
#          "Turn left onto N Circle DrPass by Dunkin' (on the left in 0.8&nbsp;mi)": 1,
#          'Head south on Spitfire Dr toward Wing Walker Dr': 1,
#          'Turn right onto Wing Walker Dr': 3,
#          'Turn left onto Allgood Dr': 3,
#          'Turn right at the 2nd cross street onto Yucatan Dr': 5,
#          'Turn right at the 2nd cross street onto Bradley Rd': 7,
#          'Head north on S McCulloch Blvd toward US-50 E': 2,
#          'Turn right onto E Platteville Blvd': 7,
#          'At the traffic circle, take the 3rd exit onto N Purcell Blvd': 7,
#          'Turn left onto Chiles Ave': 24,
#          'Head south toward Trojan Pt': 2,
#          'Turn right toward Trojan Pt': 7,
#          'Turn right onto Trojan Pt': 2,
#          'Turn left onto Johnson CtRestricted usage roadDestination will be on the left': 5,
#          'Head west on Broman Ct toward College View Dr': 3,
#          'Turn left onto College View Dr': 3,
#          'Turn left onto Millburn Dr': 3,
#          'Turn right onto Chamberlin S': 3,
#          'Turn left onto Lashelle Ave': 3,
#          'Turn left onto Lashelle Way': 7,
#          'Turn left onto B St': 14,
#          'Turn right onto Nelson BlvdRestricted usage roadDestination will be on the left': 10,
#          'Head east on Silver Stirrup Dr toward Journey Dr': 2,
#          'Turn right onto Journey Dr': 4,
#          'Turn right onto Old Glory Dr': 13,
#          'Turn left onto Ware StRestricted usage roadDestination will be on the left': 6,
#          'Head east on Araia Dr toward Red Fern Ln': 2,
#          'Turn right onto Red Fern Ln': 2,
#          'Red Fern Ln turns left and becomes Willowdale Dr': 5,
#          'Turn right onto Elmhurst Dr': 7,
#          'Turn right at the 1st cross street onto Willow Pines Pl': 7,
#          'Turn left onto Oakshire Way': 7,
#          'Turn left onto Mc Donald StRestricted usage road': 15,
#          'Head south on Lake Plaza Dr toward Tenderfoot Hill Rd': 1,
#          'Turn left onto Tenderfoot Hill Rd': 7,
#          'Turn right at the 2nd cross street onto Cheyenne Meadows Rd': 8,
#          'Head southwest on Pikes Peak Ave toward Byron Dr': 2,
#          'Turn left onto S Academy BlvdPass by Burger King (on the right in 2.7&nbsp;mi)': 9,
#          'Head northeast toward Oxford Ln': 2,
#          'Turn right toward Oxford Ln': 3,
#          'Turn left onto Oxford Ln': 4,
#          'Turn right onto S 8th St': 13,
#          'Head southeast on Broadmoor Bluffs Dr toward Royal Crown Ln': 3,
#          'Take the exit onto I-25 S toward Pueblo': 30,
#          'Slight right to stay on Magrath AveRestricted usage roadDestination will be on the right': 16,
#          'Head northwest on Springnite Dr toward Simmelink Loop': 1,
#          'Continue onto Deerfield Hills Dr': 2,
#          'Turn left onto Moonbeam Dr': 2,
#          'Turn left toward CanAm Hwy': 11,
#          'Slight right onto CanAm Hwy': 6,
#          'Head east on Hunters Run toward Heron Ct': 2,
#          'Continue onto Brant Rd': 2,
#          'Turn left onto Marabou Way': 2,
#          'Turn left onto Afton StRestricted usage road': 5,
#          'Head west toward Wando Dr': 5,
#          'Turn right onto Picket StRestricted usage roadDestination will be on the left': 10,
#          'Head west on Chelton Rd toward S Academy Blvd': 3,
#          'Turn left at the 1st cross street onto S Academy BlvdPass by Burger King (on the right in 0.8&nbsp;mi)': 3,
#          'Turn right onto Falaise Gap RdRestricted usage road': 10,
#          'Turn right onto Remagen RdRestricted usage road': 14,
#          'Turn left onto Cherbourg CirRestricted usage road': 4,
#          'Head eastRestricted usage road': 13,
#          'Turn left toward Westmeadow DrRestricted usage road': 15,
#          'Turn right toward Westmeadow DrRestricted usage road': 6,
#          'Turn left at the 1st cross street onto Westmeadow Dr': 7,
#          'Head south on Millstream Terrace toward W Rio Grande St': 1,
#          'Turn left onto W Rio Grande St': 1,
#          'Turn right onto Lower Gold Camp Rd': 3,
#          'Turn left onto S 8th StPass by AutoZone Auto Parts (on the right in 0.2&nbsp;mi)': 2,
#          'Turn right toward W Cimarron St': 6,
#          'Turn left onto Bennett StRestricted usage roadDestination will be on the right': 4,
#          'Head south on Flintshire St toward St James Dr': 1,
#          'Turn right onto St Claire Dr': 1,
#          'Turn left at the 1st cross street onto S Union Blvd': 1,
#          'Merge onto S Circle Dr': 16,
#          'Head east on Gateway Rd': 1,
#          'Turn left onto N 30th St': 2,
#          'Sharp right onto Mesa Rd': 1,
#          'At the traffic circle, continue straight to stay on Mesa Rd': 1,
#          'Turn left onto Uintah St': 8,
#          'Head west on Park Ave toward Jewett St': 1,
#          'Turn right onto S 12th St': 1,
#          'Continue onto Park Ave': 1,
#          'Turn right onto S 9th St': 1,
#          'Turn right onto US-50 E/Royal Gorge BlvdContinue to follow US-50 EPass by Sonic Drive-In (on the left in 0.2&nbsp;mi)': 1,
#          'Turn right onto Nelson Blvd': 2,
#          'Head east toward Fountain Mesa Rd': 12,
#          "Turn right onto Fountain Mesa RdPass by Carl's Jr (on the left)": 6,
#          'Turn right onto Mesa Rd': 15,
#          'Continue straight to stay on Mesa Rd': 6,
#          'Turn right onto Syracuse St': 14,
#          'Head northwest toward JL Ranch Heights Rd': 2,
#          'Turn right onto JL Ranch Heights Rd': 4,
#          'At the traffic circle, take the 1st exit and stay on JL Ranch Heights Rd': 3,
#          'Continue onto Nelson BlvdPartial restricted usage road': 3,
#          'Turn left onto Prussman BlvdRestricted usage roadDestination will be on the left': 8,
#          'Head west on Traders Pkwy toward Hidden Pr Pkwy': 3,
#          'Turn right to stay on Pacific Hills PointRestricted usage road': 8,
#          'Turn left to merge onto S Academy Blvd': 19,
#          'Head west on Pearl Dr toward Del Verde Dr': 1,
#          'Turn left onto Meadowland Blvd': 1,
#          'Turn left onto N Academy BlvdPass by Burger King (on the right in 7.3&nbsp;mi)': 1,
#          'Turn left onto Hogan StRestricted usage roadDestination will be on the right': 2,
#          'Head north on Jimmy Camp Rd toward Pullara Dr': 4,
#          'Head south on S Marksheffel Rd toward Lorson Blvd': 2,
#          'Head southwest on San Mateo Dr toward Justeagen Dr': 1,
#          'Turn left onto Katahdin Way': 8,
#          'Turn left at the 1st cross street onto Goldfield Dr': 2,
#          'Head northwest toward S Murray Blvd': 3,
#          'Turn left at the 1st cross street onto S Murray Blvd': 3,
#          'Turn right onto Brown RdRestricted usage road': 13,
#          'At the traffic circle, take the 1st exitRestricted usage road': 11,
#          'Head south on Hidden River Dr toward Desert Varnish Dr': 2,
#          'Turn left onto Desert Varnish Dr': 2,
#          'Turn right onto Barnes Rd': 12,
#          'Head northeast on Chimayo Dr toward Bison Dr': 1,
#          'Turn right onto Cortez Dr': 3,
#          'Turn right onto Hallam Ave': 3,
#          'Continue onto Security Blvd': 3,
#          'Head southeast on Benecia Dr toward Buckhead Pl': 3,
#          'Head south toward Dominion Way': 1,
#          'Turn right toward Dominion Way': 1,
#          'Turn right onto Dominion Way': 1,
#          'Take the ramp to E Woodmen Rd': 11,
#          "Keep left at the fork and merge onto E Woodmen RdPass by Carl's Jr (on the right in 0.7&nbsp;mi)": 11,
#          'Turn right onto Just Cause DrRestricted usage roadDestination will be on the right': 6,
#          'Head southwest on Settlement Way toward Chieftan Dr': 1,
#          'Turn right onto Chieftan Dr': 2,
#          'Turn left at the 2nd cross street onto Horizonview Dr': 1,
#          'Head east on Birmingham Loop': 4,
#          'Turn right onto S Union Blvd': 10,
#          'Head north on Fountain Mesa Rd toward Comanche Village Dr': 1,
#          'Head south on N Log Rd toward McDaniels Rd': 1,
#          'Turn right onto CO-94 W': 2,
#          'Turn left onto N Curtis Rd': 3,
#          'Continue onto Bradley Rd/Drennan RdContinue to follow Bradley Rd': 6,
#          'Turn right onto CO-21 N': 13,
#          'Turn left onto Milton E Proby Pkwy': 16,
#          'Head northwest on Austin Bluffs Pkwy toward Clyde Way': 1,
#          "Continue onto Garden of the Gods RdPass by McDonald's (on the right in 0.6&nbsp;mi)": 18,
#          'Head northeast toward Camden Blvd': 1,
#          'Turn right toward Camden Blvd': 1,
#          'Turn left onto Camden Blvd': 1,
#          'Turn right at the 1st cross street onto Center Valley Dr': 1,
#          'Turn right onto CanAm HwyPass by Jack in the Box (on the right in 0.5&nbsp;mi)': 2,
#          'Turn right toward Cougar Bluff PointRestricted usage road': 1,
#          'Turn left onto Cougar Bluff PointRestricted usage road': 1,
#          'Turn right onto Barkeley AveRestricted usage roadDestination will be on the left': 7,
#          'Head west on Chelton Rd toward Mallette Heights': 2,
#          'Turn right at the 1st cross street onto Fort StRestricted usage road': 1,
#          'Head east toward S 8th St': 1,
#          'Turn left onto Cheyenne Blvd': 3,
#          'At the traffic circle, take the 3rd exit onto S Tejon St': 3,
#          'Head northeast on Elk River View toward Yampa River Heights': 2,
#          'Turn left onto Cross Creek': 6,
#          "Turn right after Culver's (on the left)": 20,
#          'Head northeast on S Langdale St toward E Calhoun Dr': 1,
#          'Turn left onto E Calhoun Dr': 1,
#          'Turn left onto S Ider St': 1,
#          'Turn right onto E Smoky Hill Rd': 1,
#          'Turn left onto the E470 S rampToll road': 1,
#          'Merge onto Colorado E470 SToll road': 2,
#          'Turn right onto Specker AveRestricted usage road': 28,
#          'Head southeast on White Stone Way toward Lords Hill Dr': 2,
#          'Turn left at the 1st cross street onto Lords Hill Dr': 2,
#          'Turn left onto Legend Oak Dr': 2,
#          'Turn left onto C &amp; S Rd': 47,
#          'Turn right onto Iron Fighter Dr': 22,
#          'Head east on Oxbow Dr toward Talus Rd': 1,
#          'Turn right at the 1st cross street onto Talus Rd': 1,
#          'Turn left onto Toreva Dr': 1,
#          'Turn right at the 1st cross street onto Leather Chaps Dr': 1,
#          'Turn right at the 2nd cross street onto Baptist Rd': 2,
#          'Head north on Cider Mill Pl toward Wishbone Way': 1,
#          'Turn right onto S Marksheffel Rd': 2,
#          'Head northeast on Pueblo Reservoir Rd toward S Fishing RdRestricted usage road': 1,
#          'Continue onto S Marina RdRestricted usage road': 1,
#          'Turn left onto CO-96 E': 1,
#          'Continue straight onto Lincoln St': 1,
#          'Continue onto W 4th St': 3,
#          'Turn left onto N Bradford St': 3,
#          'Take the ramp onto I-25 N': 5,
#          'Head north toward S Carefree Cir': 1,
#          'Turn right onto S Carefree Cir': 17,
#          "Turn right onto CO-21 SPass by Wendy's (on the left in 1.4&nbsp;mi)": 9,
#          'Head northwest on Divine Heights': 5,
#          'Turn left to stay on Divine Heights': 5,
#          'Turn left onto Tutt Blvd': 12,
#          'At the traffic circle, take the 2nd exit and stay on S Carefree Cir': 17,
#          "Turn left onto CO-21 SPass by Wendy's (on the left in 1.4&nbsp;mi)": 27,
#          'Head south toward Aliso Dr': 1,
#          'Continue onto Lamprey Dr': 1,
#          'Head north on Bandley Dr toward Durbin Ln': 1,
#          'Head east toward Quail Lake CirRestricted usage road': 2,
#          'Turn right at the 1st cross street onto Quail Lake CirPartial restricted usage road': 1,
#          'Turn left onto Bayfield Dr': 6,
#          'Head south toward I-25 S': 1,
#          'Continue onto Barkeley AveRestricted usage roadDestination will be on the right': 5,
#          'Head west on Sistine Ln toward Langford Dr': 1,
#          'Turn right at the 2nd cross street onto Legend Oak Dr': 1,
#          'Head west on Firecracker Trail toward Trackage Trail': 1,
#          'Turn right onto E Ohio Ave': 17,
#          'Head south toward Cross Creek': 8,
#          'Turn right onto Cross Creek': 21,
#          ...})

# %%
len(end_coord)
# Out:
# 6285

# %%
# len(start_address)
# len(end_address)
len(placeid)
# len(end_coord)
# Out:
# 6228

# %% [markdown]
# ### Google Road API : Snap to Road API

# %%
import requests

API_KEY = 'AIzaSyBSf4esoT3GKGgvafmIwE6BHSiUWXBLbh4'


def get_place_api(coordinate_list):
    placeid = []
    for i in coordinate_list:
        url = "https://roads.googleapis.com/v1/snapToRoads?path=" + i+ '&key=' + API_KEY 
        headers = {}
        response = requests.get(url, headers=headers, data=payload, timeout=10)
        if response.status_code == 200:
            road_data = response.json()
            time.sleep(0.1)
            for r in road_data['snappedPoints']:
                placeid.append(r['placeId'])
        else:
            print(response.status_code)
            break
    return placeid

# %%
road_data
# Out:
# {'snappedPoints': [{'location': {'latitude': 38.68401950000001,
#     'longitude': -104.6875575},
#    'originalIndex': 0,
#    'placeId': 'ChIJswyqruZqE4cRHoi3FA8s0wQ'},
#   {'location': {'latitude': 38.683085299999995, 'longitude': -104.7045596},
#    'originalIndex': 1,
#    'placeId': 'ChIJzZbPl_hqE4cR3sj4bst6IoA'},
#   {'location': {'latitude': 38.673401399999996,
#     'longitude': -104.70803299999999},
#    'originalIndex': 2,
#    'placeId': 'ChIJ001u-KprE4cRjxDkoql5iFk'},
#   {'location': {'latitude': 38.7220048, 'longitude': -104.73014189999999},
#    'originalIndex': 3,
#    'placeId': 'ChIJ3W5zcedBE4cRKuIYzc67ld4'},
#   {'location': {'latitude': 38.72511809999999, 'longitude': -104.7323114},
#    'originalIndex': 4,
#    'placeId': 'ChIJ7TtRj-hBE4cRR6WiPnTzeOU'},
#   {'location': {'latitude': 38.72450169999999,
#     'longitude': -104.73474259999999},
#    'originalIndex': 5,
#    'placeId': 'ChIJU2hkUu9BE4cRbjYm8YrzFbs'},
#   {'location': {'latitude': 38.725772199999994,
#     'longitude': -104.74852709999999},
#    'originalIndex': 6,
#    'placeId': 'ChIJrXYbzPZBE4cR1vOqDlUfrew'},
#   {'location': {'latitude': 38.7251817, 'longitude': -104.75160419999999},
#    'originalIndex': 7,
#    'placeId': 'ChIJswH9PvZBE4cRIMOoGP-etSY'},
#   {'location': {'latitude': 38.7436247, 'longitude': -104.7912775},
#    'originalIndex': 8,
#    'placeId': 'ChIJA1nEv1NCE4cRrqM--ZWAfjk'},
#   {'location': {'latitude': 38.7416539, 'longitude': -104.79526899999999},
#    'originalIndex': 9,
#    'placeId': 'ChIJ6UomIVRCE4cRlffkiajI_p8'},
#   {'location': {'latitude': 38.7409381, 'longitude': -104.7990718},
#    'originalIndex': 10,
#    'placeId': 'ChIJiUnxp_hCE4cRDT5KNeyewcM'},
#   {'location': {'latitude': 38.741516100000005, 'longitude': -104.7994533},
#    'originalIndex': 11,
#    'placeId': 'ChIJ1wU9U_9CE4cRv-0d2ln2axU'}],
#  'warningMessage': "Input path is too sparse. You should provide a path where consecutive points are closer to each other. Refer to the 'path' parameter in Google Roads API documentation."}

# %% [markdown]
# ### Google Place API : Convert placeID to Address

# %%
def get_address(place_id):
    address= []
    for p in placeid:
        place_url = 'https://maps.googleapis.com/maps/api/place/details/json?place_id=' + p +'&key='+API_KEY
        payload={}
        headers = {}
        response = requests.get(place_url, headers=headers, data=payload, timeout=10)
        # check if request was successful
        if response.status_code == 200:
            place_data = response.json()
            time.sleep(2)
            address.append(place_data['result']['formatted_address'])
        else:
            print('Error!', response.status_code)
            break
    return address

# %%
get_address(placeid)
# Out:
# ---------------------------------------------------------------------------
# ConnectionResetError                      Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ConnectionResetError: [Errno 54] Connection reset by peer
#
# During handling of the above exception, another exception occurred:
#
# ProtocolError                             Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     438             if not chunked:
# --> 439                 resp = conn.urlopen(
#     440                     method=request.method,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     754
# --> 755             retries = retries.increment(
#     756                 method, url, error=e, _pool=self, _stacktrace=sys.exc_info()[2]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/retry.py in increment(self, method, url, response, error, _pool, _stacktrace)
#     531             if read is False or not self._is_method_retryable(method):
# --> 532                 raise six.reraise(type(error), error, _stacktrace)
#     533             elif read is not None:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/packages/six.py in reraise(tp, value, tb)
#     733             if value.__traceback__ is not tb:
# --> 734                 raise value.with_traceback(tb)
#     735             raise value
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, **response_kw)
#     698             # Make the request on the httplib connection object.
# --> 699             httplib_response = self._make_request(
#     700                 conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _make_request(self, conn, method, url, timeout, chunked, **httplib_request_kw)
#     381         try:
# --> 382             self._validate_conn(conn)
#     383         except (SocketTimeout, BaseSSLError) as e:
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connectionpool.py in _validate_conn(self, conn)
#    1009         if not getattr(conn, "sock", None):  # AppEngine might not have  `.sock`
# -> 1010             conn.connect()
#    1011
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/connection.py in connect(self)
#     410
# --> 411         self.sock = ssl_wrap_socket(
#     412             sock=conn,
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in ssl_wrap_socket(sock, keyfile, certfile, cert_reqs, ca_certs, server_hostname, ssl_version, ciphers, ssl_context, ca_cert_dir, key_password, ca_cert_data, tls_in_tls)
#     427     if send_sni:
# --> 428         ssl_sock = _ssl_wrap_socket_impl(
#     429             sock, context, tls_in_tls, server_hostname=server_hostname
#
# ~/opt/anaconda3/lib/python3.8/site-packages/urllib3/util/ssl_.py in _ssl_wrap_socket_impl(sock, ssl_context, tls_in_tls, server_hostname)
#     471     if server_hostname:
# --> 472         return ssl_context.wrap_socket(sock, server_hostname=server_hostname)
#     473     else:
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in wrap_socket(self, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, session)
#     499         # ctx._wrap_socket()
# --> 500         return self.sslsocket_class._create(
#     501             sock=sock,
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in _create(cls, sock, server_side, do_handshake_on_connect, suppress_ragged_eofs, server_hostname, context, session)
#    1039                         raise ValueError("do_handshake_on_connect should not be specified for non-blocking sockets")
# -> 1040                     self.do_handshake()
#    1041             except (OSError, ValueError):
#
# ~/opt/anaconda3/lib/python3.8/ssl.py in do_handshake(self, block)
#    1308                 self.settimeout(None)
# -> 1309             self._sslobj.do_handshake()
#    1310         finally:
#
# ProtocolError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))
#
# During handling of the above exception, another exception occurred:
#
# ConnectionError                           Traceback (most recent call last)
# <ipython-input-780-a2e5f369af2a> in <module>
# ----> 1 get_address(placeid)
#
# <ipython-input-779-01004f3ca401> in get_address(place_id)
#       5         payload={}
#       6         headers = {}
# ----> 7         response = requests.get(place_url, headers=headers, data=payload, timeout=10)
#       8         if response.status_code == 200:
#       9             place_data = response.json()
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in get(url, params, **kwargs)
#      74
#      75     kwargs.setdefault('allow_redirects', True)
# ---> 76     return request('get', url, params=params, **kwargs)
#      77
#      78
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/api.py in request(method, url, **kwargs)
#      59     # cases, and look like a memory leak in others.
#      60     with sessions.Session() as session:
# ---> 61         return session.request(method=method, url=url, **kwargs)
#      62
#      63
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     540         }
#     541         send_kwargs.update(settings)
# --> 542         resp = self.send(prep, **send_kwargs)
#     543
#     544         return resp
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/sessions.py in send(self, request, **kwargs)
#     653
#     654         # Send the request
# --> 655         r = adapter.send(request, **kwargs)
#     656
#     657         # Total elapsed time of the request (approximately)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/requests/adapters.py in send(self, request, stream, timeout, verify, cert, proxies)
#     496
#     497         except (ProtocolError, socket.error) as err:
# --> 498             raise ConnectionError(err, request=request)
#     499
#     500         except MaxRetryError as e:
#
# ConnectionError: ('Connection aborted.', ConnectionResetError(54, 'Connection reset by peer'))

# %%
len(address)

# %%
# save data into csv
# dict = {'StartAddress': start_address, 'EndAddress': end_address}
# c_dict = {'start_coordinate':start_coord,'end_coordinate': end_coord}
# place_dict = {'PlaceId':placeid}
# address_dict = {'Raw_RoadAddress':address}

# api_df = pd.DataFrame(dict)
# c_df = pd.DataFrame(c_dict)
# place_df = pd.DataFrame(place_dict)
# address_df = pd.DataFrame(address_dict)

# api_df.to_csv('api_address.csv')
# c_df.to_csv('coordinate.csv')
# place_df.to_csv('placeid.csv')
# address_df.to_csv('address.csv')

# %%
address
# Out:
# ['3898-3854 Astrozon Blvd, Colorado Springs, CO 80916, USA',
#  '3844-3800 Astrozon Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '1718-2120 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Chiles Ave, Fort Carson, CO 80902, USA',
#  '5992-6046 Chiles Ave, Fort Carson, CO 80913, USA',
#  'Nelson Blvd, Fort Carson, CO 80913, USA',
#  'Martinez St, Fort Carson, CO 80913, USA',
#  'Coleman St, Fort Carson, CO 80913, USA',
#  'Broadmoor Bluffs Dr, Colorado Springs, CO 80906, USA',
#  'Broadmoor Bluffs Dr, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Sheridan Ave, Fort Carson, CO 80913, USA',
#  'Woodfill Rd, Fort Carson, CO 80913, USA',
#  'St Lo Cir, Fort Carson, CO 80913, USA',
#  'St Lo Cir, Fort Carson, CO 80913, USA',
#  '520 Pikes Peak Ave, Colorado Springs, CO 80903, USA',
#  '300 Pikes Peak Ave, Colorado Springs, CO 80903, USA',
#  'Unnamed Road, Colorado Springs, CO 80903, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  '307-305 De La Vista St, Colorado Springs, CO 80911, USA',
#  '998-900 Drury Ln, Colorado Springs, CO 80911, USA',
#  '998-900 Drury Ln, Colorado Springs, CO 80911, USA',
#  '498 Quebec St, Colorado Springs, CO 80911, USA',
#  '500-618 Syracuse St, Colorado Springs, CO 80911, USA',
#  '639-699 Fay Dr, Colorado Springs, CO 80911, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Prussman Blvd, Fort Carson, CO 80913, USA',
#  'Prussman Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Legend Oak Dr, Fountain, CO 80817, USA',
#  '1585 Legend Oak Dr, Fountain, CO 80817, USA',
#  '4614-1322 C & S Rd, Fountain, CO 80817, USA',
#  '7977-7971 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  'CO-16, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '1222 Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80910, USA',
#  'Spring Bluff Rd, Colorado Springs, CO 80910, USA',
#  'Spring Bluff Rd, Colorado Springs, CO 80910, USA',
#  '3199-3101 Delta Dr, Colorado Springs, CO 80910, USA',
#  'Unnamed Road, Colorado Springs, CO 80910, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '6398-5708 Ellis St, Fort Carson, CO 80902, USA',
#  '5248-4386 Ellis St, Fort Carson, CO 80913, USA',
#  '6812 Kearsarge Dr, Colorado Springs, CO 80925, USA',
#  '6812 Kearsarge Dr, Colorado Springs, CO 80925, USA',
#  '6924-6990 Winnicut Dr, Colorado Springs, CO 80925, USA',
#  '8526-8538 S Marksheffel Rd, Colorado Springs, CO 80925, USA',
#  'Mesa Ridge Pkwy, Fountain, CO, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  '1652-1634 Cochrane Cir, Fort Carson, CO 80913, USA',
#  '701-753 Cheyenne Meadows Rd, Colorado Springs, CO 80906, USA',
#  '891-901 Cheyenne Meadows Rd, Colorado Springs, CO 80906, USA',
#  '4840 Chiles Ave, Fort Carson, CO 80902, USA',
#  '4928-4940 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5026-5056 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5058-5070 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5058-5070 Chiles Ave, Fort Carson, CO 80902, USA',
#  '113 Mitchell St, Colorado Springs, CO 80916, USA',
#  '113 Mitchell St, Colorado Springs, CO 80916, USA',
#  '232-100 Otis St, Colorado Springs, CO 80916, USA',
#  '104 McChord St, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Airport Rd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  '3-1 Rock Creek Canyon Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '1529-1509 Hartford St, Colorado Springs, CO 80906, USA',
#  '1449-1401 Hartford St, Colorado Springs, CO 80906, USA',
#  '2879-2899 Welton Dr, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Wickersham Blvd, Colorado Springs, CO 80906, USA',
#  'San Amels Way, Colorado Springs, CO 80911, USA',
#  '4677-4665 Dancing Light Way, Colorado Springs, CO 80911, USA',
#  '4677-4665 Dancing Light Way, Colorado Springs, CO 80911, USA',
#  'Goldfield Dr, Colorado Springs, CO 80911, USA',
#  'Bradley Rd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '2428-2072 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '1998-1946 Cortez Dr, Colorado Springs, CO 80911, USA',
#  '1939-1999 Hallam Ave, Colorado Springs, CO 80911, USA',
#  '1939-1999 Hallam Ave, Colorado Springs, CO 80911, USA',
#  '598-512 Security Blvd, Colorado Springs, CO 80911, USA',
#  '214-200 Main St, Colorado Springs, CO 80911, USA',
#  'CanAm Hwy, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '9650 Butts Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  '1020 Space Center Dr, Colorado Springs, CO 80915, USA',
#  'Galley Rd, Colorado Springs, CO 80915, USA',
#  '912-600 Conrad St, Colorado Springs, CO 80915, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  '3454-3458 S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  'Unnamed Road, Rock Creek, CO, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Southgate Rd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Lake Ave, Colorado Springs, CO 80905, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '7726-7668 Sistine Ln, Fountain, CO 80817, USA',
#  'Legend Oak Dr, Fountain, CO 80817, USA',
#  '1585 Legend Oak Dr, Fountain, CO 80817, USA',
#  '4614-1322 C & S Rd, Fountain, CO 80817, USA',
#  'Unnamed Road, Fountain, CO 80817, USA',
#  'Fountain Mesa Rd, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '1222 Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  '1601-1613 Cochrane Cir, Fort Carson, CO, USA',
#  '1601-1613 Cochrane Cir, Fort Carson, CO, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80923, USA',
#  'Unnamed Road, Colorado Springs, CO 80923, USA',
#  'Unnamed Road, Colorado Springs, CO 80923, USA',
#  'Unnamed Road, Colorado Springs, CO 80923, USA',
#  '7044 Tutt Blvd, Colorado Springs, CO 80923, USA',
#  'Tutt Blvd, Colorado Springs, CO 80923, USA',
#  '6498-6470 Templeton Gap Rd, Colorado Springs, CO 80923, USA',
#  'Unnamed Road, Colorado Springs, CO 80923, USA',
#  '520-458 US-24, Colorado Springs, CO, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '2480-1358 Barkeley Ave, Fort Carson, CO 80902, USA',
#  '5948-5932 Ware St, Fort Carson, CO 80913, USA',
#  '5866-5844 Ware St, Fort Carson, CO 80913, USA',
#  '3615-3763 Drennan Road, Colorado Springs, CO 80910, USA',
#  '3765-3799 Drennan Road, Colorado Springs, CO 80910, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  '9080 CO-115, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  '9650 Butts Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  '7247-7299 Araia Dr, Fountain, CO 80817, USA',
#  '7305-7351 Willowdale Dr, Fountain, CO 80817, USA',
#  '7305-7351 Willowdale Dr, Fountain, CO 80817, USA',
#  '7398-7374 Willow Pines Pl, Fountain, CO 80817, USA',
#  '7398-7300 Oakshire Way, Fountain, CO 80817, USA',
#  '7398-7300 Oakshire Way, Fountain, CO 80817, USA',
#  '1000-1026 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  '752-720 Comanche Village Dr, Fountain, CO 80817, USA',
#  '418-318 Comanche Village Dr, Fountain, CO 80817, USA',
#  'CanAm Hwy, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '2659 Ardennes St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '5738-5780 S Academy Blvd, Colorado Springs, CO 80916, USA',
#  '5804-5806 S Academy Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '4840 Chiles Ave, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '4984-5024 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5114 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5138-5144 Chiles Ave, Fort Carson, CO 80902, USA',
#  '1407-1401 Burris St, Fort Carson, CO 80913, USA',
#  'Wetzel Ave, Fort Carson, CO 80913, USA',
#  '1907-1825 Carey St, Fort Carson, CO 80913, USA',
#  'Jackpot Dr, Colorado Springs, CO 80922, USA',
#  '5098-4970 Ardley Dr, Colorado Springs, CO 80922, USA',
#  '4769-4823 Ardley Dr, Colorado Springs, CO 80922, USA',
#  'Barnes Rd, Colorado Springs, CO 80920, USA',
#  'Unnamed Road, Colorado Springs, CO 80915, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  '3460-3480 S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  '3-1 Rock Creek Canyon Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  '9650 Butts Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  '4332-4300 Neal Ct, Colorado Springs, CO 80916, USA',
#  '4234-4200 Marlow Cir, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80916, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '2050 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Cordera Crest Ave, Colorado Springs, CO 80908, USA',
#  'Cordera Crest Ave, Colorado Springs, CO 80908, USA',
#  'Old Ranch Rd, Colorado Springs, CO 80908, USA',
#  'Unnamed Road, Colorado Springs, CO 80920, USA',
#  'Unnamed Road, Colorado Springs, CO 80920, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Magrath Ave, Colorado Springs, CO 80906, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1659 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '1804 Prussman Blvd, Fort Carson, CO 80913, USA',
#  '5648-5650 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  '5682-5714 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '1408-1468 Burris St, Fort Carson, CO 80913, USA',
#  '1469-1409 Burris St, Fort Carson, CO 80913, USA',
#  'Wetzel Ave, Fort Carson, CO 80913, USA',
#  '798-760 Descendant Dr, Fountain, CO 80817, USA',
#  '638-600 Descendant Dr, Fountain, CO 80817, USA',
#  'Unnamed Road, Fountain, CO 80817, USA',
#  'CO-16, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Tank Rd, Fort Carson, CO 80913, USA',
#  'S Rockrimmon Blvd, Colorado Springs, CO 80919, USA',
#  'S Rockrimmon Blvd, Colorado Springs, CO 80919, USA',
#  '5446-5492 Tech Center Dr, Colorado Springs, CO 80919, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Magrath Ave, Colorado Springs, CO 80906, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Pomber St, Colorado Springs, CO 80911, USA',
#  'Pomber St, Colorado Springs, CO 80911, USA',
#  '6464-6468 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  'Unnamed Road, Rock Creek, CO, USA',
#  'Light Fighter Dr, Fort Carson, CO 80902, USA',
#  'Light Fighter Dr, Fort Carson, CO 80902, USA',
#  '7848-7846 Just Cause Dr, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Colorado Springs, CO 80909, USA',
#  'Unnamed Road, Colorado Springs, CO 80909, USA',
#  '3701-3747 Portal Dr E, Colorado Springs, CO 80909, USA',
#  '798-700 N Academy Blvd, Colorado Springs, CO 80909, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Utah Beach Dr, Fort Carson, CO 80913, USA',
#  'Utah Beach Dr, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '3729-3701 Westmeadow Dr, Colorado Springs, CO 80906, USA',
#  '746-700 Cheyenne Meadows Rd, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Sheridan Ave, Fort Carson, CO 80913, USA',
#  'Chiles Ave, Fort Carson, CO 80913, USA',
#  'Wayfarer Dr, Colorado Springs, CO 80925, USA',
#  'Wayfarer Dr, Colorado Springs, CO 80925, USA',
#  'Autumn Glen Ave, Colorado Springs, CO 80925, USA',
#  'Mesa Ridge Pkwy, Colorado Springs, CO 80925, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '1222 Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  '1698-1666 Cochrane Cir, Fort Carson, CO 80913, USA',
#  'Sutherland Cir, Fort Carson, CO 80913, USA',
#  '898-870 Uintah St, Colorado Springs, CO 80903, USA',
#  '426-444 Uintah St, Colorado Springs, CO 80905, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Utah Beach Dr, Fort Carson, CO 80913, USA',
#  'Utah Beach Dr, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '3206-3272 Vail Pass Dr, Colorado Springs, CO 80917, USA',
#  '3206-3272 Vail Pass Dr, Colorado Springs, CO 80917, USA',
#  '5471-5599 Whimsical Dr, Colorado Springs, CO 80917, USA',
#  '5471-5599 Whimsical Dr, Colorado Springs, CO 80917, USA',
#  'Rio Vista Dr, Colorado Springs, CO 80917, USA',
#  'S Carefree Cir, Colorado Springs, CO 80922, USA',
#  '520-458 US-24, Colorado Springs, CO, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  '3460-3480 S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  'Unnamed Road, Rock Creek Park, CO, USA',
#  'Wilderness Rd, Fort Carson, CO 80913, USA',
#  '9421-9487 Warfighter Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Spring Grove Way, Colorado Springs, CO 80906, USA',
#  '2728-2798 Springmeadow Dr, Colorado Springs, CO 80906, USA',
#  '101-121 E Cheyenne Mountain Blvd, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Fort Carson, CO 80902, USA',
#  '4098-4050 Astrozon Blvd, Colorado Springs, CO 80916, USA',
#  '3844-3800 Astrozon Blvd, Colorado Springs, CO 80916, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '2659 Ardennes St, Fort Carson, CO 80913, USA',
#  'Ardennes St, Fort Carson, CO 80913, USA',
#  '2643 Ardennes St, Fort Carson, CO 80913, USA',
#  '2050-2000 Piros Dr, Colorado Springs, CO 80915, USA',
#  '2050-2000 Piros Dr, Colorado Springs, CO 80915, USA',
#  '6898-6888 Palmer Park Blvd, Colorado Springs, CO 80915, USA',
#  'CO-21, Colorado Springs, CO 80951, USA',
#  '558-522 CO-21, Colorado Springs, CO 80915, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  'Unnamed Road, Rock Creek Park, CO, USA',
#  'Wilderness Rd, Fort Carson, CO 80913, USA',
#  '9421-9487 Warfighter Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  '12150-12158 Oregon Wagon Trail, Elbert, CO 80106, USA',
#  '12160-12166 Oregon Wagon Trail, Elbert, CO 80106, USA',
#  '11816-11800 Latigo Blvd, Elbert, CO 80106, USA',
#  '11710-11700 US-24, Peyton, CO 80831, USA',
#  'Unnamed Road, Colorado Springs, CO 80915, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  '3454-3458 S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'S 31st St, Colorado Springs, CO 80904, USA',
#  'US-24, Colorado Springs, CO 80905, USA',
#  'US-24, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  '1502-1528 S Tejon St, Colorado Springs, CO 80905, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  'Harr Ave, Fort Carson, CO 80902, USA',
#  '14150-13800 Garrett Rd, Peyton, CO 80831, USA',
#  'US-24, Colorado Springs, CO 80915, USA',
#  'Unnamed Road, Colorado Springs, CO 80951, USA',
#  'Unnamed Road, Colorado Springs, CO 80951, USA',
#  'Unnamed Road, Colorado Springs, CO 80977, USA',
#  'Bradley Rd, Colorado Springs, CO 80925, USA',
#  'Bradley Rd, Colorado Springs, CO 80925, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  'Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Magrath Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fountain, CO 80817, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '1718-2120 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Harr Ave, Fort Carson, CO 80902, USA',
#  '4824-4800 Mcnerney St, Fort Carson, CO 80902, USA',
#  'Kit Carson Dr, Fort Carson, CO 80902, USA',
#  'Kit Carson Dr, Fort Carson, CO 80902, USA',
#  'Syracuse St, Colorado Springs, CO 80911, USA',
#  '671 Syracuse St, Colorado Springs, CO 80911, USA',
#  '698-640 Fay Dr, Colorado Springs, CO 80911, USA',
#  'Syracuse St, Colorado Springs, CO 80911, USA',
#  'Syracuse St, Colorado Springs, CO 80911, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  'Magrath Ave, Colorado Springs, CO 80911, USA',
#  "O'Connell Blvd, Fort Carson, CO 80902, USA",
#  "O'Connell Blvd, Fort Carson, CO 80913, USA",
#  "O'Connell Blvd, Fort Carson, CO 80913, USA",
#  "O'Connell Blvd, Fort Carson, CO 80913, USA",
#  '1492-1498 Michelle Ct, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80910, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '2050 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '4098-4006 Shelley Ave, Colorado Springs, CO 80910, USA',
#  '3980-3900 Shelley Ave, Colorado Springs, CO 80910, USA',
#  '490-498 Ruskin Dr, Colorado Springs, CO 80910, USA',
#  '3820-3808 Airport Rd, Colorado Springs, CO 80910, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '1408-1468 Burris St, Fort Carson, CO 80913, USA',
#  '1469-1409 Burris St, Fort Carson, CO 80913, USA',
#  'Wetzel Ave, Fort Carson, CO 80913, USA',
#  '1907-1825 Carey St, Fort Carson, CO 80913, USA',
#  '2-30 S Murray Blvd, Colorado Springs, CO 80916, USA',
#  '110-174 S Murray Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Abbot St, Fort Carson, CO 80913, USA',
#  'Abbot St, Fort Carson, CO 80913, USA',
#  '1528-1616 Cheyenne Blvd, Colorado Springs, CO 80906, USA',
#  '1615-1601 W Cheyenne Rd, Colorado Springs, CO 80906, USA',
#  '1615-1601 W Cheyenne Rd, Colorado Springs, CO 80906, USA',
#  '1545-1541 Mesa Ave, Colorado Springs, CO 80906, USA',
#  '1545-1541 Mesa Ave, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '8-78 Holly Ave, Colorado Springs, CO 80906, USA',
#  '9 State Hwy 122, Colorado Springs, CO 80906, USA',
#  '21-27 State Hwy 122, Colorado Springs, CO 80906, USA',
#  '377-389 State Hwy 122, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  '1505 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Martinez St, Fort Carson, CO 80913, USA',
#  'Nelson Blvd, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '4398-4300 Conquista Dr, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80910, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  '3-1 Rock Creek Canyon Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Fort Carson, CO 80913, USA',
#  '9421-9487 Warfighter Rd, Colorado Springs, CO 80926, USA',
#  'Broadmoor Bluffs Dr, Colorado Springs, CO 80906, USA',
#  'Broadmoor Bluffs Dr, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  '1505 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Picket St, Fort Carson, CO 80913, USA',
#  'Sanders View, Colorado Springs, CO 80916, USA',
#  '1274-1280 S Murray Blvd, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80916, USA',
#  'S Chelton Rd, Colorado Springs, CO 80910, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Magrath Ave, Fort Carson, CO 80913, USA',
#  '6579-6519 Stingray Ln, Colorado Springs, CO 80925, USA',
#  'Old Glory Dr, Colorado Springs, CO 80925, USA',
#  'Fontaine Blvd, Colorado Springs, CO 80911, USA',
#  'Mesa Ridge Pkwy, Colorado Springs, CO 80925, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '699-693 W Cheyenne Rd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '1916-1926 CanAm Hwy, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  '1505 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Martinez St, Fort Carson, CO 80913, USA',
#  'Nelson Blvd, Fort Carson, CO 80913, USA',
#  'Wetzel Ave, Fort Carson, CO 80913, USA',
#  'Camino Del Rey, Fountain, CO 80817, USA',
#  '2134-2198 Cll Fontana, Fountain, CO 80817, USA',
#  'C & S Rd, Fountain, CO 80817, USA',
#  'Duckwood Rd, Fountain, CO 80817, USA',
#  'CanAm Hwy, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '1222 Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  '1688-1666 Cochrane Cir, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Aliso Dr, Colorado Springs, CO 80925, USA',
#  'Lamprey Dr, Colorado Springs, CO 80925, USA',
#  'Lamprey Dr, Colorado Springs, CO 80925, USA',
#  '7801-7849 Fontaine Blvd, Colorado Springs, CO 80925, USA',
#  'Mesa Ridge Pkwy, Colorado Springs, CO 80925, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '1222 Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  '1698-1666 Cochrane Cir, Fort Carson, CO 80913, USA',
#  'Sutherland Cir, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '498-258 S Log Rd, Calhan, CO 80808, USA',
#  'CO-94, Colorado Springs, CO 80930, USA',
#  '14852-14800 Curtis Rd, Colorado Springs, CO 80928, USA',
#  'Unnamed Road, Colorado Springs, CO 80925, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Walmart Hts, Colorado Springs, CO 80906, USA',
#  '5648-5650 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  '5682-5714 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  'Prussman Blvd, Fort Carson, CO 80913, USA',
#  '1804 Prussman Blvd, Fort Carson, CO 80913, USA',
#  'Wetzel Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Walmart Hts, Colorado Springs, CO 80906, USA',
#  '5648-5650 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Sheridan Ave, Fort Carson, CO 80902, USA',
#  '3631-3663 Rebecca Ln, Colorado Springs, CO 80917, USA',
#  '3334-3300 N Academy Blvd, Colorado Springs, CO 80917, USA',
#  '3800-3908 S Academy Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '2050 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Minick Ave, Fort Carson, CO 80913, USA',
#  '6600-6698 E Columbine Dr, Air Force Academy, CO 80840, USA',
#  'E Pine Loop, Air Force Academy, CO 80840, USA',
#  'Carlton Dr, Air Force Academy, CO 80840, USA',
#  'Pine Dr, Air Force Academy, CO 80840, USA',
#  'S Gate Blvd, Colorado Springs, CO 80920, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Khe Sanh St, Fort Carson, CO 80913, USA',
#  '2130 Khe Sanh St, Fort Carson, CO 80913, USA',
#  '904-900 Pacific Hills Point, Colorado Springs, CO 80906, USA',
#  'Pacific Hills Point, Colorado Springs, CO 80906, USA',
#  '4003-3935 Westmeadow Dr, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  '9080 CO-115, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80924, USA',
#  'Prominent Point, Colorado Springs, CO 80924, USA',
#  'Prominent Point, Colorado Springs, CO 80924, USA',
#  'Grand Cordera Pkwy, Colorado Springs, CO 80924, USA',
#  'Briargate Pkwy, Colorado Springs, CO 80920, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Magrath Ave, Colorado Springs, CO 80906, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  "O'Connell Blvd, Fort Carson, CO 80913, USA",
#  '17th St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '4215 Cheyenne Mountain Zoo Rd, Colorado Springs, CO 80906, USA',
#  '3878-3898 Cheyenne Mountain Zoo Rd, Colorado Springs, CO 80906, USA',
#  '117-113 Marland Rd S, Colorado Springs, CO 80906, USA',
#  '229-201 W Cheyenne Mountain Blvd, Colorado Springs, CO 80906, USA',
#  'W Cheyenne Mountain Blvd, Colorado Springs, CO 80906, USA',
#  '49-99 E Cheyenne Mountain Blvd, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  'Harr Ave, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Fort Carson, CO 80902, USA',
#  '7399-7389 Mekong St, Fort Carson, CO 80913, USA',
#  '7345-7317 Mekong St, Fort Carson, CO, USA',
#  '7313-7301 Mekong St, Fort Carson, CO 80913, USA',
#  '7298-7238 Attu Dr, Fort Carson, CO 80902, USA',
#  '7222-7226 Attu Dr, Fort Carson, CO 80902, USA',
#  '4894-4700 Pikes Peak Hwy, Cascade, CO 80809, USA',
#  '4598-4470 Fountain Ave, Cascade, CO 80809, USA',
#  'US-24, Colorado Springs, CO 80905, USA',
#  'US-24, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  '1502-1528 S Tejon St, Colorado Springs, CO 80905, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  'Sam Houston Loop, Fort Carson, CO 80902, USA',
#  '6454-6422 Bastogne Dr, Fort Carson, CO 80902, USA',
#  '6454-6422 Bastogne Dr, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '1538-1474 E Cheyenne Mountain Blvd, Colorado Springs, CO 80906, USA',
#  'CanAm Hwy, Colorado Springs, CO 80906, USA',
#  '746-700 Cheyenne Meadows Rd, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  'Unnamed Road, Rock Creek, CO, USA',
#  'Bayonet Cir, Fort Carson, CO 80913, USA',
#  '7938-7910 Bayonet Cir, Fort Carson, CO 80913, USA',
#  '7938-7910 Bayonet Cir, Fort Carson, CO 80913, USA',
#  '6498-6400 Eliot Ave, Colorado Springs, CO 80911, USA',
#  '6498-6400 Eliot Ave, Colorado Springs, CO 80911, USA',
#  '521 Squire St, Colorado Springs, CO 80911, USA',
#  '500-514 Raemar Dr, Colorado Springs, CO 80911, USA',
#  '556-610 Raemar Dr, Colorado Springs, CO 80911, USA',
#  '408-328 Jersey Ln, Colorado Springs, CO 80911, USA',
#  '660 Syracuse St, Colorado Springs, CO 80911, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Nelson Blvd, Fort Carson, CO 80913, USA',
#  'Nelson Blvd, Fort Carson, CO 80913, USA',
#  '6053-6001 Cowpoke Rd, Colorado Springs, CO 80924, USA',
#  '8198-7934 Black Forest Rd, Colorado Springs, CO 80908, USA',
#  '2950-2900 E Woodmen Rd, Colorado Springs, CO 80920, USA',
#  'Unnamed Road, Colorado Springs, CO 80919, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Magrath Ave, Fort Carson, CO 80913, USA',
#  'Magrath Ave, Fort Carson, CO 80913, USA',
#  'Charter Oak Ranch Rd, Fort Carson, CO 80913, USA',
#  'Mountain View Apartment, Colorado Springs, CO 80906, USA',
#  'Mountain View Apartment, Colorado Springs, CO 80906, USA',
#  '4840 Chiles Ave, Fort Carson, CO 80902, USA',
#  '4928-4940 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5026-5056 Chiles Ave, Fort Carson, CO 80902, USA',
#  '5114 Chiles Ave, Fort Carson, CO 80902, USA',
#  '1501-1599 Evans St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '7110 Cross Creek, Fountain, CO 80817, USA',
#  'Cross Creek, Fountain, CO 80817, USA',
#  '7979 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  'CO-16, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '9650 Butts Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'Son Tay Rd, Colorado Springs, CO 80913, USA',
#  'S Perry St, Castle Rock, CO 80104, USA',
#  'Plum Creek Pkwy, Castle Rock, CO 80104, USA',
#  '1384-854 Frontage Rd, Castle Rock, CO 80104, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  '1418-1424 S Tejon St, Colorado Springs, CO 80905, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  'Unnamed Road, Rock Creek Park, CO, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  '9650 Butts Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1659 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Prussman Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Iron Fighter Dr, Fort Carson, CO 80913, USA',
#  '1598-1538 Security Blvd, Colorado Springs, CO 80911, USA',
#  '1398-1300 Security Blvd, Colorado Springs, CO 80911, USA',
#  '1398-1300 Security Blvd, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '2659 Ardennes St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Walmart Hts, Colorado Springs, CO 80906, USA',
#  '5648-5650 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  '5682-5714 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '1718-2120 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Harr Ave, Fort Carson, CO 80902, USA',
#  'Harr Ave, Fort Carson, CO 80902, USA',
#  'Harr Ave, Fort Carson, CO 80902, USA',
#  '625-615 Raemar Dr, Colorado Springs, CO 80911, USA',
#  '625-615 Raemar Dr, Colorado Springs, CO 80911, USA',
#  '445-499 Jersey Ln, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80923, USA',
#  '7455 Test Dr, Colorado Springs, CO 80923, USA',
#  '2950-2900 E Woodmen Rd, Colorado Springs, CO 80920, USA',
#  'Unnamed Road, Colorado Springs, CO 80919, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  'Unnamed Road, Colorado Springs, CO 80905, USA',
#  '1502-1528 S Tejon St, Colorado Springs, CO 80905, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Grove St, Fort Carson, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '5800-5898 Normandy Rd, Fort Carson, CO 80902, USA',
#  '5800-5898 Normandy Rd, Fort Carson, CO 80902, USA',
#  '4775-4763 Lydia Grove, Colorado Springs, CO 80916, USA',
#  '4775-4763 Lydia Grove, Colorado Springs, CO 80916, USA',
#  'Airport Rd, Colorado Springs, CO 80910, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Goodfellow St, Colorado Springs, CO 80914, USA',
#  'Ent Ave, Colorado Springs, CO 80914, USA',
#  'Paine Street, Colorado Springs, CO 80914, USA',
#  'Unnamed Road, Colorado Springs, CO 80914, USA',
#  'Unnamed Road, Colorado Springs, CO 80914, USA',
#  'Airport Rd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  '3454-3458 S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'JL Ranch Heights Rd, Colorado Springs, CO 80902, USA',
#  '9080 CO-115, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  '9650 Butts Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80926, USA',
#  'E Hwy 105, Monument, CO 80132, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Magrath Ave, Colorado Springs, CO 80906, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  "O'Connell Blvd, Fort Carson, CO 80913, USA",
#  '1120 Long St, Fort Carson, CO 80913, USA',
#  '1120 Long St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80902, USA',
#  'S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'US-87, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '2659 Ardennes St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Walmart Hts, Colorado Springs, CO 80906, USA',
#  '5648-5650 S Academy Blvd, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  'Bastogne Dr, Fort Carson, CO 80902, USA',
#  '6454-6422 Bastogne Dr, Fort Carson, CO 80902, USA',
#  '7835-8063 Campground Dr, Fountain, CO 80817, USA',
#  'Squirrel Creek Rd, Fountain, CO 80817, USA',
#  'Squirrel Creek Rd, Fountain, CO 80817, USA',
#  '8294-8242 C & S Rd, Fountain, CO 80817, USA',
#  '2148-2198 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  '8299-8201 Silver Glen Dr, Fountain, CO 80817, USA',
#  '8287-8191 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  '1652-1634 Cochrane Cir, Fort Carson, CO 80913, USA',
#  '5739-5731 Kittery Dr, Colorado Springs, CO 80911, USA',
#  'Crawford Ave, Colorado Springs, CO 80911, USA',
#  'Grinnell Blvd, Colorado Springs, CO 80911, USA',
#  'Fontaine Blvd, Colorado Springs, CO 80911, USA',
#  '298-116 Dean Dr, Colorado Springs, CO 80911, USA',
#  '7380-7456 CanAm Hwy, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Wilderness Rd, Colorado Springs, CO 80926, USA',
#  'Unnamed Road, Colorado Springs, CO 80913, USA',
#  '1901 Louise Ln, Colorado Springs, CO 80910, USA',
#  'Louise Ln, Colorado Springs, CO 80910, USA',
#  'Monterey Rd, Colorado Springs, CO 80910, USA',
#  'Monterey Rd, Colorado Springs, CO 80910, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '396-390 State Hwy 122, Colorado Springs, CO 80906, USA',
#  'CO-115, Colorado Springs, CO 80902, USA',
#  'Nelson Blvd, Fort Carson, CO 80902, USA',
#  '7300-7398 Sheridan Ave, Fort Carson, CO 80902, USA',
#  '1505 Sheridan Ave, Fort Carson, CO 80902, USA',
#  'Sheridan Ave, Fort Carson, CO 80913, USA',
#  'Prussman Blvd, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  '4840 Chiles Ave, Fort Carson, CO 80902, USA',
#  'Funk Ave, Fort Carson, CO 80902, USA',
#  'Funk Ave, Fort Carson, CO 80902, USA',
#  '4302-4318 Inchon Cir, Fort Carson, CO 80902, USA',
#  '200-298 Selfridge St, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Airport Rd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'S Powers Blvd, Colorado Springs, CO 80916, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  'Milton E Proby Pkwy, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80911, USA',
#  'Unnamed Road, Colorado Springs, CO 80906, USA',
#  'Unnamed Road, Colorado Springs, CO 80916, USA',
#  '900 Magrath Ave, Fort Carson, CO, USA',
#  '1580-1656 Barkeley Ave, Fort Carson, CO 80913, USA',
#  '1718-2120 Barkeley Ave, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '17th St, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  '7879-8063 Firecracker Trail, Fountain, CO 80817, USA',
#  'Unnamed Road, Fountain, CO 80817, USA',
#  'Squirrel Creek Rd, Fountain, CO 80817, USA',
#  'Squirrel Creek Rd, Fountain, CO 80817, USA',
#  'Link Rd, Fountain, CO 80817, USA',
#  '2148-2198 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  '8299-8201 Silver Glen Dr, Fountain, CO 80817, USA',
#  '8287-8191 Fountain Mesa Rd, Fountain, CO 80817, USA',
#  'CO-16, Colorado Springs, CO 80911, USA',
#  '3702-3703 Magrath Ave, Colorado Springs, CO 80911, USA',
#  'Specker Ave, Fort Carson, CO 80913, USA',
#  '1222 Specker Ave, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80913, USA',
#  'Titus Blvd, Fort Carson, CO 80902, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  'Unnamed Road, Fort Carson, CO 80913, USA',
#  ...]

# %% [markdown]
# #### Clean Address data

# %%
import re
# Unnamed Road from data
unknown_road = 'Unnamed Road'
# function to clean raw address to only show street name
def clean_address(address):
    sliced_address = []
    for i in address:
        address_split = i.split(',')
        road_name = address_split[0]
        if unknown_road not in road_name:
            raw_road = road_name.split(" ",1)
            # check first string contains only digits and - to remove
            if bool(re.search("^[0-9_-]*$", raw_road[0])):
                sliced_address.append(raw_road[1])
            else:
                sliced_address.append(road_name)
    return sliced_address

# %%
# clean address data to obtain concise road name (sliced address)
sliced_address = clean_address(address)
sliced_address
# Out:
# ['Astrozon Blvd',
#  'Astrozon Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Nelson Blvd',
#  'Martinez St',
#  'Coleman St',
#  'Broadmoor Bluffs Dr',
#  'Broadmoor Bluffs Dr',
#  'S Academy Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Woodfill Rd',
#  'St Lo Cir',
#  'St Lo Cir',
#  'Pikes Peak Ave',
#  'Pikes Peak Ave',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'De La Vista St',
#  'Drury Ln',
#  'Drury Ln',
#  'Quebec St',
#  'Syracuse St',
#  'Fay Dr',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Prussman Blvd',
#  'Prussman Blvd',
#  'Legend Oak Dr',
#  'Legend Oak Dr',
#  'C & S Rd',
#  'Fountain Mesa Rd',
#  'CO-16',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Spring Bluff Rd',
#  'Spring Bluff Rd',
#  'Delta Dr',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Ellis St',
#  'Ellis St',
#  'Kearsarge Dr',
#  'Kearsarge Dr',
#  'Winnicut Dr',
#  'S Marksheffel Rd',
#  'Mesa Ridge Pkwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Cochrane Cir',
#  'Cheyenne Meadows Rd',
#  'Cheyenne Meadows Rd',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Mitchell St',
#  'Mitchell St',
#  'Otis St',
#  'McChord St',
#  'Airport Rd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'Rock Creek Canyon Rd',
#  'Wilderness Rd',
#  'Hartford St',
#  'Hartford St',
#  'Welton Dr',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Wickersham Blvd',
#  'San Amels Way',
#  'Dancing Light Way',
#  'Dancing Light Way',
#  'Goldfield Dr',
#  'Bradley Rd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Cortez Dr',
#  'Hallam Ave',
#  'Hallam Ave',
#  'Security Blvd',
#  'Main St',
#  'CanAm Hwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Butts Rd',
#  'Space Center Dr',
#  'Galley Rd',
#  'Conrad St',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'Titus Blvd',
#  'Southgate Rd',
#  'Lake Ave',
#  'US-87',
#  'Magrath Ave',
#  'Sistine Ln',
#  'Legend Oak Dr',
#  'Legend Oak Dr',
#  'C & S Rd',
#  'Fountain Mesa Rd',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Cochrane Cir',
#  'Cochrane Cir',
#  'Tutt Blvd',
#  'Tutt Blvd',
#  'Templeton Gap Rd',
#  'US-24',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Ware St',
#  'Ware St',
#  'Drennan Road',
#  'Drennan Road',
#  'JL Ranch Heights Rd',
#  'CO-115',
#  'Wilderness Rd',
#  'Wilderness Rd',
#  'Butts Rd',
#  'Araia Dr',
#  'Willowdale Dr',
#  'Willowdale Dr',
#  'Willow Pines Pl',
#  'Oakshire Way',
#  'Oakshire Way',
#  'Fountain Mesa Rd',
#  'Comanche Village Dr',
#  'Comanche Village Dr',
#  'CanAm Hwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Ardennes St',
#  'S Academy Blvd',
#  'S Academy Blvd',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Burris St',
#  'Wetzel Ave',
#  'Carey St',
#  'Jackpot Dr',
#  'Ardley Dr',
#  'Ardley Dr',
#  'Barnes Rd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'Rock Creek Canyon Rd',
#  'Wilderness Rd',
#  'Wilderness Rd',
#  'Butts Rd',
#  'Neal Ct',
#  'Marlow Cir',
#  'S Chelton Rd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Cordera Crest Ave',
#  'Cordera Crest Ave',
#  'Old Ranch Rd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Prussman Blvd',
#  'S Academy Blvd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Burris St',
#  'Burris St',
#  'Wetzel Ave',
#  'Descendant Dr',
#  'Descendant Dr',
#  'CO-16',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Tank Rd',
#  'S Rockrimmon Blvd',
#  'S Rockrimmon Blvd',
#  'Tech Center Dr',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Pomber St',
#  'Pomber St',
#  'S Academy Blvd',
#  'S Academy Blvd',
#  'JL Ranch Heights Rd',
#  'Light Fighter Dr',
#  'Light Fighter Dr',
#  'Just Cause Dr',
#  'Portal Dr E',
#  'N Academy Blvd',
#  'S Academy Blvd',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Utah Beach Dr',
#  'Utah Beach Dr',
#  'Westmeadow Dr',
#  'Cheyenne Meadows Rd',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Chiles Ave',
#  'Wayfarer Dr',
#  'Wayfarer Dr',
#  'Autumn Glen Ave',
#  'Mesa Ridge Pkwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Cochrane Cir',
#  'Sutherland Cir',
#  'Uintah St',
#  'Uintah St',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Utah Beach Dr',
#  'Utah Beach Dr',
#  'Vail Pass Dr',
#  'Vail Pass Dr',
#  'Whimsical Dr',
#  'Whimsical Dr',
#  'Rio Vista Dr',
#  'S Carefree Cir',
#  'US-24',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'Wilderness Rd',
#  'Warfighter Rd',
#  'Spring Grove Way',
#  'Springmeadow Dr',
#  'E Cheyenne Mountain Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Astrozon Blvd',
#  'Astrozon Blvd',
#  'S Academy Blvd',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Ardennes St',
#  'Ardennes St',
#  'Ardennes St',
#  'Piros Dr',
#  'Piros Dr',
#  'Palmer Park Blvd',
#  'CO-21',
#  'CO-21',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'Wilderness Rd',
#  'Warfighter Rd',
#  'Oregon Wagon Trail',
#  'Oregon Wagon Trail',
#  'Latigo Blvd',
#  'US-24',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'CO-115',
#  'Nelson Blvd',
#  'S 31st St',
#  'US-24',
#  'US-24',
#  'S Tejon St',
#  'CO-115',
#  'Nelson Blvd',
#  'Harr Ave',
#  'Garrett Rd',
#  'US-24',
#  'Bradley Rd',
#  'Bradley Rd',
#  'CO-16',
#  'CO-16',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Harr Ave',
#  'Mcnerney St',
#  'Kit Carson Dr',
#  'Kit Carson Dr',
#  'Syracuse St',
#  'Syracuse St',
#  'Fay Dr',
#  'Syracuse St',
#  'Syracuse St',
#  'CO-16',
#  'Magrath Ave',
#  "O'Connell Blvd",
#  "O'Connell Blvd",
#  "O'Connell Blvd",
#  "O'Connell Blvd",
#  'Michelle Ct',
#  'S Chelton Rd',
#  'S Chelton Rd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Shelley Ave',
#  'Shelley Ave',
#  'Ruskin Dr',
#  'Airport Rd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Burris St',
#  'Burris St',
#  'Wetzel Ave',
#  'Carey St',
#  'S Murray Blvd',
#  'S Murray Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Abbot St',
#  'Abbot St',
#  'Cheyenne Blvd',
#  'W Cheyenne Rd',
#  'W Cheyenne Rd',
#  'Mesa Ave',
#  'Mesa Ave',
#  'Holly Ave',
#  'State Hwy 122',
#  'State Hwy 122',
#  'State Hwy 122',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Martinez St',
#  'Nelson Blvd',
#  'Specker Ave',
#  'Conquista Dr',
#  'S Chelton Rd',
#  'S Chelton Rd',
#  'S Academy Blvd',
#  'JL Ranch Heights Rd',
#  'Rock Creek Canyon Rd',
#  'Wilderness Rd',
#  'Warfighter Rd',
#  'Broadmoor Bluffs Dr',
#  'Broadmoor Bluffs Dr',
#  'S Academy Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Picket St',
#  'Sanders View',
#  'S Murray Blvd',
#  'S Chelton Rd',
#  'S Chelton Rd',
#  'S Academy Blvd',
#  'US-87',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Stingray Ln',
#  'Old Glory Dr',
#  'Fontaine Blvd',
#  'Mesa Ridge Pkwy',
#  'CO-16',
#  'Magrath Ave',
#  'W Cheyenne Rd',
#  'CanAm Hwy',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Martinez St',
#  'Nelson Blvd',
#  'Wetzel Ave',
#  'Camino Del Rey',
#  'Cll Fontana',
#  'C & S Rd',
#  'Duckwood Rd',
#  'CanAm Hwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Cochrane Cir',
#  'Aliso Dr',
#  'Lamprey Dr',
#  'Lamprey Dr',
#  'Fontaine Blvd',
#  'Mesa Ridge Pkwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Cochrane Cir',
#  'Sutherland Cir',
#  'S Log Rd',
#  'CO-94',
#  'Curtis Rd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Walmart Hts',
#  'S Academy Blvd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Prussman Blvd',
#  'Prussman Blvd',
#  'Wetzel Ave',
#  'Walmart Hts',
#  'S Academy Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Rebecca Ln',
#  'N Academy Blvd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Minick Ave',
#  'E Columbine Dr',
#  'E Pine Loop',
#  'Carlton Dr',
#  'Pine Dr',
#  'S Gate Blvd',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Khe Sanh St',
#  'Khe Sanh St',
#  'Pacific Hills Point',
#  'Pacific Hills Point',
#  'Westmeadow Dr',
#  'JL Ranch Heights Rd',
#  'CO-115',
#  'Wilderness Rd',
#  'Prominent Point',
#  'Prominent Point',
#  'Grand Cordera Pkwy',
#  'Briargate Pkwy',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Magrath Ave',
#  "O'Connell Blvd",
#  '17th St',
#  'Cheyenne Mountain Zoo Rd',
#  'Cheyenne Mountain Zoo Rd',
#  'Marland Rd S',
#  'W Cheyenne Mountain Blvd',
#  'W Cheyenne Mountain Blvd',
#  'E Cheyenne Mountain Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Harr Ave',
#  'Mekong St',
#  'Mekong St',
#  'Mekong St',
#  'Attu Dr',
#  'Attu Dr',
#  'Pikes Peak Hwy',
#  'Fountain Ave',
#  'US-24',
#  'US-24',
#  'S Tejon St',
#  'CO-115',
#  'Nelson Blvd',
#  'Sam Houston Loop',
#  'Bastogne Dr',
#  'Bastogne Dr',
#  'E Cheyenne Mountain Blvd',
#  'CanAm Hwy',
#  'Cheyenne Meadows Rd',
#  'JL Ranch Heights Rd',
#  'Bayonet Cir',
#  'Bayonet Cir',
#  'Bayonet Cir',
#  'Eliot Ave',
#  'Eliot Ave',
#  'Squire St',
#  'Raemar Dr',
#  'Raemar Dr',
#  'Jersey Ln',
#  'Syracuse St',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Nelson Blvd',
#  'Nelson Blvd',
#  'Cowpoke Rd',
#  'Black Forest Rd',
#  'E Woodmen Rd',
#  'US-87',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Charter Oak Ranch Rd',
#  'Mountain View Apartment',
#  'Mountain View Apartment',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Chiles Ave',
#  'Evans St',
#  'Cross Creek',
#  'Cross Creek',
#  'Fountain Mesa Rd',
#  'CO-16',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Butts Rd',
#  'Son Tay Rd',
#  'S Perry St',
#  'Plum Creek Pkwy',
#  'Frontage Rd',
#  'S Tejon St',
#  'JL Ranch Heights Rd',
#  'Wilderness Rd',
#  'Wilderness Rd',
#  'Butts Rd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Prussman Blvd',
#  'Iron Fighter Dr',
#  'Security Blvd',
#  'Security Blvd',
#  'Security Blvd',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Ardennes St',
#  'Walmart Hts',
#  'S Academy Blvd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Harr Ave',
#  'Harr Ave',
#  'Harr Ave',
#  'Raemar Dr',
#  'Raemar Dr',
#  'Jersey Ln',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Wilderness Rd',
#  'Test Dr',
#  'E Woodmen Rd',
#  'S Tejon St',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Grove St',
#  'Nelson Blvd',
#  'Normandy Rd',
#  'Normandy Rd',
#  'Lydia Grove',
#  'Lydia Grove',
#  'Airport Rd',
#  'Magrath Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Goodfellow St',
#  'Ent Ave',
#  'Paine Street',
#  'Airport Rd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'CO-115',
#  'Wilderness Rd',
#  'Wilderness Rd',
#  'Butts Rd',
#  'E Hwy 105',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Magrath Ave',
#  "O'Connell Blvd",
#  'Long St',
#  'Long St',
#  'S Academy Blvd',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Ardennes St',
#  'Walmart Hts',
#  'S Academy Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Bastogne Dr',
#  'Bastogne Dr',
#  'Campground Dr',
#  'Squirrel Creek Rd',
#  'Squirrel Creek Rd',
#  'C & S Rd',
#  'Fountain Mesa Rd',
#  'Silver Glen Dr',
#  'Fountain Mesa Rd',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Cochrane Cir',
#  'Kittery Dr',
#  'Crawford Ave',
#  'Grinnell Blvd',
#  'Fontaine Blvd',
#  'Dean Dr',
#  'CanAm Hwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Wilderness Rd',
#  'Louise Ln',
#  'Louise Ln',
#  'Monterey Rd',
#  'Monterey Rd',
#  'State Hwy 122',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Prussman Blvd',
#  'Chiles Ave',
#  'Funk Ave',
#  'Funk Ave',
#  'Inchon Cir',
#  'Selfridge St',
#  'Airport Rd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  '17th St',
#  'Firecracker Trail',
#  'Squirrel Creek Rd',
#  'Squirrel Creek Rd',
#  'Link Rd',
#  'Fountain Mesa Rd',
#  'Silver Glen Dr',
#  'Fountain Mesa Rd',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Lindbergh Rd',
#  'Mesa Top Dr',
#  'Mesa Top Dr',
#  'Baptist Rd',
#  'Baptist Rd',
#  'Baptist Rd',
#  'US-87',
#  'Magrath Ave',
#  'Titus Blvd',
#  'Pond Terrace',
#  'Lake Ave',
#  'Lake Ave',
#  'Comanche Village Dr',
#  'Comanche Village Dr',
#  'CanAm Hwy',
#  'CO-16',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Citadel Dr N',
#  'N Academy Blvd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  "O'Connell Blvd",
#  "O'Connell Blvd",
#  'Jimmy Camp Rd',
#  'CanAm Hwy',
#  'CanAm Hwy',
#  'US-87',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Hourglass Dr',
#  'Hourglass Dr',
#  'Hourglass Dr',
#  'Kearsarge Dr',
#  'Kearsarge Dr',
#  'Winnicut Dr',
#  'Mesa Ridge Pkwy',
#  'S Powers Blvd',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Wilderness Rd',
#  'Wilderness Rd',
#  'Warfighter Rd',
#  'Sisters Grove',
#  'Sisters Grove',
#  'E Woodmen Rd',
#  'E Woodmen Rd',
#  'E Woodmen Rd',
#  'E Woodmen Rd',
#  'US-87',
#  'Magrath Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Barkeley Ave',
#  'Fencer Rd',
#  'Marabou Way',
#  'Bradley Rd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Harr Ave',
#  'Mcnerney St',
#  'Mcnerney St',
#  'Kit Carson Dr',
#  'Kit Carson Dr',
#  'Pacific Hills Point',
#  'Pacific Hills Point',
#  'Westmeadow Dr',
#  'Westmeadow Dr',
#  'Capistrano Point',
#  'Harr Ave',
#  'Harr Ave',
#  'Ellis St',
#  'Asher Hts',
#  'Asher Hts',
#  'Integrity Center Point',
#  'Barnes Rd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'JL Ranch Heights Rd',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Research Pkwy',
#  'Research Pkwy',
#  'Research Pkwy',
#  'Research Pkwy',
#  'CO-21',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'S Powers Blvd',
#  'Milton E Proby Pkwy',
#  'Magrath Ave',
#  "O'Connell Blvd",
#  'Pmi Access Rd',
#  'Pueblo Blvd',
#  'CO-47',
#  'CO-47',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Harr Ave',
#  'Harr Ave',
#  'Red Dawn Dr',
#  'Red Dawn Dr',
#  'Ridge Dr',
#  'Silverqueen Rd',
#  'Silverqueen Rd',
#  'Eagleridge Cir',
#  'Eagleridge Cir',
#  'N Elizabeth St',
#  'Eagleridge Blvd',
#  'CanAm Hwy',
#  'Santa Fe Ave',
#  'Eassayons Rd',
#  'Butts Rd',
#  'Butts Rd',
#  'Warfighter Rd',
#  'Warfighter Rd',
#  'Warfighter Rd',
#  'Venetucci Blvd',
#  'Venetucci Blvd',
#  'Venetucci Blvd',
#  'S Academy Blvd',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Ardennes St',
#  'Descendant Dr',
#  'Descendant Dr',
#  'Fountain Mesa Rd',
#  'Fountain Mesa Rd',
#  'CO-16',
#  'Magrath Ave',
#  'Tenderfoot Hill Rd',
#  'CanAm Hwy',
#  'Cheyenne Meadows Rd',
#  'JL Ranch Heights Rd',
#  'Rock Creek Canyon Rd',
#  'Wilderness Rd',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Utah Beach Dr',
#  'Utah Beach Dr',
#  'Venetucci Blvd',
#  'Venetucci Blvd',
#  'S Academy Blvd',
#  'JL Ranch Heights Rd',
#  'Wilderness Rd',
#  'Middle Bay Way',
#  'E Ohio Ave',
#  'CanAm Hwy',
#  'S Fountain St',
#  'US-87',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Attu Dr',
#  'Fountain Mesa Rd',
#  'Mesa Rd',
#  'Mesa Rd',
#  'Mesa Rd',
#  'CO-16',
#  'Magrath Ave',
#  'Nelson Blvd',
#  'Nelson Blvd',
#  'Bays Water Dr',
#  'Bays Water Dr',
#  'Family Pl',
#  'Austin Bluffs Pkwy',
#  'Briargate Pkwy',
#  'US-87',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'Titus Blvd',
#  'Butts Rd',
#  'Walmart Hts',
#  'Venetucci Blvd',
#  'CO-115',
#  'Nelson Blvd',
#  'Harr Ave',
#  'Benning Street',
#  'Benning Street',
#  'E Jackson St',
#  'E Jackson St',
#  'N Cascade Ave',
#  'N Cascade Ave',
#  'Uintah St',
#  'S Tejon St',
#  'CO-115',
#  'Nelson Blvd',
#  'Harr Ave',
#  'Jimmy Camp Rd',
#  'E Ohio Ave',
#  'CanAm Hwy',
#  'Santa Fe Ave',
#  'Eassayons Rd',
#  'Butts Rd',
#  'Butts Rd',
#  'Brylie Way',
#  'Brylie Way',
#  'Dancing Light Way',
#  'Dancing Light Way',
#  'Goldfield Dr',
#  'Bradley Rd',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Cheyenne Meadows Rd',
#  'CO-115',
#  'Nelson Blvd',
#  'Grove St',
#  'Coleman St',
#  'Nelson Blvd',
#  'Chiles Ave',
#  'Lashelle Ave',
#  'Lashelle Way',
#  'Lashelle Way',
#  'B St',
#  'Magrath Ave',
#  'Titus Blvd',
#  'Titus Blvd',
#  'Specker Ave',
#  'Specker Ave',
#  'Ardennes St',
#  '5th Ave',
#  'Grant St',
#  '7th St',
#  'CO-115',
#  'Nelson Blvd',
#  'Sheridan Ave',
#  'Sheridan Ave',
#  'Elmhurst Dr',
#  'Willow Pines Pl',
#  'Oakshire Way',
#  'Oakshire Way',
#  'Fountain Mesa Rd',
#  'Comanche Village Dr',
#  'Comanche Village Dr',
#  'CanAm Hwy',
#  'CO-16',
#  'Magrath Ave',
#  'Specker Ave',
#  'Specker Ave',
#  'S Academy Blvd',
#  'Chiles Ave',
#  'Funk Ave',
#  'Funk Ave',
#  'Willett Cir',
#  'Cheyenne Meadows Rd',
#  'Crestridge Ave',
#  'Catalina Dr',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Barkeley Ave',
#  'Abbot Ln',
#  'Abbot Ln',
#  'S 8th St',
#  'US-24',
#  'S Academy Blvd',
#  'Magrath Ave',
#  'Magrath Ave',
#  'Barkeley Ave',
#  'Walmart Hts',
#  'Venetucci Blvd',
#  ...]

# %%
len(address)
# Out:
# 9973

# %%
len(sliced_address)
# Out:
# 7108

# %%
len(ei_street_count)
# Out:
# 594

# %%
from collections import Counter

ei_street_count = Counter(sliced_address)

print('Most commonly utilized road to Fort Carson(EI):\n')
for street, count in ei_street_count.most_common():
    print('Street: '+street.ljust(20), 'Count: '+str(count).ljust(20))
# Out:
# Most commonly utilized road to Fort Carson(EI):
#
# Street: Magrath Ave          Count: 611
# Street: Specker Ave          Count: 332
# Street: Nelson Blvd          Count: 261
# Street: CO-16                Count: 260
# Street: Titus Blvd           Count: 234
# Street: CO-115               Count: 224
# Street: S Academy Blvd       Count: 222
# Street: Barkeley Ave         Count: 200
# Street: S Powers Blvd        Count: 198
# Street: Sheridan Ave         Count: 191
# Street: Chiles Ave           Count: 165
# Street: CanAm Hwy            Count: 148
# Street: Harr Ave             Count: 127
# Street: US-87                Count: 114
# Street: Wilderness Rd        Count: 92
# Street: JL Ranch Heights Rd  Count: 85
# Street: Milton E Proby Pkwy  Count: 76
# Street: Prussman Blvd        Count: 75
# Street: US-24                Count: 65
# Street: Fountain Mesa Rd     Count: 61
# Street: Butts Rd             Count: 58
# Street: O'Connell Blvd       Count: 58
# Street: Cochrane Cir         Count: 52
# Street: Lake Ave             Count: 50
# Street: S Tejon St           Count: 50
# Street: Ardennes St          Count: 47
# Street: S Chelton Rd         Count: 44
# Street: Fontaine Blvd        Count: 44
# Street: Cheyenne Meadows Rd  Count: 42
# Street: Bradley Rd           Count: 42
# Street: Warfighter Rd        Count: 40
# Street: Mesa Ridge Pkwy      Count: 37
# Street: Comanche Village Dr  Count: 34
# Street: Ellis St             Count: 30
# Street: CO-21                Count: 30
# Street: Venetucci Blvd       Count: 30
# Street: Walmart Hts          Count: 29
# Street: Funk Ave             Count: 28
# Street: E Woodmen Rd         Count: 27
# Street: Coleman St           Count: 26
# Street: Utah Beach Dr        Count: 26
# Street: Sutherland Cir       Count: 26
# Street: Martinez St          Count: 25
# Street: Airport Rd           Count: 25
# Street: Mesa Rd              Count: 25
# Street: Westmeadow Dr        Count: 24
# Street: Bastogne Dr          Count: 24
# Street: S Nevada Ave         Count: 24
# Street: Syracuse St          Count: 22
# Street: Minick Ave           Count: 22
# Street: Wetzel Ave           Count: 21
# Street: Hourglass Dr         Count: 21
# Street: Squirrel Creek Rd    Count: 20
# Street: Jimmy Camp Rd        Count: 20
# Street: Security Blvd        Count: 19
# Street: Burris St            Count: 19
# Street: Broadmoor Bluffs Dr  Count: 18
# Street: C & S Rd             Count: 18
# Street: Rock Creek Canyon Rd Count: 18
# Street: Southgate Rd         Count: 18
# Street: N Academy Blvd       Count: 18
# Street: S Fountain St        Count: 18
# Street: S Main St            Count: 18
# Street: Light Fighter Dr     Count: 17
# Street: Kit Carson Dr        Count: 17
# Street: Inchon Cir           Count: 17
# Street: Uintah St            Count: 16
# Street: E Cheyenne Mountain Blvd Count: 16
# Street: Pacific Hills Point  Count: 16
# Street: Grove St             Count: 16
# Street: Benning Street       Count: 16
# Street: Kearsarge Dr         Count: 15
# Street: Mekong St            Count: 15
# Street: Dean Dr              Count: 15
# Street: Monterey Rd          Count: 15
# Street: Oakshire Way         Count: 14
# Street: Descendant Dr        Count: 14
# Street: S Murray Blvd        Count: 14
# Street: Bayonet Cir          Count: 14
# Street: Mcnerney St          Count: 13
# Street: State Hwy 122        Count: 13
# Street: Astrozon Blvd        Count: 12
# Street: Legend Oak Dr        Count: 12
# Street: Dancing Light Way    Count: 12
# Street: Main St              Count: 12
# Street: Lamprey Dr           Count: 12
# Street: Khe Sanh St          Count: 12
# Street: Briargate Pkwy       Count: 12
# Street: Raemar Dr            Count: 12
# Street: Research Pkwy        Count: 12
# Street: Bad Toelz Rd         Count: 12
# Street: N Union Blvd         Count: 12
# Street: Hancock Expy         Count: 12
# Street: Palmer Park Blvd     Count: 11
# Street: Sam Houston Loop     Count: 11
# Street: Mountain View Apartment Count: 11
# Street: Silver Glen Dr       Count: 11
# Street: Sneffels St          Count: 11
# Street: Drennan Road         Count: 10
# Street: Barnes Rd            Count: 10
# Street: W Cheyenne Rd        Count: 10
# Street: Old Glory Dr         Count: 10
# Street: Red Dawn Dr          Count: 10
# Street: Eassayons Rd         Count: 10
# Street: Irwin Dr             Count: 10
# Street: Pikes Peak Ave       Count: 9
# Street: Goldfield Dr         Count: 9
# Street: Wayfarer Dr          Count: 9
# Street: Picket St            Count: 9
# Street: Attu Dr              Count: 9
# Street: Normandy Rd          Count: 9
# Street: Grinnell Blvd        Count: 9
# Street: Baptist Rd           Count: 9
# Street: Santa Fe Ave         Count: 9
# Street: Old Pueblo Rd        Count: 9
# Street: Star Ranch Rd        Count: 9
# Street: Delta Dr             Count: 8
# Street: Winnicut Dr          Count: 8
# Street: S Marksheffel Rd     Count: 8
# Street: Hartford St          Count: 8
# Street: Ware St              Count: 8
# Street: Willowdale Dr        Count: 8
# Street: Cordera Crest Ave    Count: 8
# Street: Autumn Glen Ave      Count: 8
# Street: Piros Dr             Count: 8
# Street: W Cheyenne Mountain Blvd Count: 8
# Street: Jersey Ln            Count: 8
# Street: Cross Creek          Count: 8
# Street: Middle Bay Way       Count: 8
# Street: Lashelle Way         Count: 8
# Street: S 8th St             Count: 8
# Street: Eastmeadow Dr        Count: 8
# Street: Chaseglen Dr         Count: 8
# Street: Constitution Ave     Count: 8
# Street: W Brookside St       Count: 8
# Street: Woodfill Rd          Count: 7
# Street: Wickersham Blvd      Count: 7
# Street: Tutt Blvd            Count: 7
# Street: Willow Pines Pl      Count: 7
# Street: Tank Rd              Count: 7
# Street: Just Cause Dr        Count: 7
# Street: 17th St              Count: 7
# Street: Link Rd              Count: 7
# Street: CO-47                Count: 7
# Street: E Ohio Ave           Count: 7
# Street: Progress Dr          Count: 7
# Street: W Bijou St           Count: 7
# Street: Meadow Peak View     Count: 7
# Street: Marksheffel Rd       Count: 7
# Street: Pershing Dr          Count: 7
# Street: St Lo Cir            Count: 6
# Street: Drury Ln             Count: 6
# Street: Fay Dr               Count: 6
# Street: Spring Bluff Rd      Count: 6
# Street: Mitchell St          Count: 6
# Street: Welton Dr            Count: 6
# Street: Hallam Ave           Count: 6
# Street: Space Center Dr      Count: 6
# Street: Galley Rd            Count: 6
# Street: Carey St             Count: 6
# Street: Ardley Dr            Count: 6
# Street: S Rockrimmon Blvd    Count: 6
# Street: Pomber St            Count: 6
# Street: Vail Pass Dr         Count: 6
# Street: Whimsical Dr         Count: 6
# Street: Oregon Wagon Trail   Count: 6
# Street: Michelle Ct          Count: 6
# Street: Shelley Ave          Count: 6
# Street: Abbot St             Count: 6
# Street: Mesa Ave             Count: 6
# Street: Rebecca Ln           Count: 6
# Street: Prominent Point      Count: 6
# Street: Cheyenne Mountain Zoo Rd Count: 6
# Street: Eliot Ave            Count: 6
# Street: Iron Fighter Dr      Count: 6
# Street: Lydia Grove          Count: 6
# Street: Long St              Count: 6
# Street: Campground Dr        Count: 6
# Street: Louise Ln            Count: 6
# Street: Mesa Top Dr          Count: 6
# Street: Sisters Grove        Count: 6
# Street: Marabou Way          Count: 6
# Street: Asher Hts            Count: 6
# Street: Silverqueen Rd       Count: 6
# Street: Eagleridge Cir       Count: 6
# Street: Bays Water Dr        Count: 6
# Street: E Jackson St         Count: 6
# Street: N Cascade Ave        Count: 6
# Street: Brylie Way           Count: 6
# Street: B St                 Count: 6
# Street: Abbot Ln             Count: 6
# Street: Forrest Blfs Vw      Count: 6
# Street: Lexington Dr         Count: 6
# Street: Willow Spring Rd     Count: 6
# Street: Willis Dr            Count: 6
# Street: Bent Grass Meadows Dr Count: 6
# Street: Ballona Dr           Count: 6
# Street: W Illinois Ave       Count: 6
# Street: Stratmoor Dr         Count: 6
# Street: Centennial Blvd      Count: 6
# Street: Wycliffe Dr          Count: 6
# Street: Verdun Loop          Count: 6
# Street: Dublin Blvd          Count: 6
# Street: Grand Prix Ct        Count: 6
# Street: Womack St            Count: 6
# Street: S Marksheffel Blvd   Count: 6
# Street: Hare Ave             Count: 6
# Street: Jet Wing Dr          Count: 6
# Street: S Union Blvd         Count: 6
# Street: Conrad St            Count: 5
# Street: Old Ranch Rd         Count: 5
# Street: CO-94                Count: 5
# Street: Evans St             Count: 5
# Street: Paine Street         Count: 5
# Street: Crawford Ave         Count: 5
# Street: Citadel Dr N         Count: 5
# Street: St Lo Dr             Count: 5
# Street: N Allworth Ct        Count: 5
# Street: Benecia Dr           Count: 5
# Street: E Platte Ave         Count: 5
# Street: S 21st St            Count: 5
# Street: S Circle Dr          Count: 5
# Street: Guadal Canal Cir     Count: 5
# Street: Tevis St             Count: 5
# Street: Quebec St            Count: 4
# Street: Sistine Ln           Count: 4
# Street: Araia Dr             Count: 4
# Street: Marlow Cir           Count: 4
# Street: S Carefree Cir       Count: 4
# Street: Sanders View         Count: 4
# Street: Aliso Dr             Count: 4
# Street: Pine Dr              Count: 4
# Street: S Gate Blvd          Count: 4
# Street: Charter Oak Ranch Rd Count: 4
# Street: Son Tay Rd           Count: 4
# Street: Firecracker Trail    Count: 4
# Street: Integrity Center Point Count: 4
# Street: Tenderfoot Hill Rd   Count: 4
# Street: Mazatlan Cir         Count: 4
# Street: Christie St          Count: 4
# Street: Alturas Dr           Count: 4
# Street: Hidden Pr Pkwy       Count: 4
# Street: MacKenzie Ave        Count: 4
# Street: Parliament Dr        Count: 4
# Street: E St Elmo Ave        Count: 4
# Street: Roth Ave             Count: 4
# Street: Woody Creek Dr       Count: 4
# Street: Huertgen Forest Rd   Count: 4
# Street: Como Bay St          Count: 4
# Street: Mineral Belt Dr      Count: 4
# Street: Cattle Baron Wy      Count: 4
# Street: Pitcher Point        Count: 4
# Street: E Fountain Blvd      Count: 4
# Street: Lorson Blvd          Count: 4
# Street: E Navajo St          Count: 4
# Street: Marne Loop           Count: 4
# Street: Lakehurst Dr         Count: 4
# Street: E Cheyenne Rd        Count: 4
# Street: Brant Rd             Count: 4
# Street: E Costilla St        Count: 4
# Street: Garden of the Gods Rd Count: 4
# Street: Gold Hill Mesa Dr    Count: 4
# Street: Loomis Ave           Count: 4
# Street: De La Vista St       Count: 3
# Street: McChord St           Count: 3
# Street: San Amels Way        Count: 3
# Street: Cortez Dr            Count: 3
# Street: Templeton Gap Rd     Count: 3
# Street: Jackpot Dr           Count: 3
# Street: Tech Center Dr       Count: 3
# Street: Portal Dr E          Count: 3
# Street: Rio Vista Dr         Count: 3
# Street: Spring Grove Way     Count: 3
# Street: Springmeadow Dr      Count: 3
# Street: Latigo Blvd          Count: 3
# Street: S 31st St            Count: 3
# Street: Garrett Rd           Count: 3
# Street: Ruskin Dr            Count: 3
# Street: Stingray Ln          Count: 3
# Street: Camino Del Rey       Count: 3
# Street: Cll Fontana          Count: 3
# Street: Duckwood Rd          Count: 3
# Street: Curtis Rd            Count: 3
# Street: E Columbine Dr       Count: 3
# Street: E Pine Loop          Count: 3
# Street: Carlton Dr           Count: 3
# Street: Grand Cordera Pkwy   Count: 3
# Street: Marland Rd S         Count: 3
# Street: Fountain Ave         Count: 3
# Street: Squire St            Count: 3
# Street: Cowpoke Rd           Count: 3
# Street: Black Forest Rd      Count: 3
# Street: S Perry St           Count: 3
# Street: Plum Creek Pkwy      Count: 3
# Street: Frontage Rd          Count: 3
# Street: Test Dr              Count: 3
# Street: Goodfellow St        Count: 3
# Street: Ent Ave              Count: 3
# Street: E Hwy 105            Count: 3
# Street: Kittery Dr           Count: 3
# Street: Selfridge St         Count: 3
# Street: Lindbergh Rd         Count: 3
# Street: Pond Terrace         Count: 3
# Street: Fencer Rd            Count: 3
# Street: Capistrano Point     Count: 3
# Street: Pmi Access Rd        Count: 3
# Street: Pueblo Blvd          Count: 3
# Street: Ridge Dr             Count: 3
# Street: N Elizabeth St       Count: 3
# Street: Family Pl            Count: 3
# Street: Lashelle Ave         Count: 3
# Street: 5th Ave              Count: 3
# Street: 7th St               Count: 3
# Street: Elmhurst Dr          Count: 3
# Street: Willett Cir          Count: 3
# Street: Passing Sky Dr       Count: 3
# Street: Escanaba Dr          Count: 3
# Street: Morado Dr            Count: 3
# Street: Heathercrest Dr      Count: 3
# Street: Pinnacle Dr          Count: 3
# Street: Carefree Cir N       Count: 3
# Street: Van Teylingen Dr     Count: 3
# Street: Londonderry Dr       Count: 3
# Street: Ancestra Dr          Count: 3
# Street: Vincent Dr           Count: 3
# Street: E Willamette Ave     Count: 3
# Street: E Cimarron St        Count: 3
# Street: Journey Dr           Count: 3
# Street: Aviation Way         Count: 3
# Street: Spotted Tail Dr      Count: 3
# Street: Harrier Ridge Dr     Count: 3
# Street: Antelope Ridge Dr    Count: 3
# Street: Shasta Dr            Count: 3
# Street: Wilson Rd            Count: 3
# Street: Maxwell St           Count: 3
# Street: Vickers Dr           Count: 3
# Street: Peterson Rd          Count: 3
# Street: E Bijou St           Count: 3
# Street: Purcell Blvd         Count: 3
# Street: Okinawa Dr           Count: 3
# Street: Woodstock St         Count: 3
# Street: Otis St              Count: 2
# Street: Neal Ct              Count: 2
# Street: Cheyenne Blvd        Count: 2
# Street: Holly Ave            Count: 2
# Street: Conquista Dr         Count: 2
# Street: S Log Rd             Count: 2
# Street: Pikes Peak Hwy       Count: 2
# Street: Eagleridge Blvd      Count: 2
# Street: Austin Bluffs Pkwy   Count: 2
# Street: Grant St             Count: 2
# Street: Crestridge Ave       Count: 2
# Street: Catalina Dr          Count: 2
# Street: Florence Ave         Count: 2
# Street: US-50                Count: 2
# Street: Beckham St           Count: 2
# Street: Pinon Valley Rd      Count: 2
# Street: Brigantine Dr        Count: 2
# Street: Wilcox St            Count: 2
# Street: Pebble Ridge Cir     Count: 2
# Street: W 43rd St            Count: 2
# Street: US-287               Count: 2
# Street: Drennan Rd           Count: 2
# Street: Chatfield Dr         Count: 2
# Street: Bass Pro Dr          Count: 2
# Street: Spectrum Loop        Count: 2
# Street: Voyager Pkwy         Count: 2
# Street: Cobblestone Dr       Count: 2
# Street: Garman Dr            Count: 2
# Street: Johanne Pl           Count: 2
# Street: Avenida Del Cielo    Count: 2
# Street: W Douglass Dr        Count: 2
# Street: E Douglass Dr        Count: 2
# Street: Community Center Dr  Count: 2
# Street: N Prospect St        Count: 2
# Street: Dover St             Count: 2
# Street: Lyckman Dr           Count: 2
# Street: 8th St               Count: 2
# Street: Praderia Ave         Count: 2
# Street: Maizeland Rd         Count: 2
# Street: Moccassin Dr         Count: 2
# Street: Silver Stirrup Dr    Count: 2
# Street: Presidential Heights Count: 2
# Street: E Kiowa St           Count: 2
# Street: Trojan Pt            Count: 2
# Street: Candelabra Dr        Count: 2
# Street: Datil Path           Count: 2
# Street: Horizonview Dr       Count: 2
# Street: Concerto Dr          Count: 2
# Street: Maram Way            Count: 2
# Street: Camden Blvd          Count: 2
# Street: Edmondstown Dr       Count: 2
# Street: Donahue Dr           Count: 2
# Street: Vickie Ln            Count: 2
# Street: Adana Dr             Count: 2
# Street: Tory Ridge Dr        Count: 2
# Street: Stetson Hills Blvd   Count: 2
# Street: Pine Village Way     Count: 2
# Street: S Woodland Ave       Count: 2
# Street: Windingpark Dr       Count: 2
# Street: S Vern St            Count: 2
# Street: N Tejon St           Count: 2
# Street: N El Paso St         Count: 2
# Street: Harlow Ridge Pl      Count: 2
# Street: Coral Ridge Dr       Count: 2
# Street: Mc Donald St         Count: 2
# Street: Snowy River Dr       Count: 2
# Street: Rea Rd               Count: 2
# Street: Coventry Dr          Count: 2
# Street: Hannah Ridge Dr      Count: 2
# Street: Hogan St             Count: 2
# Street: Broadway             Count: 2
# Street: Douglas Ln           Count: 2
# Street: Jerry Murphy Rd      Count: 2
# Street: Parkglen Dr          Count: 2
# Street: Stockton Dr          Count: 2
# Street: Afton St             Count: 2
# Street: Chia Dr              Count: 2
# Street: Sand Myrtle Dr       Count: 2
# Street: Senita Dr            Count: 2
# Street: E Euclid Ave         Count: 2
# Street: Raven Hills Ct       Count: 2
# Street: Westmark Ave         Count: 2
# Street: Yampa River Heights  Count: 2
# Street: Bennett St           Count: 2
# Street: Janitell Rd          Count: 2
# Street: Payette Dr           Count: 2
# Street: S Limit St           Count: 2
# Street: Miller Rd            Count: 2
# Street: Yano St              Count: 2
# Street: Piute Rd             Count: 2
# Street: E Boulder St         Count: 2
# Street: Manzana Dr           Count: 2
# Street: S Hancock Ave        Count: 2
# Street: CO-67                Count: 2
# Street: Bonita Dr            Count: 2
# Street: Shea Dr              Count: 2
# Street: Wageman Dr           Count: 2
# Street: Lamine Dr            Count: 2
# Street: Oxford Ln            Count: 2
# Street: Interquest Pkwy      Count: 2
# Street: Crestone Ln          Count: 2
# Street: Rocky Bluff Point    Count: 2
# Street: Explorer Dr          Count: 2
# Street: Coyote Run Trail     Count: 2
# Street: Chalkstone Ln        Count: 2
# Street: Chamberlin S         Count: 2
# Street: Friendship Ln W      Count: 2
# Street: Langley St           Count: 2
# Street: Catalina Pl          Count: 2
# Street: Broadmoor Valley Rd  Count: 2
# Street: Lincoln Plaza Dr     Count: 1
# Street: Early Sun Dr         Count: 1
# Street: Academy Cir          Count: 1
# Street: Campus Dr            Count: 1
# Street: S Weber St           Count: 1
# Street: E Antelope Dr        Count: 1
# Street: S Peterson Blvd      Count: 1
# Street: Innovation Loop      Count: 1
# Street: Peak Innovation Pkwy Count: 1
# Street: Beacon Lite Rd       Count: 1
# Street: Thunder Mountain Ave Count: 1
# Street: Manitou Blvd         Count: 1
# Street: N Walnut St          Count: 1
# Street: Radiant Dr           Count: 1
# Street: Josephine Heights    Count: 1
# Street: Cheyenne Villas Point Count: 1
# Street: Flintshire St        Count: 1
# Street: Fiona Ln             Count: 1
# Street: Newport Rd           Count: 1
# Street: Cresta Rd            Count: 1
# Street: Sunshine Trail       Count: 1
# Street: Cliff Rd             Count: 1
# Street: Country Park Point   Count: 1
# Street: Saguaro Cir          Count: 1
# Street: Elwell St            Count: 1
# Street: Village Meadows Dr   Count: 1
# Street: Center Valley Dr     Count: 1
# Street: Morningside Dr       Count: 1
# Street: Raywood View         Count: 1
# Street: Arlington Dr         Count: 1
# Street: McCullough Cir       Count: 1
# Street: Tierra Rojo Dr       Count: 1
# Street: Hiddenwalk Way       Count: 1
# Street: Lambert Rd           Count: 1
# Street: Stapleton Dr         Count: 1
# Street: Meridian Rd          Count: 1
# Street: Half Turn Rd         Count: 1
# Street: W Rockrimmon Blvd    Count: 1
# Street: Manistique Dr        Count: 1
# Street: Vandenberg St        Count: 1
# Street: W Fillmore St        Count: 1
# Street: Creekfront Dr        Count: 1
# Street: Hurley Dr            Count: 1
# Street: Echoglen Ct          Count: 1
# Street: Fort St              Count: 1
# Street: Willshire Dr         Count: 1
# Street: Aspen Dr             Count: 1
# Street: Grand Blvd           Count: 1
# Street: Hackberry Dr         Count: 1
# Street: Widefield Dr         Count: 1
# Street: Skuna Dr             Count: 1
# Street: Creek Crossing St    Count: 1
# Street: W Rio Grande St      Count: 1
# Street: Pickaxe Terrace      Count: 1
# Street: Lower Gold Camp Rd   Count: 1
# Street: Widefield Blvd       Count: 1
# Street: E Cholla Dr          Count: 1
# Street: N Lyons Dr           Count: 1
# Street: N Platteville Blvd   Count: 1
# Street: Gobatti Pl           Count: 1
# Street: Grissom Dr.          Count: 1
# Street: Village Rd S         Count: 1
# Street: Verde Dr             Count: 1
# Street: Bandley Dr           Count: 1
# Street: Hunter Jumper Dr     Count: 1
# Street: Jeffers Way          Count: 1
# Street: Paragon Dr           Count: 1
# Street: Desert Cir           Count: 1
# Street: Brahma Trail         Count: 1
# Street: E Ramona Ave         Count: 1
# Street: Loma Vista Point     Count: 1
# Street: Vista Ridge Point    Count: 1
# Street: Birmingham Loop      Count: 1
# Street: Grandstaff St        Count: 1
# Street: Sand Creek Dr        Count: 1
# Street: S Colorado Blvd      Count: 1
# Street: Flint St             Count: 1
# Street: Wahsatch Ave         Count: 1
# Street: Raven Hills Rd       Count: 1
# Street: Rusina Rd            Count: 1
# Street: Elkton Dr            Count: 1
# Street: N Chestnut St        Count: 1
# Street: Springridge Dr       Count: 1
# Street: Norad Rd             Count: 1
# Street: Ketchum Dr           Count: 1
# Street: Lolo Dr              Count: 1
# Street: Barn Owl Dr          Count: 1
# Street: Plaza Blvd           Count: 1
# Street: Escapardo Way        Count: 1
# Street: Oro Blanco Dr        Count: 1
# Street: Harvard St           Count: 1
# Street: Farthing Dr          Count: 1
# Street: Pawnee Rd            Count: 1
# Street: Bijou Ct             Count: 1
# Street: N Weber St           Count: 1
# Street: Cantrell Dr          Count: 1
# Street: Naples Dr            Count: 1
# Street: B Street over Pass   Count: 1
# Street: Ridgegate Pkwy       Count: 1
# Street: Wineglass Rd         Count: 1
# Street: Bar B Rd             Count: 1
# Street: Falling Star Rd      Count: 1
# Street: Grand Overlook St    Count: 1
# Street: Springs Vista St     Count: 1
# Street: Carson Cir           Count: 1
# Street: Carson Blvd          Count: 1
# Street: Harvest Moon Terrace Count: 1
# Street: Hazy Morning Dr      Count: 1
# Street: Old Hospital St      Count: 1
# Street: Printers Pkwy        Count: 1
# Street: S Parkside Dr        Count: 1
# Street: Quail Lake Rd        Count: 1
# Street: Bayfield Dr          Count: 1
# Street: Deer Meadow Cir      Count: 1
# Street: Roundup Butte St     Count: 1
# Street: Eagle View Dr        Count: 1
# Street: El Morro Rd          Count: 1
# Street: Picatinny Ln         Count: 1
# Street: Chaplin Dr           Count: 1
# Street: Matta Dr             Count: 1
# Street: Meadowland Blvd      Count: 1
# Street: Indian Pipe Cir      Count: 1
# Street: Rampart Hills View   Count: 1
# Street: Hartsel Dr           Count: 1
# Street: Ordway Dr            Count: 1
# Street: Carriage Meadows Dr  Count: 1
# Street: King St              Count: 1
# Street: Brown Rd             Count: 1
# Street: Stewart Ave          Count: 1
# Street: Cranbrook Cir        Count: 1
# Street: Glenhurst Dr         Count: 1
# Street: Chapel Hills Dr      Count: 1
# Street: Jamboree Dr          Count: 1
# Street: San Felice Point     Count: 1
# Street: Circle Dr            Count: 1
# Street: Travis St            Count: 1
# Street: Highland Way         Count: 1
# Street: N Curtis Rd          Count: 1
# Street: Chipita Park Rd      Count: 1
# Street: Illinois St          Count: 1
# Street: Edisto Dr            Count: 1
# Street: Montrose Ave         Count: 1
# Street: Laramie Dr           Count: 1
