# %%
#import libraries
import numpy as np
import pandas as pd
import ast
import requests
import urllib.parse

# %%
#get data
visits_df = pd.read_csv("your_data_may_12_2022_0506pm.csv.gz", compression = "gzip")

# %%
#convert dates to datetime
visits_df['date_range_start'] = pd.to_datetime(visits_df['date_range_start'], infer_datetime_format = True)
visits_df['date_range_end'] = pd.to_datetime(visits_df['date_range_end'], infer_datetime_format = True)

# %%
#get lat and long for unique streets
lat = []
lon = []
adds = []

for str_addr in visits_df["street_address"].unique():
    try:
        url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(str_addr) +'?format=json'

        response = requests.get(url).json()
        lat.append(response[0]["lat"])
        lon.append(response[0]["lon"])
    except:
        adds.append(str_addr)
        lat.append(np.nan)
        lon.append(np.nan)

# %%
#substitute addresses that don't return responses
adds_sub = ['1650 Cochrane Circle, Fort Carson', '6110 Martinez St', '6520 Specker Ave', 'AAFES, Chiles Ave',
 '1804 Prussman Blvd', 'Martinez St, Fort Carson', '1925 Specker Ave', '900 Magrath Ave', 'Ware Street, Fort Carson',
 '1637 Flint St, Fort Carson', 'Fort st, Fort Carson', 'McCullough Circle, Fort Carson',
 '5115 Chiles Ave', '980 O\'Connell Boulevard, Fort Carson',
 '5553 Fort St, Fort Carson', 'Martinez St, Fort Carson', 'Wilderness Road, Colorado', 'Butts Rd, Fort Carson', 
 '6980 Quinn St', '1725 Woodfill Rd', '1511 chiles Ave, Fort Carson', '1553 Wetzel Ave, Fort Carson']

# %%
adds_dict = dict(zip(adds, adds_sub))

# %% [raw]
# {'Fort Carson Meddac 1650 Cochrane Circle': '1650 Cochrane Circle, Fort Carson',
#  'Fort Carson Charleys 6110 Martinez St': '6110 Martinez St',
#  '6520 Specker Ave Bldg 1827': '6520 Specker Ave',
#  'Aafes Food Ct Chiles Ave': 'AAFES, Chiles Ave',
#  '1804 Prussman Blvd Bldg 1534': '1804 Prussman Blvd',
#  'Martinez St Bldg 1500': 'Martinez St, Fort Carson',
#  '1925 Sprecker Ave': '1925 Specker Ave',
#  'Bldg 900 Mcgrath Ave': '900 Magrath Ave',
#  'NE Corner Ellis Street &Amp; Ware Street Fort Cars': 'Ware Street, Fort Carson',
#  '1637 Flint St Bldg 1528': '1637 Flint St, Fort Carson',
#  '5410 Red Dawn Dr Apt A': 'Fort st, Fort Carson',
#  '5420 Sapper Lp': 'McCullough Circle, Fort Carson',
#  '5115 Chiles Ave Bldg 510': '5115 Chiles Ave',
#  '980 Oconnell Blvd': "980 O'Connell Boulevard, Fort Carson",
#  '5553 Fort St Apt D': '5553 Fort St, Fort Carson',
#  'Aafes Foodcourt Martinez St': 'Martinez St, Fort Carson',
#  '1 Wilderness Rd At Range Control': 'Wilderness Road, Colorado',
#  'Wilderness Rd @ Butts Rd.': 'Butts Rd, Fort Carson',
#  '6980 Quinn St Bldg 2355': '6980 Quinn St',
#  '1725 Woodfill Rd Bldg 7300': '1725 Woodfill Rd',
#  '1511chiles Ave': '1511 chiles Ave, Fort Carson',
#  '1553 Wetzel Ave Bldg 1513': '1553 Wetzel Ave, Fort Carson'}

# %%
visits_df["street_address"] = visits_df["street_address"].apply(lambda st: adds_dict.get(st, st))

# %%
#get lat and long for unique streets
add_lat = {}
add_lon = {}

for str_addr in visits_df["street_address"].unique():
    try:
        url = 'https://nominatim.openstreetmap.org/search/' + urllib.parse.quote(str_addr) +'?format=json'

        response = requests.get(url).json()
        add_lat[str_addr] = response[0]["lat"]
        add_lon[str_addr] = response[0]["lon"]
    except:
        add_lat[str_addr] = np.nan
        add_lon[str_addr] = np.nan

# %%
#getting lat and long for the data
visits_df["latitude"] = visits_df["street_address"].apply(lambda st: add_lat[st])
visits_df["longitude"] = visits_df["street_address"].apply(lambda st: add_lon[st])

# %%
visits_df.isnull().sum()
# Out:
# placekey                                         0
# parent_placekey                               3599
# location_name                                    0
# street_address                                   0
# city                                             0
# region                                           0
# postal_code                                      0
# iso_country_code                                 0
# safegraph_brand_ids                           2702
# brands                                        2702
# date_range_start                                 0
# date_range_end                                   0
# raw_visit_counts                                 0
# raw_visitor_counts                               0
# visits_by_day                                    0
# visits_by_each_hour                              0
# poi_cbg                                          0
# visitor_home_cbgs                                0
# visitor_home_aggregation                         0
# visitor_daytime_cbgs                             0
# visitor_country_of_origin                       18
# distance_from_home                             444
# median_dwell                                     0
# bucketed_dwell_times                             0
# related_same_day_brand                           0
# related_same_week_brand                          0
# device_type                                      0
# normalized_visits_by_state_scaling               0
# normalized_visits_by_total_visits                0
# normalized_visits_by_total_visitors              0
# normalized_visits_by_region_naics_visits         0
# normalized_visits_by_region_naics_visitors       0
# latitude                                         0
# longitude                                        0
# dtype: int64

# %%
#sort by date
visits_df = visits_df.sort_values(by = ["date_range_start"])

# %%
#convert string of list to list
visits_df["visits_by_day"] = visits_df["visits_by_day"].apply(lambda x: ast.literal_eval(x))
visits_df["visits_by_each_hour"] = visits_df["visits_by_each_hour"].apply(lambda x: ast.literal_eval(x))

# %%
#split visits by dates
visits_df_split = visits_df.explode("visits_by_day")

# %%
#add 7 indices for each week
visits_df_split["date_idx"] = list(range(0, 7))*visits_df.shape[0]

# %%
#convert indices to timedelta from the start of the week
visits_df_split["date"] = visits_df_split["date_idx"].apply(lambda idx: pd.Timedelta(days = idx))

# %%
#get date by adding timedelta to the start of the week
visits_df_split['date'] = visits_df_split['date_range_start'] + visits_df_split["date"]
# Out:
# /Users/priyankarotte/opt/anaconda3/lib/python3.8/site-packages/pandas/core/arrays/datetimelike.py:1108: PerformanceWarning: Adding/subtracting object-dtype array to TimedeltaArray not vectorized
#   warnings.warn(

# %%
#get visits by each hour per day
visits_df_split['visits_by_each_hour'] = visits_df_split.apply(lambda df: 
                                                               df.visits_by_each_hour[df.date_idx * 24: 
                                                                                      df.date_idx * 24 + 24], 
                                                               axis=1)

# %%
visits_df_split[["date"]]
# Out:
#                           date
# 672  2020-09-28 00:00:00-06:00
# 672  2020-09-29 00:00:00-06:00
# 672  2020-09-30 00:00:00-06:00
# 672  2020-10-01 00:00:00-06:00
# 672  2020-10-02 00:00:00-06:00
# ..                         ...
# 0    2021-09-22 00:00:00-06:00
# 0    2021-09-23 00:00:00-06:00
# 0    2021-09-24 00:00:00-06:00
# 0    2021-09-25 00:00:00-06:00
# 0    2021-09-26 00:00:00-06:00
#
# [27027 rows x 1 columns]

# %%
#add week
visits_df_split['week'] = pd.to_datetime(visits_df_split['date'], infer_datetime_format = True, utc = True).dt.isocalendar().week

# %%
#add month
visits_df_split['month'] = pd.to_datetime(visits_df_split['date'], infer_datetime_format = True, utc = True).dt.month

# %%
visits_df_split.to_csv("safegraph.csv")

# %%
visits_df_split
# Out:
#                 placekey parent_placekey            location_name  \
# 672  222-22c@5q9-7d4-mx5             NaN  Out of the Norm Designs
# 672  222-22c@5q9-7d4-mx5             NaN  Out of the Norm Designs
# 672  222-22c@5q9-7d4-mx5             NaN  Out of the Norm Designs
# 672  222-22c@5q9-7d4-mx5             NaN  Out of the Norm Designs
# 672  222-22c@5q9-7d4-mx5             NaN  Out of the Norm Designs
# ..                   ...             ...                      ...
# 0    zzy-222@5q9-7cw-q75             NaN      Evans ACH FT Carson
# 0    zzy-222@5q9-7cw-q75             NaN      Evans ACH FT Carson
# 0    zzy-222@5q9-7cw-q75             NaN      Evans ACH FT Carson
# 0    zzy-222@5q9-7cw-q75             NaN      Evans ACH FT Carson
# 0    zzy-222@5q9-7cw-q75             NaN      Evans ACH FT Carson
#
#                         street_address         city region  postal_code  \
# 672                   6110 Martinez St  Fort Carson     CO        80913
# 672                   6110 Martinez St  Fort Carson     CO        80913
# 672                   6110 Martinez St  Fort Carson     CO        80913
# 672                   6110 Martinez St  Fort Carson     CO        80913
# 672                   6110 Martinez St  Fort Carson     CO        80913
# ..                                 ...          ...    ...          ...
# 0    1650 Cochrane Circle, Fort Carson  Fort Carson     CO        80913
# 0    1650 Cochrane Circle, Fort Carson  Fort Carson     CO        80913
# 0    1650 Cochrane Circle, Fort Carson  Fort Carson     CO        80913
# 0    1650 Cochrane Circle, Fort Carson  Fort Carson     CO        80913
# 0    1650 Cochrane Circle, Fort Carson  Fort Carson     CO        80913
#
#     iso_country_code safegraph_brand_ids brands  ...  \
# 672               US                 NaN    NaN  ...
# 672               US                 NaN    NaN  ...
# 672               US                 NaN    NaN  ...
# 672               US                 NaN    NaN  ...
# 672               US                 NaN    NaN  ...
# ..               ...                 ...    ...  ...
# 0                 US                 NaN    NaN  ...
# 0                 US                 NaN    NaN  ...
# 0                 US                 NaN    NaN  ...
# 0                 US                 NaN    NaN  ...
# 0                 US                 NaN    NaN  ...
#
#     normalized_visits_by_total_visits normalized_visits_by_total_visitors  \
# 672                          0.000018                            0.000047
# 672                          0.000018                            0.000047
# 672                          0.000018                            0.000047
# 672                          0.000018                            0.000047
# 672                          0.000018                            0.000047
# ..                                ...                                 ...
# 0                            0.000118                            0.000220
# 0                            0.000118                            0.000220
# 0                            0.000118                            0.000220
# 0                            0.000118                            0.000220
# 0                            0.000118                            0.000220
#
#      normalized_visits_by_region_naics_visits  \
# 672                                  0.001594
# 672                                  0.001594
# 672                                  0.001594
# 672                                  0.001594
# 672                                  0.001594
# ..                                        ...
# 0                                    0.011520
# 0                                    0.011520
# 0                                    0.011520
# 0                                    0.011520
# 0                                    0.011520
#
#      normalized_visits_by_region_naics_visitors          latitude  \
# 672                                    0.002099  38.7370794797105
# 672                                    0.002099  38.7370794797105
# 672                                    0.002099  38.7370794797105
# 672                                    0.002099  38.7370794797105
# 672                                    0.002099  38.7370794797105
# ..                                          ...               ...
# 0                                      0.023156       38.71985545
# 0                                      0.023156       38.71985545
# 0                                      0.023156       38.71985545
# 0                                      0.023156       38.71985545
# 0                                      0.023156       38.71985545
#
#                longitude  date_idx                       date week month
# 672          -104.796681         0  2020-09-28 00:00:00-06:00   40     9
# 672          -104.796681         1  2020-09-29 00:00:00-06:00   40     9
# 672          -104.796681         2  2020-09-30 00:00:00-06:00   40     9
# 672          -104.796681         3  2020-10-01 00:00:00-06:00   40    10
# 672          -104.796681         4  2020-10-02 00:00:00-06:00   40    10
# ..                   ...       ...                        ...  ...   ...
# 0    -104.79725291870511         2  2021-09-22 00:00:00-06:00   38     9
# 0    -104.79725291870511         3  2021-09-23 00:00:00-06:00   38     9
# 0    -104.79725291870511         4  2021-09-24 00:00:00-06:00   38     9
# 0    -104.79725291870511         5  2021-09-25 00:00:00-06:00   38     9
# 0    -104.79725291870511         6  2021-09-26 00:00:00-06:00   38     9
#
# [27027 rows x 38 columns]
