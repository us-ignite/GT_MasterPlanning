# %%
import pandas as pd

# %%
header = list(pd.read_csv('TripBulkReportTripsHeaders.csv',keep_default_na=True))
df_1 = pd.read_csv('trips.csv', keep_default_na=True, names=header, index_col=False)
df_2 = pd.read_csv('trips1.csv', keep_default_na=True, names=header, index_col=False)

# %%
df_1.head(10)
# Out:
#                              TripId                          DeviceId  \
# 0  430562b3e55e94dbfb6ae834ed19e9b0  02f0b84069e6caba98665688b907c035
# 1  96b6ea1d8075a91f0303d884d8378bf3  034bbea593bf94b8309a098651c3036c
# 2  d0ecaacf51412f7fcc3117e7eb01d12e  03b672981c5da907cf256bf0245e1d01
# 3  e0f43e41709cbadf8822c72c1974e5e0  066bf8928ed16a20c8aa38236830943f
# 4  bc40dc1213f27351388e3c8e02cc135d  0691bd9c8f51b1aa0ef73e3909ff0467
# 5  00d24e39220be69831d8894e254d7194  06a4af08e5b62c87f3c881ab6aa28681
# 6  914b6769a626b25226395502ef48fd40  0716f93ec5aa2e0ee6b1ebe04cf36c3a
# 7  0f1da24ffba6f8619778c02370215fd3  0780dfc81f2279035d68becd8e3c73c8
# 8  0e8479c5edfb1e8c590c84d1fff8cf60  095b6ec9bf79a36c48dd1251261e304a
# 9  146d9db26257f4fd9e78964f8b758171  0ad4188372ceb1718c3317660130aab7
#
#                          ProviderId  Mode                 StartDate  \
# 0  42998cf32d552343bc8e460416382dca     1  2021-04-07T22:35:03.000Z
# ...

# %%
df_2.head(10)
# Out:
#                              TripId                          DeviceId  \
# 0  f769cba84168f26f310121252a3d6221  016c6f10b672995deacfd2fd69ecea43
# 1  eb35bf94706c43e87cd1188b4eaaa054  0214f23b641fa5aa6a2d2f5f6a3dd319
# 2  dd5ed43edc1d40eb7c94d3f88bb05d37  03a98dc2d758e7f8d5eb93ebde238113
# 3  af0ff252c7d908f49d78528c592318b9  03b9479572de58e5d85430cca8e9bc24
# 4  c1eaff6a58ea4f795599c61317553109  045670b534eaea3ab670fe9f7e1e8fa8
# 5  8075db9e47afa5eaf59d0cde54ce658f  076400f5b759032aa5e7b75911876319
# 6  b6b7d4e7567126008b4bb0e7c1501824  09f7643eba3ed436f7846a4d3faf2631
# 7  87fc0f7fbecc7120cab21997bee7c5c6  0a735b340fe640d398da2f23e1541043
# 8  cba6a626471e2e3ee2584f93561dcdd3  0ba058c22751ec9e3b055501db041f47
# 9  6fc21f3c03fb7f250c14b9f83e25ebef  0c2541e0bb57c3005605b778bfaeb37a
#
#                          ProviderId  Mode                 StartDate  \
# 0  d07e70efcfab08731a97e7b91be644de     1  2020-10-18T20:49:50.000Z
# ...

# %%
trips_df = pd.concat([df_1, df_2], ignore_index=True, axis=0)
trips_df.head()
# Out:
#                              TripId                          DeviceId  \
# 0  430562b3e55e94dbfb6ae834ed19e9b0  02f0b84069e6caba98665688b907c035
# 1  96b6ea1d8075a91f0303d884d8378bf3  034bbea593bf94b8309a098651c3036c
# 2  d0ecaacf51412f7fcc3117e7eb01d12e  03b672981c5da907cf256bf0245e1d01
# 3  e0f43e41709cbadf8822c72c1974e5e0  066bf8928ed16a20c8aa38236830943f
# 4  bc40dc1213f27351388e3c8e02cc135d  0691bd9c8f51b1aa0ef73e3909ff0467
#
#                          ProviderId  Mode                 StartDate  \
# 0  42998cf32d552343bc8e460416382dca     1  2021-04-07T22:35:03.000Z
# 1  d07e70efcfab08731a97e7b91be644de     1  2021-04-06T23:27:12.000Z
# 2  d07e70efcfab08731a97e7b91be644de     1  2021-04-02T21:49:56.000Z
# 3  42998cf32d552343bc8e460416382dca     1  2021-04-06T12:02:42.000Z
# 4  d07e70efcfab08731a97e7b91be644de     1  2021-04-06T19:13:00.000Z
#
#    StartWDay                   EndDate  EndWDay  StartLocLat  StartLocLon  \
# ...
